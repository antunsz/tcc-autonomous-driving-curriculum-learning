# %%
try:
    import mlagents
    print("ml-agents already installed")
except ImportError:
    # !python -m pip install -q mlagents==0.27.0
    print("Installed ml-agents")
# Out:
# ml-agents already installed

# %% [markdown]
# # Q-Learning Keras

# %%
import random
import tensorflow as tf
import numpy as np
import datetime
import traceback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Conv2D, Flatten, concatenate
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import Huber, LogCosh, CategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.environment import ActionTuple, BaseEnv

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Deep Q-Learning

# %%
behavior_name = 'AlphaRomeo?team=0'

# %%
num_actions = 8


def create_q_model():
    with tf.device('GPU:0'):
        
        inputs = Input(shape=(14))
        layer1 = Dense(128, activation="linear")(inputs)
        layer2 = Dense(512, activation="linear")(layer1)
        layer3 = Dense(128, activation="linear")(layer2)
        action = Dense(num_actions, activation="linear")(layer3)

        return Model(inputs=inputs, outputs=action)


model = create_q_model()

model_target = create_q_model()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 14)]              0
#
#  dense (Dense)               (None, 128)               1920
#
#  dense_1 (Dense)             (None, 512)               66048
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dense_3 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 134,664
# Trainable params: 134,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_target, show_shapes=True, show_dtype=True, show_layer_activations=True)

# %%
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = RMSprop(learning_rate=0.01, clipnorm=1.0)

# Configuration paramaters for the whole setup
gamma = 0.01  # Discount factor for past rewards
epsilon = 0.5  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
max_steps_per_episode = 10000
batch_size = 128

# Memórias de repetição de experiência
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 1000
# Number of frames for exploration
epsilon_greedy_frames = 100000
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 10000
# Train the model after 4 actions
update_after_actions = 20
# How often to update the target network
update_target_network = 100
# Using huber loss for stability
loss_function=Huber()

# %%
env = UnityEnvironment(file_name="Alpha Romeo", seed=1, side_channels=[], worker_id=1)

log_folder = 'logs/{}'.format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
writer = tf.summary.create_file_writer(log_folder)

# tf.debugging.experimental.enable_dump_debug_info(log_folder, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)

try:
    while True:  # Run until solvedloss_function
        with writer.as_default():
            env.reset()
            done = False
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            if decision_steps:
                state = decision_steps[0].obs[0]
            if terminal_steps:
                done = True                
                state = decision_steps[0].obs[0]
                         
            episode_reward = 0

            for timestep in range(1, max_steps_per_episode):
                # env.render(); Adding this line would show the attempts
                # of the agent in a pop up window.
                frame_count += 1

                # Use epsilon-greedy for exploration
                if  epsilon > np.random.rand(1)[0]:
                    # Take random action
                    action = random.choice([1,2,3,4,5,6,7,8])
                    
                else:
                    # Predict action Q-values
                    # From environment state
                    state_tensor = tf.convert_to_tensor(state)
                    state_tensor = tf.expand_dims(state_tensor, 0)
                    action_probs = model(state_tensor, training=False)
                    # Take best action
                    action = action_probs[0]
                    action = int(tf.argmax(action)+1)
                    

                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                # Apply the sampled action in our environment

                action_tuple = ActionTuple()
                action_tuple.add_discrete(np.array([[action]]))
                
                env.set_actions(behavior_name, action_tuple)
                
                env.step()

                decision_steps, terminal_steps = env.get_steps(behavior_name)

                if terminal_steps:
                    done = True
                    env.reset()
                    decision_steps, terminal_steps = env.get_steps(behavior_name)
                    state_next = decision_steps[0].obs[0]
    #                 decision_steps, terminal_steps = env.get_steps(behavior_name)
                    break

                else:
                    state_next = decision_steps[0].obs[0]

                reward = decision_steps[0].reward
        #         state_next = np.array(state_next)

                episode_reward += reward
                # Save actions and states in replay buffer
                action_history.append(action)
                state_history.append(state)
                state_next_history.append(state_next)
                done_history.append(done) 
                rewards_history.append(reward)
                state = state_next

                # Update every fourth frame and once batch size is over 32
                if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

                    # Selecionar índices aleatóriamente
                    indices = np.random.choice(range(len(done_history)), size=batch_size)

                    # Usando list comprehension para buscar os valores dos índices selecionados
                    state_sample = np.array([state_history[i] for i in indices])
                    
                    state_next_sample = np.array([state_next_history[i] for i in indices])
                    
                    rewards_sample = [rewards_history[i] for i in indices]
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor(
                        [float(done_history[i]) for i in indices]
                    )

                    # Build the updated Q-values for the sampled future states
                    # Use the target model for stability
                    state_next_sample = tf.reshape(state_next_sample, [-1, 14])
                    future_rewards = model_target.predict(np.array(state_next_sample))

                    # Q value = reward + discount factor * expected future reward
                    updated_q_values = rewards_sample + gamma * tf.reduce_max(
                        future_rewards, axis=1
                    )

                    # If final frame set the last value to -1
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values

                    masks = tf.one_hot(action_sample, num_actions)

                    with tf.GradientTape() as tape:
                        # Train the model on the states and updated Q-values
                        q_values = model(np.array(state_sample))


                        # Apply the masks to the Q-values to get the Q-value for action taken
                        q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)

                        # Calculate loss between new Q-value and old Q-value

                        loss = loss_function(updated_q_values, q_action)

                    # Backpropagation
                    grads = tape.gradient(loss, model.trainable_variables)
                    optimizer.apply_gradients(zip(grads, model.trainable_variables))

                if frame_count % update_target_network == 0:
                    # update the the target network with new weights
                    model_target.set_weights(model.get_weights())
                    # Log details
                    template = "running reward: {:.2f} at episode {}, frame count {}"
                    print(template.format(running_reward, episode_count, frame_count))
                    tf.summary.scalar(name="running reward", data=running_reward, step=episode_count)
                    tf.summary.scalar(name="reward", data=reward, step=episode_count)
                    tf.summary.scalar(name="epsilon", data=epsilon, step=episode_count)
                    tf.summary.scalar(name="frame_count", data=frame_count, step=episode_count)
                    dqn_variable = model.trainable_variables
                    tf.summary.histogram(name="dqn_variables", data=tf.convert_to_tensor(dqn_variable[0]), step=episode_count)
                    tf.summary.histogram(name="actions", data=action, step=episode_count)
                    writer.flush()
                    
            # Limit the state and reward history
            if len(rewards_history) > max_memory_length:
                del rewards_history[:1]
                del state_history[:1]
                del state_next_history[:1]
                del action_history[:1]
                del done_history[:1]

            if done:
                env.reset()
                done = False


            # Update running reward to check condition for solving
            episode_reward_history.append(episode_reward)
            if len(episode_reward_history) > 100:
                del episode_reward_history[:1]
            running_reward = np.mean(episode_reward_history)

            episode_count += 10

            if running_reward > 500000:  # Condition to consider the task solved
                print("Solved at episode {}!".format(episode_count))
                break
except:
    print(traceback.print_exc())
    writer.close()
    env.close()
# Out:
# running reward: 0.00 at episode 0, frame count 100
# running reward: -1982000.00 at episode 10, frame count 200
# running reward: -1374000.00 at episode 20, frame count 300
# running reward: -1045333.33 at episode 30, frame count 400
# running reward: -932800.00 at episode 50, frame count 500
# running reward: -932800.00 at episode 50, frame count 600
# running reward: -850857.14 at episode 70, frame count 700
# running reward: -850857.14 at episode 70, frame count 800
# running reward: -871777.78 at episode 90, frame count 900
# running reward: -853600.00 at episode 100, frame count 1000
# running reward: -856727.27 at episode 110, frame count 1100
# running reward: -836000.00 at episode 130, frame count 1200
# running reward: -836000.00 at episode 130, frame count 1300
# running reward: -908857.14 at episode 140, frame count 1400
# running reward: -937866.67 at episode 150, frame count 1500
# running reward: -933000.00 at episode 160, frame count 1600
# running reward: -932352.94 at episode 170, frame count 1700
# running reward: -932352.94 at episode 170, frame count 1800
# running reward: -931368.42 at episode 190, frame count 1900
# running reward: -931368.42 at episode 190, frame count 2000
# running reward: -924000.00 at episode 200, frame count 2100
# running reward: -960666.67 at episode 210, frame count 2200
# running reward: -960666.67 at episode 210, frame count 2300
# running reward: -1016545.45 at episode 220, frame count 2400
# running reward: -1001652.17 at episode 230, frame count 2500
# running reward: -949920.00 at episode 250, frame count 2600
# running reward: -928666.67 at episode 270, frame count 2700
# running reward: -915142.86 at episode 280, frame count 2800
# running reward: -904344.83 at episode 290, frame count 2900
# running reward: -899032.26 at episode 310, frame count 3000
# running reward: -869454.55 at episode 330, frame count 3100
# running reward: -855235.29 at episode 340, frame count 3200
# running reward: -865657.14 at episode 350, frame count 3300
# running reward: -840648.65 at episode 370, frame count 3400
# running reward: -838000.00 at episode 380, frame count 3500
# running reward: -835538.46 at episode 390, frame count 3600
# running reward: -835538.46 at episode 390, frame count 3700
# running reward: -880550.00 at episode 400, frame count 3800
# running reward: -884048.78 at episode 410, frame count 3900
# running reward: -874186.05 at episode 430, frame count 4000
# running reward: -849466.67 at episode 450, frame count 4100
# running reward: -835695.65 at episode 460, frame count 4200
# running reward: -849446.81 at episode 470, frame count 4300
# running reward: -844693.88 at episode 490, frame count 4400
# running reward: -826352.94 at episode 510, frame count 4500
# running reward: -808792.45 at episode 530, frame count 4600
# running reward: -805777.78 at episode 540, frame count 4700
# running reward: -795000.00 at episode 560, frame count 4800
# running reward: -791929.82 at episode 570, frame count 4900
# running reward: -797482.76 at episode 580, frame count 5000
# running reward: -784200.00 at episode 600, frame count 5100
# running reward: -770354.84 at episode 620, frame count 5200
# running reward: -776603.17 at episode 630, frame count 5300
# running reward: -771093.75 at episode 640, frame count 5400
# running reward: -776121.21 at episode 660, frame count 5500
# running reward: -780865.67 at episode 670, frame count 5600
# running reward: -783000.00 at episode 680, frame count 5700
# running reward: -778173.91 at episode 690, frame count 5800
# running reward: -784942.86 at episode 700, frame count 5900
# running reward: -785042.25 at episode 710, frame count 6000
# running reward: -783753.42 at episode 730, frame count 6100
# running reward: -783837.84 at episode 740, frame count 6200
# running reward: -787253.33 at episode 750, frame count 6300
# running reward: -773428.57 at episode 770, frame count 6400
# running reward: -764050.63 at episode 790, frame count 6500
# running reward: -761650.00 at episode 800, frame count 6600
# running reward: -754170.73 at episode 820, frame count 6700
# running reward: -750952.38 at episode 840, frame count 6800
# running reward: -754470.59 at episode 850, frame count 6900
# running reward: -748689.66 at episode 870, frame count 7000
# running reward: -747318.18 at episode 880, frame count 7100
# running reward: -737010.99 at episode 910, frame count 7200
# running reward: -737021.74 at episode 920, frame count 7300
# running reward: -738258.06 at episode 930, frame count 7400
# running reward: -744553.19 at episode 940, frame count 7500
# running reward: -740416.67 at episode 960, frame count 7600
# running reward: -740416.67 at episode 960, frame count 7700
# running reward: -740795.92 at episode 980, frame count 7800
# running reward: -736464.65 at episode 990, frame count 7900
# running reward: -724420.00 at episode 1010, frame count 8000
# running reward: -722280.00 at episode 1030, frame count 8100
# running reward: -713960.00 at episode 1050, frame count 8200
# running reward: -707700.00 at episode 1060, frame count 8300
# running reward: -707700.00 at episode 1060, frame count 8400
# running reward: -726740.00 at episode 1070, frame count 8500
# running reward: -723220.00 at episode 1080, frame count 8600
# running reward: -726540.00 at episode 1090, frame count 8700
# running reward: -721340.00 at episode 1110, frame count 8800
# running reward: -718900.00 at episode 1130, frame count 8900
# running reward: -710100.00 at episode 1140, frame count 9000
# running reward: -699620.00 at episode 1150, frame count 9100
# running reward: -694280.00 at episode 1170, frame count 9200
# running reward: -690600.00 at episode 1180, frame count 9300
# running reward: -691040.00 at episode 1190, frame count 9400
# running reward: -682580.00 at episode 1210, frame count 9500
# running reward: -664340.00 at episode 1230, frame count 9600
# running reward: -666520.00 at episode 1240, frame count 9700
# running reward: -668760.00 at episode 1250, frame count 9800
# running reward: -669260.00 at episode 1270, frame count 9900
# running reward: -669260.00 at episode 1270, frame count 10000
# running reward: -682560.00 at episode 1280, frame count 10100
# running reward: -685000.00 at episode 1290, frame count 10200
# running reward: -681400.00 at episode 1310, frame count 10300
# running reward: -689280.00 at episode 1320, frame count 10400
# running reward: -691100.00 at episode 1330, frame count 10500
# running reward: -688440.00 at episode 1350, frame count 10600
# running reward: -691200.00 at episode 1360, frame count 10700
# running reward: -695960.00 at episode 1370, frame count 10800
# running reward: -691140.00 at episode 1390, frame count 10900
# running reward: -665920.00 at episode 1410, frame count 11000
# running reward: -663480.00 at episode 1420, frame count 11100
# running reward: -665100.00 at episode 1430, frame count 11200
# running reward: -675260.00 at episode 1440, frame count 11300
# running reward: -685220.00 at episode 1460, frame count 11400
# running reward: -671260.00 at episode 1480, frame count 11500
# running reward: -673140.00 at episode 1490, frame count 11600
# running reward: -672760.00 at episode 1510, frame count 11700
# running reward: -678280.00 at episode 1520, frame count 11800
# running reward: -678280.00 at episode 1520, frame count 11900
# running reward: -689380.00 at episode 1530, frame count 12000
# running reward: -687240.00 at episode 1540, frame count 12100
# running reward: -691740.00 at episode 1560, frame count 12200
# running reward: -687460.00 at episode 1570, frame count 12300
# running reward: -688680.00 at episode 1580, frame count 12400
# running reward: -693740.00 at episode 1590, frame count 12500
# running reward: -702680.00 at episode 1610, frame count 12600
# running reward: -708620.00 at episode 1620, frame count 12700
# running reward: -707560.00 at episode 1630, frame count 12800
# running reward: -713420.00 at episode 1640, frame count 12900
# running reward: -711040.00 at episode 1650, frame count 13000
# running reward: -714720.00 at episode 1660, frame count 13100
# running reward: -710280.00 at episode 1670, frame count 13200
# running reward: -711320.00 at episode 1690, frame count 13300
# running reward: -707160.00 at episode 1700, frame count 13400
# running reward: -705920.00 at episode 1710, frame count 13500
# running reward: -704500.00 at episode 1730, frame count 13600
# running reward: -705940.00 at episode 1740, frame count 13700
# running reward: -698400.00 at episode 1760, frame count 13800
# running reward: -704820.00 at episode 1770, frame count 13900
# running reward: -705740.00 at episode 1780, frame count 14000
# running reward: -710260.00 at episode 1790, frame count 14100
# running reward: -715480.00 at episode 1800, frame count 14200
# running reward: -717280.00 at episode 1810, frame count 14300
# running reward: -718300.00 at episode 1830, frame count 14400
# running reward: -721220.00 at episode 1840, frame count 14500
# running reward: -723040.00 at episode 1860, frame count 14600
# running reward: -720020.00 at episode 1870, frame count 14700
# running reward: -721960.00 at episode 1880, frame count 14800
# running reward: -725520.00 at episode 1890, frame count 14900
# running reward: -725520.00 at episode 1890, frame count 15000
# running reward: -739760.00 at episode 1900, frame count 15100
# running reward: -744240.00 at episode 1910, frame count 15200
# running reward: -739820.00 at episode 1930, frame count 15300
# running reward: -729600.00 at episode 1940, frame count 15400
# running reward: -732600.00 at episode 1950, frame count 15500
# running reward: -740680.00 at episode 1960, frame count 15600
# running reward: -733400.00 at episode 1970, frame count 15700
# running reward: -744840.00 at episode 1980, frame count 15800
# running reward: -746300.00 at episode 1990, frame count 15900
# running reward: -744660.00 at episode 2010, frame count 16000
# running reward: -750440.00 at episode 2040, frame count 16200
# running reward: -753560.00 at episode 2050, frame count 16300
# running reward: -746860.00 at episode 2070, frame count 16400
# running reward: -745300.00 at episode 2080, frame count 16500
# running reward: -741800.00 at episode 2090, frame count 16600
# running reward: -743400.00 at episode 2110, frame count 16700
# running reward: -752120.00 at episode 2120, frame count 16800
# running reward: -752160.00 at episode 2130, frame count 16900
# running reward: -749060.00 at episode 2140, frame count 17000
# running reward: -756080.00 at episode 2150, frame count 17100
# running reward: -757460.00 at episode 2160, frame count 17200
# running reward: -759460.00 at episode 2170, frame count 17300
# running reward: -748040.00 at episode 2200, frame count 17400
# running reward: -748040.00 at episode 2200, frame count 17500
# running reward: -757000.00 at episode 2210, frame count 17600
# running reward: -759360.00 at episode 2230, frame count 17700
# running reward: -767520.00 at episode 2240, frame count 17800
# running reward: -764740.00 at episode 2250, frame count 17900
# running reward: -766300.00 at episode 2260, frame count 18000
# running reward: -777700.00 at episode 2270, frame count 18100
# running reward: -764080.00 at episode 2280, frame count 18200
# running reward: -766300.00 at episode 2290, frame count 18300
# running reward: -766700.00 at episode 2300, frame count 18400
# running reward: -772300.00 at episode 2310, frame count 18500
# running reward: -764000.00 at episode 2320, frame count 18600
# running reward: -765400.00 at episode 2330, frame count 18700
# running reward: -765400.00 at episode 2330, frame count 18800
# running reward: -764360.00 at episode 2350, frame count 18900
# running reward: -764740.00 at episode 2360, frame count 19000
# running reward: -758940.00 at episode 2380, frame count 19100
# running reward: -758980.00 at episode 2390, frame count 19200
# running reward: -759040.00 at episode 2400, frame count 19300
# running reward: -760740.00 at episode 2410, frame count 19400
# running reward: -762200.00 at episode 2420, frame count 19500
# running reward: -762240.00 at episode 2430, frame count 19600
# running reward: -758700.00 at episode 2440, frame count 19700
# running reward: -762820.00 at episode 2450, frame count 19800
# running reward: -767640.00 at episode 2460, frame count 19900
# running reward: -768340.00 at episode 2470, frame count 20000
# running reward: -772380.00 at episode 2480, frame count 20100
# running reward: -767760.00 at episode 2490, frame count 20200
# running reward: -767560.00 at episode 2500, frame count 20300
# running reward: -766660.00 at episode 2520, frame count 20400
# running reward: -759100.00 at episode 2530, frame count 20500
# running reward: -767320.00 at episode 2540, frame count 20600
# running reward: -761300.00 at episode 2560, frame count 20700
# running reward: -765620.00 at episode 2570, frame count 20800
# running reward: -758000.00 at episode 2580, frame count 20900
# running reward: -761660.00 at episode 2590, frame count 21000
# running reward: -755980.00 at episode 2600, frame count 21100
# running reward: -753280.00 at episode 2610, frame count 21200
# running reward: -753280.00 at episode 2610, frame count 21300
# running reward: -743180.00 at episode 2630, frame count 21400
# running reward: -736340.00 at episode 2640, frame count 21500
# running reward: -736280.00 at episode 2650, frame count 21600
# running reward: -734160.00 at episode 2660, frame count 21700
# running reward: -735000.00 at episode 2670, frame count 21800
# running reward: -736780.00 at episode 2680, frame count 21900
# running reward: -737720.00 at episode 2690, frame count 22000
# running reward: -737320.00 at episode 2700, frame count 22100
# running reward: -735820.00 at episode 2710, frame count 22200
# running reward: -734340.00 at episode 2720, frame count 22300
# running reward: -733840.00 at episode 2740, frame count 22400
# running reward: -742800.00 at episode 2750, frame count 22500
# running reward: -744020.00 at episode 2760, frame count 22600
# running reward: -747660.00 at episode 2770, frame count 22700
# running reward: -746800.00 at episode 2790, frame count 22800
# running reward: -739720.00 at episode 2800, frame count 22900
# running reward: -743020.00 at episode 2810, frame count 23000
# running reward: -742420.00 at episode 2820, frame count 23100
# running reward: -742420.00 at episode 2820, frame count 23200
# running reward: -759660.00 at episode 2830, frame count 23300
# running reward: -759660.00 at episode 2830, frame count 23400
# running reward: -773800.00 at episode 2840, frame count 23500
# running reward: -779100.00 at episode 2850, frame count 23600
# running reward: -779100.00 at episode 2850, frame count 23700
# running reward: -777000.00 at episode 2860, frame count 23800
# running reward: -785300.00 at episode 2870, frame count 23900
# running reward: -784200.00 at episode 2880, frame count 24000
# running reward: -789300.00 at episode 2890, frame count 24100
# running reward: -783040.00 at episode 2900, frame count 24200
# running reward: -783040.00 at episode 2900, frame count 24300
# running reward: -781060.00 at episode 2910, frame count 24400
# running reward: -782180.00 at episode 2930, frame count 24500
# running reward: -785860.00 at episode 2940, frame count 24600
# running reward: -777660.00 at episode 2950, frame count 24700
# running reward: -777240.00 at episode 2960, frame count 24800
# running reward: -779560.00 at episode 2970, frame count 24900
# running reward: -768780.00 at episode 2980, frame count 25000
# running reward: -768780.00 at episode 2980, frame count 25100
# running reward: -774820.00 at episode 2990, frame count 25200
# running reward: -776120.00 at episode 3000, frame count 25300
# running reward: -777460.00 at episode 3010, frame count 25400
# running reward: -784520.00 at episode 3020, frame count 25500
# running reward: -778020.00 at episode 3040, frame count 25600
# running reward: -775800.00 at episode 3050, frame count 25700
# running reward: -770380.00 at episode 3070, frame count 25800
# running reward: -767480.00 at episode 3080, frame count 25900
# running reward: -767480.00 at episode 3080, frame count 26000
# running reward: -774700.00 at episode 3100, frame count 26100
# running reward: -774700.00 at episode 3100, frame count 26200
# running reward: -775340.00 at episode 3110, frame count 26300
# running reward: -773080.00 at episode 3120, frame count 26400
# running reward: -769740.00 at episode 3140, frame count 26500
# running reward: -765160.00 at episode 3150, frame count 26600
# running reward: -757460.00 at episode 3160, frame count 26700
# running reward: -754860.00 at episode 3170, frame count 26800
# running reward: -754860.00 at episode 3170, frame count 26900
# running reward: -759800.00 at episode 3190, frame count 27000
# running reward: -764040.00 at episode 3200, frame count 27100
# running reward: -755960.00 at episode 3220, frame count 27200
# running reward: -750840.00 at episode 3230, frame count 27300
# running reward: -741380.00 at episode 3240, frame count 27400
# running reward: -742300.00 at episode 3250, frame count 27500
# running reward: -733240.00 at episode 3260, frame count 27600
# running reward: -731400.00 at episode 3270, frame count 27700
# running reward: -731260.00 at episode 3280, frame count 27800
# running reward: -728460.00 at episode 3290, frame count 27900
# running reward: -724480.00 at episode 3300, frame count 28000
# running reward: -723460.00 at episode 3310, frame count 28100
# running reward: -729320.00 at episode 3320, frame count 28200
# running reward: -729320.00 at episode 3320, frame count 28300
# running reward: -729420.00 at episode 3340, frame count 28400
# running reward: -730920.00 at episode 3350, frame count 28500
# running reward: -732160.00 at episode 3360, frame count 28600
# running reward: -736440.00 at episode 3370, frame count 28700
# running reward: -739640.00 at episode 3380, frame count 28800
# running reward: -746140.00 at episode 3390, frame count 28900
# running reward: -746220.00 at episode 3400, frame count 29000
# running reward: -742680.00 at episode 3410, frame count 29100
# running reward: -740280.00 at episode 3420, frame count 29200
# running reward: -743720.00 at episode 3430, frame count 29300
# running reward: -740240.00 at episode 3440, frame count 29400
# running reward: -736400.00 at episode 3450, frame count 29500
# running reward: -736400.00 at episode 3450, frame count 29600
# running reward: -731780.00 at episode 3460, frame count 29700
# running reward: -735740.00 at episode 3480, frame count 29800
# running reward: -743160.00 at episode 3490, frame count 29900
# running reward: -743160.00 at episode 3490, frame count 30000
# running reward: -743160.00 at episode 3490, frame count 30100
# running reward: -743160.00 at episode 3490, frame count 30200
# running reward: -743160.00 at episode 3490, frame count 30300
# running reward: -743160.00 at episode 3490, frame count 30400
# running reward: -808460.00 at episode 3510, frame count 30500
# running reward: -809740.00 at episode 3520, frame count 30600
# running reward: -808020.00 at episode 3530, frame count 30700
# running reward: -802060.00 at episode 3550, frame count 30800
# running reward: -803360.00 at episode 3560, frame count 30900
# running reward: -808820.00 at episode 3580, frame count 31000
# running reward: -808140.00 at episode 3590, frame count 31100
# running reward: -814940.00 at episode 3600, frame count 31200
# running reward: -817080.00 at episode 3610, frame count 31300
# running reward: -821500.00 at episode 3620, frame count 31400
# running reward: -825120.00 at episode 3640, frame count 31500
# running reward: -823460.00 at episode 3650, frame count 31600
# running reward: -814820.00 at episode 3670, frame count 31700
# running reward: -812800.00 at episode 3680, frame count 31800
# running reward: -812520.00 at episode 3690, frame count 31900
# running reward: -811820.00 at episode 3700, frame count 32000
# running reward: -816820.00 at episode 3710, frame count 32100
# running reward: -813500.00 at episode 3720, frame count 32200
# running reward: -813500.00 at episode 3720, frame count 32300
# running reward: -812620.00 at episode 3730, frame count 32400
# running reward: -814460.00 at episode 3740, frame count 32500
# running reward: -812460.00 at episode 3750, frame count 32600
# running reward: -820960.00 at episode 3760, frame count 32700
# running reward: -812840.00 at episode 3770, frame count 32800
# running reward: -812020.00 at episode 3780, frame count 32900
# running reward: -814620.00 at episode 3790, frame count 33000
# running reward: -821780.00 at episode 3800, frame count 33100
# running reward: -820060.00 at episode 3810, frame count 33200
# running reward: -824400.00 at episode 3820, frame count 33300
# running reward: -784140.00 at episode 3840, frame count 33400
# running reward: -772440.00 at episode 3860, frame count 33500
# running reward: -763180.00 at episode 3880, frame count 33600
# running reward: -758320.00 at episode 3890, frame count 33700
# running reward: -756440.00 at episode 3900, frame count 33800
# running reward: -747620.00 at episode 3920, frame count 33900
# running reward: -746900.00 at episode 3930, frame count 34000
# running reward: -744480.00 at episode 3950, frame count 34100
# running reward: -742240.00 at episode 3960, frame count 34200
# running reward: -742080.00 at episode 3980, frame count 34300
# running reward: -741960.00 at episode 3990, frame count 34400
# running reward: -739180.00 at episode 4000, frame count 34500
# running reward: -735900.00 at episode 4020, frame count 34600
# running reward: -741780.00 at episode 4030, frame count 34700
# running reward: -746740.00 at episode 4040, frame count 34800
# running reward: -746900.00 at episode 4070, frame count 35000
# running reward: -747140.00 at episode 4080, frame count 35100
# running reward: -744480.00 at episode 4100, frame count 35200
# running reward: -731920.00 at episode 4120, frame count 35300
# running reward: -730700.00 at episode 4140, frame count 35400
# running reward: -730840.00 at episode 4160, frame count 35500
# running reward: -732060.00 at episode 4170, frame count 35600
# running reward: -729820.00 at episode 4180, frame count 35700
# running reward: -730720.00 at episode 4200, frame count 35800
# running reward: -735800.00 at episode 4210, frame count 35900
# running reward: -734220.00 at episode 4220, frame count 36000
# running reward: -737700.00 at episode 4230, frame count 36100
# running reward: -744620.00 at episode 4250, frame count 36200
# running reward: -741400.00 at episode 4270, frame count 36300
# running reward: -741580.00 at episode 4280, frame count 36400
# running reward: -744120.00 at episode 4290, frame count 36500
# running reward: -745100.00 at episode 4300, frame count 36600
# running reward: -739900.00 at episode 4320, frame count 36700
# running reward: -740500.00 at episode 4350, frame count 36900
# running reward: -743980.00 at episode 4360, frame count 37000
# running reward: -740400.00 at episode 4370, frame count 37100
# running reward: -739720.00 at episode 4380, frame count 37200
# running reward: -735820.00 at episode 4390, frame count 37300
# running reward: -739940.00 at episode 4410, frame count 37400
# running reward: -741680.00 at episode 4420, frame count 37500
# running reward: -742180.00 at episode 4440, frame count 37600
# running reward: -741000.00 at episode 4450, frame count 37700
# running reward: -739640.00 at episode 4470, frame count 37800
# running reward: -738120.00 at episode 4480, frame count 37900
# running reward: -735040.00 at episode 4490, frame count 38000
# running reward: -670820.00 at episode 4510, frame count 38100
# running reward: -674040.00 at episode 4530, frame count 38200
# running reward: -672600.00 at episode 4540, frame count 38300
# running reward: -677520.00 at episode 4550, frame count 38400
# running reward: -680220.00 at episode 4570, frame count 38500
# running reward: -674700.00 at episode 4590, frame count 38600
# running reward: -670380.00 at episode 4600, frame count 38700
# running reward: -666720.00 at episode 4620, frame count 38800
# running reward: -664680.00 at episode 4630, frame count 38900
# running reward: -665420.00 at episode 4660, frame count 39000
# running reward: -671400.00 at episode 4670, frame count 39100
# running reward: -668080.00 at episode 4690, frame count 39200
# running reward: -670860.00 at episode 4700, frame count 39300
# running reward: -669020.00 at episode 4720, frame count 39400
# running reward: -665220.00 at episode 4730, frame count 39500
# running reward: -661720.00 at episode 4750, frame count 39600
# running reward: -657380.00 at episode 4760, frame count 39700
# running reward: -664580.00 at episode 4770, frame count 39800
# running reward: -661260.00 at episode 4790, frame count 39900
# running reward: -651580.00 at episode 4810, frame count 40000
# running reward: -652340.00 at episode 4830, frame count 40100
# running reward: -661620.00 at episode 4840, frame count 40200
# running reward: -665780.00 at episode 4850, frame count 40300
# running reward: -673240.00 at episode 4860, frame count 40400
# running reward: -676840.00 at episode 4880, frame count 40500
# running reward: -671860.00 at episode 4900, frame count 40600
# running reward: -675060.00 at episode 4920, frame count 40700
# running reward: -676440.00 at episode 4930, frame count 40800
# running reward: -681240.00 at episode 4940, frame count 40900
# running reward: -681920.00 at episode 4950, frame count 41000
# running reward: -681080.00 at episode 4970, frame count 41100
# running reward: -685280.00 at episode 4980, frame count 41200
# running reward: -681440.00 at episode 4990, frame count 41300
# running reward: -680100.00 at episode 5000, frame count 41400
# running reward: -679120.00 at episode 5020, frame count 41500
# running reward: -672560.00 at episode 5030, frame count 41600
# running reward: -669260.00 at episode 5040, frame count 41700
# running reward: -666860.00 at episode 5060, frame count 41800
# running reward: -665320.00 at episode 5070, frame count 41900
# running reward: -662580.00 at episode 5080, frame count 42000
# running reward: -663540.00 at episode 5090, frame count 42100
# running reward: -663560.00 at episode 5100, frame count 42200
# running reward: -669120.00 at episode 5110, frame count 42300
# running reward: -672720.00 at episode 5130, frame count 42400
# running reward: -668820.00 at episode 5140, frame count 42500
# running reward: -668820.00 at episode 5140, frame count 42600
# running reward: -678180.00 at episode 5160, frame count 42700
# running reward: -676520.00 at episode 5170, frame count 42800
# running reward: -677620.00 at episode 5180, frame count 42900
# running reward: -667440.00 at episode 5200, frame count 43000
# running reward: -663120.00 at episode 5210, frame count 43100
# running reward: -660980.00 at episode 5220, frame count 43200
# running reward: -658960.00 at episode 5230, frame count 43300
# running reward: -658240.00 at episode 5240, frame count 43400
# running reward: -653880.00 at episode 5250, frame count 43500
# running reward: -652820.00 at episode 5270, frame count 43600
# running reward: -655600.00 at episode 5280, frame count 43700
# running reward: -645780.00 at episode 5300, frame count 43800
# running reward: -645780.00 at episode 5300, frame count 43900
# running reward: -639720.00 at episode 5320, frame count 44000
# running reward: -641460.00 at episode 5330, frame count 44100
# running reward: -640120.00 at episode 5340, frame count 44200
# running reward: -636500.00 at episode 5360, frame count 44300
# running reward: -639360.00 at episode 5370, frame count 44400
# running reward: -635960.00 at episode 5390, frame count 44500
# running reward: -636220.00 at episode 5400, frame count 44600
# running reward: -632620.00 at episode 5420, frame count 44700
# running reward: -631340.00 at episode 5430, frame count 44800
# running reward: -622360.00 at episode 5450, frame count 44900
# running reward: -620400.00 at episode 5460, frame count 45000
# running reward: -623160.00 at episode 5480, frame count 45100
# running reward: -622660.00 at episode 5490, frame count 45200
# running reward: -619100.00 at episode 5510, frame count 45300
# running reward: -619100.00 at episode 5510, frame count 45400
# running reward: -621180.00 at episode 5530, frame count 45500
# running reward: -624420.00 at episode 5540, frame count 45600
# running reward: -620540.00 at episode 5550, frame count 45700
# running reward: -616320.00 at episode 5560, frame count 45800
# running reward: -610060.00 at episode 5580, frame count 45900
# running reward: -612680.00 at episode 5590, frame count 46000
# running reward: -616660.00 at episode 5600, frame count 46100
# running reward: -611540.00 at episode 5610, frame count 46200
# running reward: -609260.00 at episode 5620, frame count 46300
# running reward: -600700.00 at episode 5640, frame count 46400
# running reward: -604960.00 at episode 5660, frame count 46500
# running reward: -601780.00 at episode 5670, frame count 46600
# running reward: -595560.00 at episode 5680, frame count 46700
# running reward: -597820.00 at episode 5700, frame count 46800
# running reward: -597200.00 at episode 5710, frame count 46900
# running reward: -601840.00 at episode 5720, frame count 47000
# running reward: -603540.00 at episode 5740, frame count 47100
# running reward: -599240.00 at episode 5750, frame count 47200
# running reward: -594900.00 at episode 5770, frame count 47300
# running reward: -593580.00 at episode 5780, frame count 47400
# running reward: -594140.00 at episode 5790, frame count 47500
# running reward: -597040.00 at episode 5800, frame count 47600
# running reward: -593500.00 at episode 5820, frame count 47700
# running reward: -595460.00 at episode 5830, frame count 47800
# running reward: -586120.00 at episode 5840, frame count 47900
# running reward: -584360.00 at episode 5850, frame count 48000
# running reward: -577600.00 at episode 5860, frame count 48100
# running reward: -572540.00 at episode 5880, frame count 48200
# running reward: -568100.00 at episode 5890, frame count 48300
# running reward: -566460.00 at episode 5900, frame count 48400
# running reward: -565100.00 at episode 5910, frame count 48500
# running reward: -568020.00 at episode 5920, frame count 48600
# running reward: -567240.00 at episode 5930, frame count 48700
# running reward: -568920.00 at episode 5950, frame count 48800
# running reward: -567580.00 at episode 5960, frame count 48900
# running reward: -571240.00 at episode 5970, frame count 49000
# running reward: -570040.00 at episode 5980, frame count 49100
# running reward: -570880.00 at episode 5990, frame count 49200
# running reward: -568780.00 at episode 6000, frame count 49300
# running reward: -564120.00 at episode 6010, frame count 49400
# running reward: -565500.00 at episode 6020, frame count 49500
# running reward: -566640.00 at episode 6030, frame count 49600
# running reward: -565140.00 at episode 6040, frame count 49700
# running reward: -567320.00 at episode 6060, frame count 49800
# running reward: -570220.00 at episode 6070, frame count 49900
# running reward: -571040.00 at episode 6080, frame count 50000
# running reward: -571040.00 at episode 6080, frame count 50100
# running reward: -572560.00 at episode 6090, frame count 50200
# running reward: -574860.00 at episode 6100, frame count 50300
# running reward: -567660.00 at episode 6110, frame count 50400
# running reward: -563360.00 at episode 6130, frame count 50500
# running reward: -567780.00 at episode 6140, frame count 50600
# running reward: -568500.00 at episode 6150, frame count 50700
# running reward: -563300.00 at episode 6160, frame count 50800
# running reward: -562860.00 at episode 6170, frame count 50900
# running reward: -567240.00 at episode 6190, frame count 51000
# running reward: -571160.00 at episode 6200, frame count 51100
# running reward: -571960.00 at episode 6210, frame count 51200
# running reward: -574060.00 at episode 6220, frame count 51300
# running reward: -578260.00 at episode 6230, frame count 51400
# running reward: -581340.00 at episode 6240, frame count 51500
# running reward: -583120.00 at episode 6250, frame count 51600
# running reward: -581520.00 at episode 6260, frame count 51700
# running reward: -583660.00 at episode 6280, frame count 51800
# running reward: -583660.00 at episode 6280, frame count 51900
# running reward: -585080.00 at episode 6300, frame count 52000
# running reward: -584580.00 at episode 6310, frame count 52100
# running reward: -588700.00 at episode 6320, frame count 52200
# running reward: -589860.00 at episode 6330, frame count 52300
# running reward: -589240.00 at episode 6350, frame count 52400
# running reward: -580800.00 at episode 6370, frame count 52600
# running reward: -579100.00 at episode 6380, frame count 52700
# running reward: -581000.00 at episode 6390, frame count 52800
# running reward: -576980.00 at episode 6400, frame count 52900
# running reward: -576520.00 at episode 6410, frame count 53000
# running reward: -584800.00 at episode 6420, frame count 53100
# running reward: -583020.00 at episode 6430, frame count 53200
# running reward: -583600.00 at episode 6440, frame count 53300
# running reward: -590740.00 at episode 6450, frame count 53400
# running reward: -593420.00 at episode 6460, frame count 53500
# running reward: -592560.00 at episode 6470, frame count 53600
# running reward: -592560.00 at episode 6470, frame count 53700
# running reward: -595540.00 at episode 6490, frame count 53800
# running reward: -596440.00 at episode 6500, frame count 53900
# running reward: -598440.00 at episode 6510, frame count 54000
# running reward: -591320.00 at episode 6520, frame count 54100
# running reward: -595300.00 at episode 6530, frame count 54200
# running reward: -592580.00 at episode 6540, frame count 54300
# running reward: -597580.00 at episode 6550, frame count 54400
# running reward: -601440.00 at episode 6560, frame count 54500
# running reward: -604900.00 at episode 6570, frame count 54600
# running reward: -605060.00 at episode 6580, frame count 54700
# running reward: -604840.00 at episode 6590, frame count 54800
# running reward: -604040.00 at episode 6610, frame count 54900
# running reward: -605860.00 at episode 6630, frame count 55000
# running reward: -606540.00 at episode 6640, frame count 55100
# running reward: -603880.00 at episode 6660, frame count 55200
# running reward: -601000.00 at episode 6670, frame count 55300
# running reward: -605640.00 at episode 6680, frame count 55400
# running reward: -605400.00 at episode 6690, frame count 55500
# running reward: -599860.00 at episode 6700, frame count 55600
# running reward: -597220.00 at episode 6710, frame count 55700
# running reward: -586860.00 at episode 6730, frame count 55800
# running reward: -589640.00 at episode 6740, frame count 55900
# running reward: -585160.00 at episode 6760, frame count 56000
# running reward: -583740.00 at episode 6770, frame count 56100
# running reward: -581540.00 at episode 6780, frame count 56200
# running reward: -583660.00 at episode 6790, frame count 56300
# running reward: -582880.00 at episode 6800, frame count 56400
# running reward: -584180.00 at episode 6810, frame count 56500
# running reward: -585000.00 at episode 6820, frame count 56600
# running reward: -580980.00 at episode 6840, frame count 56700
# running reward: -581360.00 at episode 6860, frame count 56800
# running reward: -581920.00 at episode 6870, frame count 56900
# running reward: -583420.00 at episode 6880, frame count 57000
# running reward: -583900.00 at episode 6890, frame count 57100
# running reward: -588100.00 at episode 6900, frame count 57200
# running reward: -593100.00 at episode 6910, frame count 57300
# running reward: -593840.00 at episode 6920, frame count 57400
# running reward: -599060.00 at episode 6930, frame count 57500
# running reward: -594340.00 at episode 6940, frame count 57600
# running reward: -593460.00 at episode 6950, frame count 57700
# running reward: -599620.00 at episode 6960, frame count 57800
# running reward: -593160.00 at episode 6970, frame count 57900
# running reward: -594780.00 at episode 6980, frame count 58000
# running reward: -594260.00 at episode 6990, frame count 58100
# running reward: -601520.00 at episode 7000, frame count 58200
# running reward: -608180.00 at episode 7010, frame count 58300
# running reward: -607300.00 at episode 7020, frame count 58400
# running reward: -606820.00 at episode 7030, frame count 58500
# running reward: -606020.00 at episode 7050, frame count 58600
# running reward: -607540.00 at episode 7060, frame count 58700
# running reward: -601180.00 at episode 7080, frame count 58800
# running reward: -601520.00 at episode 7090, frame count 58900
# running reward: -601680.00 at episode 7100, frame count 59000
# running reward: -605680.00 at episode 7110, frame count 59100
# running reward: -608160.00 at episode 7130, frame count 59200
# running reward: -606240.00 at episode 7140, frame count 59300
# running reward: -600300.00 at episode 7150, frame count 59400
# running reward: -605040.00 at episode 7160, frame count 59500
# running reward: -611820.00 at episode 7170, frame count 59600
# running reward: -607420.00 at episode 7180, frame count 59700
# running reward: -609920.00 at episode 7190, frame count 59800
# running reward: -613060.00 at episode 7200, frame count 59900
# running reward: -613080.00 at episode 7220, frame count 60000
# running reward: -608660.00 at episode 7230, frame count 60100
# running reward: -603980.00 at episode 7250, frame count 60200
# running reward: -609300.00 at episode 7260, frame count 60300
# running reward: -606060.00 at episode 7280, frame count 60400
# running reward: -604900.00 at episode 7290, frame count 60500
# running reward: -604100.00 at episode 7310, frame count 60600
# running reward: -598020.00 at episode 7330, frame count 60700
# running reward: -596800.00 at episode 7340, frame count 60800
# running reward: -593280.00 at episode 7350, frame count 60900
# running reward: -597900.00 at episode 7360, frame count 61000
# running reward: -603820.00 at episode 7380, frame count 61100
# running reward: -603420.00 at episode 7390, frame count 61200
# running reward: -609760.00 at episode 7400, frame count 61300
# running reward: -613080.00 at episode 7410, frame count 61400
# running reward: -609940.00 at episode 7420, frame count 61500
# running reward: -618400.00 at episode 7430, frame count 61600
# running reward: -616440.00 at episode 7450, frame count 61800
# running reward: -612420.00 at episode 7470, frame count 61900
# running reward: -604180.00 at episode 7480, frame count 62000
# running reward: -607940.00 at episode 7500, frame count 62100
# running reward: -607720.00 at episode 7510, frame count 62200
# running reward: -604820.00 at episode 7520, frame count 62300
# running reward: -599640.00 at episode 7530, frame count 62400
# running reward: -592880.00 at episode 7550, frame count 62500
# running reward: -587940.00 at episode 7560, frame count 62600
# running reward: -583540.00 at episode 7570, frame count 62700
# running reward: -586180.00 at episode 7590, frame count 62800
# running reward: -589360.00 at episode 7600, frame count 62900
# running reward: -591320.00 at episode 7610, frame count 63000
# running reward: -595940.00 at episode 7620, frame count 63100
# running reward: -597160.00 at episode 7630, frame count 63200
# running reward: -603800.00 at episode 7660, frame count 63400
# running reward: -609860.00 at episode 7670, frame count 63500
# running reward: -603940.00 at episode 7690, frame count 63600
# running reward: -608880.00 at episode 7700, frame count 63700
# running reward: -610420.00 at episode 7710, frame count 63800
# running reward: -609860.00 at episode 7720, frame count 63900
# running reward: -609700.00 at episode 7730, frame count 64000
# running reward: -609520.00 at episode 7740, frame count 64100
# running reward: -610600.00 at episode 7750, frame count 64200
# running reward: -615620.00 at episode 7760, frame count 64300
# running reward: -611700.00 at episode 7780, frame count 64400
# running reward: -609260.00 at episode 7790, frame count 64500
# running reward: -608620.00 at episode 7810, frame count 64600
# running reward: -607180.00 at episode 7820, frame count 64700
# running reward: -609620.00 at episode 7840, frame count 64800
# running reward: -607340.00 at episode 7850, frame count 64900
# running reward: -606880.00 at episode 7860, frame count 65000
# running reward: -603980.00 at episode 7880, frame count 65100
# running reward: -601960.00 at episode 7900, frame count 65200
# running reward: -601240.00 at episode 7910, frame count 65300
# running reward: -587440.00 at episode 7930, frame count 65400
# running reward: -585440.00 at episode 7950, frame count 65500
# running reward: -578700.00 at episode 7970, frame count 65600
# running reward: -568880.00 at episode 7990, frame count 65700
# running reward: -562500.00 at episode 8000, frame count 65800
# running reward: -556800.00 at episode 8010, frame count 65900
# running reward: -562100.00 at episode 8020, frame count 66000
# running reward: -562400.00 at episode 8040, frame count 66100
# running reward: -562400.00 at episode 8040, frame count 66200
# running reward: -566440.00 at episode 8060, frame count 66300
# running reward: -571360.00 at episode 8070, frame count 66400
# running reward: -568000.00 at episode 8090, frame count 66500
# running reward: -561740.00 at episode 8110, frame count 66600
# running reward: -565500.00 at episode 8120, frame count 66700
# running reward: -568860.00 at episode 8130, frame count 66800
# running reward: -573680.00 at episode 8140, frame count 66900
# running reward: -575420.00 at episode 8150, frame count 67000
# running reward: -571480.00 at episode 8160, frame count 67100
# running reward: -565440.00 at episode 8170, frame count 67200
# running reward: -568840.00 at episode 8180, frame count 67300
# running reward: -568080.00 at episode 8190, frame count 67400
# running reward: -561680.00 at episode 8210, frame count 67500
# running reward: -562640.00 at episode 8220, frame count 67600
# running reward: -567020.00 at episode 8230, frame count 67700
# running reward: -566980.00 at episode 8240, frame count 67800
# running reward: -572640.00 at episode 8250, frame count 67900
# running reward: -566580.00 at episode 8260, frame count 68000
# running reward: -561780.00 at episode 8270, frame count 68100
# running reward: -565900.00 at episode 8290, frame count 68200
# running reward: -568900.00 at episode 8300, frame count 68300
# running reward: -572720.00 at episode 8310, frame count 68400
# running reward: -574760.00 at episode 8330, frame count 68500
# running reward: -574760.00 at episode 8330, frame count 68600
# running reward: -578060.00 at episode 8340, frame count 68700
# running reward: -582980.00 at episode 8360, frame count 68800
# running reward: -576080.00 at episode 8380, frame count 68900
# running reward: -576700.00 at episode 8390, frame count 69000
# running reward: -565880.00 at episode 8410, frame count 69100
# running reward: -564960.00 at episode 8420, frame count 69200
# running reward: -545880.00 at episode 8460, frame count 69400
# running reward: -547060.00 at episode 8470, frame count 69500
# running reward: -544040.00 at episode 8490, frame count 69600
# running reward: -544380.00 at episode 8500, frame count 69700
# running reward: -546820.00 at episode 8520, frame count 69800
# running reward: -553480.00 at episode 8530, frame count 69900
# running reward: -550540.00 at episode 8550, frame count 70000
# running reward: -550100.00 at episode 8560, frame count 70100
# running reward: -554000.00 at episode 8580, frame count 70200
# running reward: -554680.00 at episode 8590, frame count 70300
# running reward: -550600.00 at episode 8600, frame count 70400
# running reward: -545400.00 at episode 8620, frame count 70500
# running reward: -544900.00 at episode 8640, frame count 70600
# running reward: -540860.00 at episode 8650, frame count 70700
# running reward: -536420.00 at episode 8660, frame count 70800
# running reward: -531700.00 at episode 8670, frame count 70900
# running reward: -538120.00 at episode 8680, frame count 71000
# running reward: -541940.00 at episode 8690, frame count 71100
# running reward: -540180.00 at episode 8700, frame count 71200
# running reward: -539840.00 at episode 8710, frame count 71300
# running reward: -539840.00 at episode 8710, frame count 71400
# running reward: -552320.00 at episode 8730, frame count 71500
# running reward: -551100.00 at episode 8740, frame count 71600
# running reward: -552160.00 at episode 8750, frame count 71700
# running reward: -545760.00 at episode 8770, frame count 71800
# running reward: -550280.00 at episode 8780, frame count 71900
# running reward: -554660.00 at episode 8790, frame count 72000
# running reward: -553920.00 at episode 8810, frame count 72100
# running reward: -553880.00 at episode 8820, frame count 72200
# running reward: -555740.00 at episode 8840, frame count 72300
# running reward: -559140.00 at episode 8850, frame count 72400
# running reward: -560940.00 at episode 8860, frame count 72500
# running reward: -562140.00 at episode 8870, frame count 72600
# running reward: -561740.00 at episode 8890, frame count 72700
# running reward: -561260.00 at episode 8910, frame count 72800
# running reward: -564840.00 at episode 8930, frame count 72900
# running reward: -564660.00 at episode 8940, frame count 73000
# running reward: -568860.00 at episode 8950, frame count 73100
# running reward: -571600.00 at episode 8960, frame count 73200
# running reward: -572680.00 at episode 8980, frame count 73400
# running reward: -577000.00 at episode 9000, frame count 73500
# running reward: -575960.00 at episode 9020, frame count 73600
# running reward: -573500.00 at episode 9040, frame count 73700
# running reward: -567220.00 at episode 9060, frame count 73800
# running reward: -563240.00 at episode 9070, frame count 73900
# running reward: -567780.00 at episode 9080, frame count 74000
# running reward: -570020.00 at episode 9100, frame count 74100
# running reward: -572060.00 at episode 9110, frame count 74200
# running reward: -572060.00 at episode 9110, frame count 74300
# running reward: -572960.00 at episode 9130, frame count 74400
# running reward: -568300.00 at episode 9140, frame count 74500
# running reward: -571260.00 at episode 9150, frame count 74600
# running reward: -575040.00 at episode 9170, frame count 74700
# running reward: -571320.00 at episode 9180, frame count 74800
# running reward: -567980.00 at episode 9200, frame count 74900
# running reward: -563760.00 at episode 9210, frame count 75000
# running reward: -562340.00 at episode 9230, frame count 75100
# running reward: -552120.00 at episode 9250, frame count 75200
# running reward: -555120.00 at episode 9260, frame count 75300
# running reward: -551740.00 at episode 9280, frame count 75400
# running reward: -553600.00 at episode 9300, frame count 75500
# running reward: -553560.00 at episode 9310, frame count 75600
# running reward: -548180.00 at episode 9330, frame count 75700
# running reward: -541700.00 at episode 9350, frame count 75800
# running reward: -543400.00 at episode 9370, frame count 75900
# running reward: -543280.00 at episode 9380, frame count 76000
# running reward: -541080.00 at episode 9410, frame count 76100
# running reward: -536560.00 at episode 9420, frame count 76200
# running reward: -538300.00 at episode 9440, frame count 76300
# running reward: -539560.00 at episode 9470, frame count 76500
# running reward: -540280.00 at episode 9480, frame count 76600
# running reward: -539260.00 at episode 9490, frame count 76700
# running reward: -540120.00 at episode 9500, frame count 76800
# running reward: -540920.00 at episode 9510, frame count 76900
# running reward: -540700.00 at episode 9520, frame count 77000
# running reward: -539060.00 at episode 9530, frame count 77100
# running reward: -542960.00 at episode 9540, frame count 77200
# running reward: -545880.00 at episode 9550, frame count 77300
# running reward: -543940.00 at episode 9560, frame count 77400
# running reward: -538000.00 at episode 9570, frame count 77500
# running reward: -538500.00 at episode 9590, frame count 77600
# running reward: -535440.00 at episode 9600, frame count 77700
# running reward: -533060.00 at episode 9620, frame count 77800
# running reward: -533620.00 at episode 9630, frame count 77900
# running reward: -531260.00 at episode 9640, frame count 78000
# running reward: -538420.00 at episode 9660, frame count 78100
# running reward: -539960.00 at episode 9670, frame count 78200
# running reward: -535200.00 at episode 9690, frame count 78300
# running reward: -530260.00 at episode 9710, frame count 78400
# running reward: -530260.00 at episode 9710, frame count 78500
# running reward: -517360.00 at episode 9730, frame count 78600
# running reward: -517360.00 at episode 9730, frame count 78700
# running reward: -517360.00 at episode 9730, frame count 78800
# running reward: -517360.00 at episode 9730, frame count 78900
# running reward: -517360.00 at episode 9730, frame count 79000
# running reward: -517360.00 at episode 9730, frame count 79100
# running reward: -594300.00 at episode 9740, frame count 79200
# running reward: -598300.00 at episode 9750, frame count 79300
# running reward: -606320.00 at episode 9770, frame count 79400
# running reward: -603600.00 at episode 9780, frame count 79500
# running reward: -603660.00 at episode 9790, frame count 79600
# running reward: -611500.00 at episode 9800, frame count 79700
# running reward: -610880.00 at episode 9810, frame count 79800
# running reward: -610420.00 at episode 9820, frame count 79900
# running reward: -609260.00 at episode 9830, frame count 80000
# running reward: -609660.00 at episode 9840, frame count 80100
# running reward: -605780.00 at episode 9850, frame count 80200
# running reward: -605680.00 at episode 9860, frame count 80300
# running reward: -605100.00 at episode 9880, frame count 80400
# running reward: -607240.00 at episode 9890, frame count 80500
# running reward: -604480.00 at episode 9900, frame count 80600
# running reward: -605680.00 at episode 9910, frame count 80700
# running reward: -608240.00 at episode 9920, frame count 80800
# running reward: -613200.00 at episode 9940, frame count 80900
# running reward: -610160.00 at episode 9950, frame count 81000
# running reward: -608960.00 at episode 9970, frame count 81100
# running reward: -606180.00 at episode 9990, frame count 81200
# running reward: -610020.00 at episode 10000, frame count 81300
# running reward: -614400.00 at episode 10010, frame count 81400
# running reward: -608360.00 at episode 10030, frame count 81500
# running reward: -607520.00 at episode 10050, frame count 81600
# running reward: -608660.00 at episode 10060, frame count 81700
# running reward: -615480.00 at episode 10070, frame count 81800
# running reward: -611140.00 at episode 10080, frame count 81900
# running reward: -613340.00 at episode 10100, frame count 82000
# running reward: -601360.00 at episode 10120, frame count 82100
# running reward: -601620.00 at episode 10140, frame count 82200
# running reward: -601040.00 at episode 10160, frame count 82300
# running reward: -602240.00 at episode 10170, frame count 82400
# running reward: -601180.00 at episode 10180, frame count 82500
# running reward: -602020.00 at episode 10200, frame count 82600
# running reward: -604740.00 at episode 10210, frame count 82700
# running reward: -601460.00 at episode 10230, frame count 82800
# running reward: -604220.00 at episode 10250, frame count 82900
# running reward: -604220.00 at episode 10250, frame count 83000
# running reward: -609540.00 at episode 10280, frame count 83200
# running reward: -605140.00 at episode 10290, frame count 83300
# running reward: -604640.00 at episode 10310, frame count 83400
# running reward: -606240.00 at episode 10330, frame count 83500
# running reward: -607440.00 at episode 10340, frame count 83600
# running reward: -607440.00 at episode 10340, frame count 83700
# running reward: -612880.00 at episode 10350, frame count 83800
# running reward: -619700.00 at episode 10360, frame count 83900
# running reward: -615060.00 at episode 10370, frame count 84000
# running reward: -615060.00 at episode 10370, frame count 84100
# running reward: -624220.00 at episode 10400, frame count 84200
# running reward: -629720.00 at episode 10420, frame count 84300
# running reward: -634440.00 at episode 10430, frame count 84400
# running reward: -632200.00 at episode 10450, frame count 84500
# running reward: -630880.00 at episode 10470, frame count 84600
# running reward: -627800.00 at episode 10490, frame count 84700
# running reward: -624940.00 at episode 10500, frame count 84800
# running reward: -626760.00 at episode 10520, frame count 84900
# running reward: -621320.00 at episode 10540, frame count 85000
# running reward: -617700.00 at episode 10550, frame count 85100
# running reward: -618960.00 at episode 10560, frame count 85200
# running reward: -619300.00 at episode 10580, frame count 85300
# running reward: -620980.00 at episode 10590, frame count 85400
# running reward: -621620.00 at episode 10620, frame count 85500
# running reward: -623160.00 at episode 10630, frame count 85600
# running reward: -615620.00 at episode 10660, frame count 85700
# running reward: -605080.00 at episode 10680, frame count 85800
# running reward: -604480.00 at episode 10700, frame count 85900
# running reward: -610160.00 at episode 10720, frame count 86000
# running reward: -613300.00 at episode 10730, frame count 86100
# running reward: -539120.00 at episode 10740, frame count 86200
# running reward: -533200.00 at episode 10760, frame count 86300
# running reward: -536600.00 at episode 10770, frame count 86400
# running reward: -536600.00 at episode 10770, frame count 86500
# running reward: -541580.00 at episode 10780, frame count 86600
# running reward: -534620.00 at episode 10800, frame count 86700
# running reward: -534400.00 at episode 10810, frame count 86800
# running reward: -534160.00 at episode 10820, frame count 86900
# running reward: -532520.00 at episode 10840, frame count 87000
# running reward: -532520.00 at episode 10840, frame count 87100
# running reward: -538700.00 at episode 10860, frame count 87200
# running reward: -542420.00 at episode 10870, frame count 87300
# running reward: -542600.00 at episode 10890, frame count 87500
# running reward: -546740.00 at episode 10900, frame count 87600
# running reward: -546320.00 at episode 10910, frame count 87700
# running reward: -545900.00 at episode 10920, frame count 87800
# running reward: -539840.00 at episode 10940, frame count 87900
# running reward: -539420.00 at episode 10960, frame count 88000
# running reward: -534240.00 at episode 10970, frame count 88100
# running reward: -534240.00 at episode 10970, frame count 88200
# running reward: -534240.00 at episode 10970, frame count 88300
# running reward: -534240.00 at episode 10970, frame count 88400
# running reward: -534240.00 at episode 10970, frame count 88500
# running reward: -534240.00 at episode 10970, frame count 88600
# running reward: -597180.00 at episode 11000, frame count 88700
# running reward: -597160.00 at episode 11010, frame count 88800
# running reward: -602020.00 at episode 11030, frame count 88900
# running reward: -604620.00 at episode 11040, frame count 89000
# running reward: -604020.00 at episode 11050, frame count 89100
# running reward: -603220.00 at episode 11070, frame count 89200
# running reward: -604400.00 at episode 11080, frame count 89300
# running reward: -597480.00 at episode 11100, frame count 89400
# running reward: -597280.00 at episode 11110, frame count 89500
# running reward: -600140.00 at episode 11120, frame count 89600
# running reward: -604620.00 at episode 11130, frame count 89700
# running reward: -603360.00 at episode 11140, frame count 89800
# running reward: -599840.00 at episode 11150, frame count 89900
# running reward: -598580.00 at episode 11170, frame count 90000
# running reward: -602600.00 at episode 11180, frame count 90100
# running reward: -603740.00 at episode 11200, frame count 90200
# running reward: -598800.00 at episode 11220, frame count 90300
# running reward: -598560.00 at episode 11230, frame count 90400
# running reward: -601700.00 at episode 11240, frame count 90500
# running reward: -601960.00 at episode 11250, frame count 90600
# running reward: -601480.00 at episode 11260, frame count 90700
# running reward: -595600.00 at episode 11280, frame count 90800
# running reward: -600640.00 at episode 11290, frame count 90900
# running reward: -596420.00 at episode 11300, frame count 91000
# running reward: -598300.00 at episode 11320, frame count 91100
# running reward: -598300.00 at episode 11320, frame count 91200
# running reward: -599180.00 at episode 11340, frame count 91300
# running reward: -590940.00 at episode 11350, frame count 91400
# running reward: -585920.00 at episode 11360, frame count 91500
# running reward: -580420.00 at episode 11380, frame count 91600
# running reward: -585140.00 at episode 11390, frame count 91700
# running reward: -589100.00 at episode 11410, frame count 91800
# running reward: -589300.00 at episode 11420, frame count 91900
# Traceback (most recent call last):
#   File "C:\Users\carlo\AppData\Local\Temp/ipykernel_16940/2467447296.py", line 54, in <module>
#     env.step()
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\environment.py", line 333, in step
#     outputs = self._communicator.exchange(step_input, self._poll_process)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_communicator.py", line 137, in exchange
#     self.poll_for_timeout(poll_callback)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_communicator.py", line 103, in poll_for_timeout
#     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 330, in _poll
#     return bool(wait([self], timeout))
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 879, in wait
#     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 811, in _exhaustive_wait
#     res = _winapi.WaitForMultipleObjects(L, False, timeout)
# KeyboardInterrupt
# None

# %%
from collections import Counter

# %%
c = Counter(action_history)
c
# Out:
# Counter({1: 64511,
#          7: 3903,
#          2: 3601,
#          8: 3201,
#          3: 2669,
#          6: 5178,
#          4: 3214,
#          5: 3554})

# %%
c = Counter(action_history)
sum_actions = 0
d = dict(c)
for k,v in d.items():
    sum_actions += v
print("Total:", sum_actions)

for k,v in d.items():
    print(f"{k}:{v/sum_actions}")
# Out:
# Total: 89831
# 1:0.7181373913237078
# 7:0.0434482528303147
# 2:0.04008638443299084
# 8:0.03563357860872082
# 3:0.029711346862441698
# 6:0.05764157139517539
# 4:0.0357782947980096
# 5:0.03956317974863911

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
model.layers[4].get_weights()[0].shape
# Out:
# (9, 9, 128, 128)

# %%
resh = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))

# %%
# for i in 
plt.imshow(model.layers[4].get_weights()[0][:,:,127,127])

# %%
plt.imshow(state_history[0], cmap='gray')

# %%
resh.shape
# Out:
# (16384, 9, 9, 1)

# %%
plt.imshow(resh[6, :,:,:])

# %%
env.close()
