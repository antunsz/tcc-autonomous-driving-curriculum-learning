# %%
try:
    import mlagents
    print("ml-agents already installed")
except ImportError:
    # !python -m pip install -q mlagents==0.27.0
    print("Installed ml-agents")
# Out:
# ml-agents already installed

# %% [markdown]
# # Q-Learning Keras

# %%
import random
import tensorflow as tf
import numpy as np
import datetime
import traceback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Conv2D, Flatten, concatenate, MaxPooling2D, Dropout
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import Huber, LogCosh, CategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model
from collections import Counter

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.environment import ActionTuple, BaseEnv

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Deep Q-Learning

# %%
behavior_name = 'AlphaRomeo?team=0'

# %%
num_actions = 9


def create_q_model():
    #Rede conolucional
    inputs = Input(shape=(84, 84, 3,))

    layer1 = Conv2D(32, 10, strides=1, activation="relu")(inputs)
    layer2 = MaxPooling2D(pool_size=(2, 2))(layer1)
    layer3 = Conv2D(32, 12, strides=1, activation="relu")(layer2)
    layer4 = MaxPooling2D(pool_size=(2, 2))(layer3)
    layer5 = Dropout(0.5)(layer4)
    

    layer6 = Flatten()(layer5)
    conv_output = Dense(128, activation="relu")(layer6)
    conv_output_model = Model(inputs=inputs, outputs=conv_output)

    #Rede Neural
    numerical_inputs = Input(shape=(2))
    layer7 = Dense(128, activation="relu")(numerical_inputs)
    layer8 = Dense(128, activation="relu")(layer7)
    numerical_output = Dense(128, activation="linear")(layer8)

    numerical_output_model = Model(inputs=numerical_inputs, outputs=numerical_output)

    #as duas saídas combinadas
    combined = concatenate([conv_output_model.output, numerical_output_model.output])

    layer9 = Dense(128, activation="relu")(combined)
    layer10 = Dense(128, activation="relu")(layer9)

    action = Dense(num_actions, activation="linear")(layer10)

    return Model(inputs=[conv_output_model.input, numerical_output_model.input], outputs=action)


model = create_q_model()

model_target = create_q_model()

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 84, 84, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 75, 75, 32)   9632        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 37, 37, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 26, 26, 32)   147488      ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 32)  0           ['conv2d_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 2)]          0           []
#
#  dropout (Dropout)              (None, 13, 13, 32)   0           ['max_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          384         ['input_2[0][0]']
#
#  flatten (Flatten)              (None, 5408)         0           ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16512       ['dense_1[0][0]']
#
#  dense (Dense)                  (None, 128)          692352      ['flatten[0][0]']
#
#  dense_3 (Dense)                (None, 128)          16512       ['dense_2[0][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['dense[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['concatenate[0][0]']
#
#  dense_5 (Dense)                (None, 128)          16512       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 9)            1161        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 933,449
# Trainable params: 933,449
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_target, show_shapes=True, show_dtype=True, show_layer_activations=True)

# %%
#loading dos pesos e bias aprendidos na pista1
for l in range(12):
    try:
        weights_and_bias = np.load("../../../pista2/Car_AI/build/weights/"+str(model.layers[l].__class__).split(".")[-1][:-2]+"_pista2_"+str(l)+".npy", allow_pickle=True)
        model.layers[l].set_weights(weights_and_bias)
    except:
        weights = np.load("../../../pista2/Car_AI/build/weights/"+str(model.layers[l].__class__).split(".")[-1][:-2]+"_w_pista2_"+str(l)+".npy", allow_pickle=True)
        bias = np.load("../../../pista2/Car_AI/build/weights/"+str(model.layers[l].__class__).split(".")[-1][:-2]+"_b_pista2_"+str(l)+".npy", allow_pickle=True)
        weights_and_bias = [weights, bias]
        model.layers[l].set_weights(weights_and_bias)

# %%
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = RMSprop(learning_rate=0.0025, clipnorm=1.0)

# Configuration paramaters for the whole setup
gamma = 0.01  # Discount factor for past rewards
epsilon = 0.5  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
max_steps_per_episode = 10000
batch_size = 128

# Memórias de repetição de experiência
action_history = []
state_conv_history = []
state_conv_next_history = []
state_num_history = []
state_num_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 1000
# Number of frames for exploration
epsilon_greedy_frames = 100000
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 1000
# Train the model after 4 actions
update_after_actions = 20
# How often to update the target network
update_target_network = 100
# Using huber loss for stability
loss_function=Huber()

# %%
env = UnityEnvironment(file_name="Alpha Romeo", seed=1, side_channels=[], worker_id=1, no_graphics=True)

log_folder = 'logs/{}'.format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
writer = tf.summary.create_file_writer(log_folder)

# tf.debugging.experimental.enable_dump_debug_info(log_folder, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)


try:
    while True:  # Run until solvedloss_function
        with writer.as_default():
            env.reset()
            done = False
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            if decision_steps:
                state_conv = decision_steps[0].obs[0]
                state_num = decision_steps[0].obs[1]
            if terminal_steps:
                done = True                
                state_conv = decision_steps[0].obs[0]
                state_numerical = decision_steps[0].obs[1]
                continue

            episode_reward = 0

            for timestep in range(1, max_steps_per_episode):
                # env.render(); Adding this line would show the attempts
                # of the agent in a pop up window.
                frame_count += 1

                # Use epsilon-greedy for exploration
                if  epsilon > np.random.rand(1)[0]:
                    # Take random action
                    action = random.choice([1,2,3,4,5,6,7,8,9])

                else:
                    # Predict action Q-values
                    # From environment state
                    state_conv_tensor = tf.convert_to_tensor(state_conv)
                    state_num_tensor = tf.convert_to_tensor(state_num)
                    state_conv_tensor = tf.expand_dims(state_conv_tensor, 0)
                    state_num_tensor = tf.expand_dims(state_num_tensor, 0)
                    action_probs = model([state_conv_tensor, state_num_tensor], training=False)
                    # Take best action
                    action = action_probs[0]
                    action = int(tf.argmax(action)+1)


                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                # Apply the sampled action in our environment

                action_tuple = ActionTuple()
                action_tuple.add_discrete(np.array([[action]]))

                env.set_actions(behavior_name, action_tuple)

                env.step()

                decision_steps, terminal_steps = env.get_steps(behavior_name)

                if terminal_steps:
                    reward = terminal_steps[0].reward
                    state_conv_next = terminal_steps[0].obs[0]
                    state_num_next = terminal_steps[0].obs[1]
                    episode_reward += reward
                    # Save actions and states in replay buffer
                    action_history.append(action)
                    state_conv_history.append(state_conv)
                    state_num_history.append(state_num)
                    state_conv_next_history.append(state_conv_next)
                    state_num_next_history.append(state_num_next)
                    done_history.append(1) 
                    rewards_history.append(reward)
#                     env.reset()
#                     decision_steps, terminal_steps = env.get_steps(behavior_name)
#                     state_conv_next = decision_steps[0].obs[0]
#                     state_num_next = decision_steps[0].obs[1]
    #                 decision_steps, terminal_steps = env.get_steps(behavior_name)
                    
                    break

                else:
                    state_conv_next = decision_steps[0].obs[0]
                    state_num_next = decision_steps[0].obs[1]


                reward = decision_steps[0].reward
        #         state_next = np.array(state_next)

                episode_reward += reward
                # Save actions and states in replay buffer
                action_history.append(action)
                state_conv_history.append(state_conv)
                state_num_history.append(state_num)
                state_conv_next_history.append(state_conv_next)
                state_num_next_history.append(state_num_next)
                done_history.append(done) 
                rewards_history.append(reward)
                state_conv = state_conv_next
                state_num = state_num_next

                # Update every fourth frame and once batch size is over 32
                if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

                    # Selecionar índices aleatóriamente
                    indices = np.random.choice(range(len(done_history)), size=batch_size)

                    # Usando list comprehension para buscar os valores dos índices selecionados
                    state_conv_sample = np.array([state_conv_history[i] for i in indices])
                    state_num_sample = np.array([state_num_history[i] for i in indices])
                    state_conv_next_sample = np.array([state_conv_next_history[i] for i in indices])
                    state_num_next_sample = np.array([state_num_next_history[i] for i in indices])
                    rewards_sample = [rewards_history[i] for i in indices]
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor(
                        [float(done_history[i]) for i in indices]
                    )

                    # Build the updated Q-values for the sampled future states
                    # Use the target model for stability
                    state_num_next_sample = tf.reshape(state_num_next_sample, [-1, 2])
                    future_rewards = model_target.predict([np.array(state_conv_next_sample), np.array(state_num_next_sample)])

                    # Q value = reward + discount factor * expected future reward
                    updated_q_values = rewards_sample + gamma * tf.reduce_max(
                        future_rewards, axis=1
                    )

                    # If final frame set the last value to -1
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values

                    masks = tf.one_hot(action_sample, num_actions)
                    with tf.device('GPU:0'):
                        with tf.GradientTape() as tape:
                            # Train the model on the states and updated Q-values
                            q_values = model([np.array(state_conv_sample), np.array(state_num_sample)])


                            # Apply the masks to the Q-values to get the Q-value for action taken
                            q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)

                            # Calculate loss between new Q-value and old Q-value

                            loss = loss_function(updated_q_values, q_action)
                            

                        # Backpropagation
                        grads = tape.gradient(loss, model.trainable_variables)
                        optimizer.apply_gradients(zip(grads, model.trainable_variables))

                if frame_count % update_target_network == 0:
                    # update the the target network with new weights
                    model_target.set_weights(model.get_weights())
                    # Log details
                    template = "running reward: {:.2f} at episode {}, frame count {}"
                    print(template.format(running_reward, episode_count, frame_count))
                    tf.summary.scalar(name="running reward", data=running_reward, step=episode_count)
                    tf.summary.scalar(name="reward", data=reward, step=episode_count)
                    tf.summary.scalar(name="epsilon", data=epsilon, step=episode_count)
                    tf.summary.scalar(name="frame_count", data=frame_count, step=episode_count)
                    dqn_variable = model.trainable_variables
                    tf.summary.histogram(name="dqn_variables", data=tf.convert_to_tensor(dqn_variable[0]), step=episode_count)
                    tf.summary.histogram(name="actions", data=action, step=episode_count)
#                     convs = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))
#                     tf.summary.image("Training data", data=convs[:5, :, :, :], step=episode_count)
                    writer.flush()

            # Limit the state and reward history
            if len(rewards_history) > max_memory_length:
                del rewards_history[:1]
                del state_conv_history[:1]
                del state_num_history[:1]
                del state_conv_next_history[:1]
                del state_num_next_history[:1]
                del action_history[:1]
                del done_history[:1]

            if done:
                done = False
            
            env.reset()

            # Update running reward to check condition for solving
            episode_reward_history.append(episode_reward)
            if len(episode_reward_history) > 100:
                del episode_reward_history[:1]
            running_reward = np.mean(episode_reward_history)

            episode_count += 10

            if running_reward > 500000:  # Condition to consider the task solved
                print("Solved at episode {}!".format(episode_count))
                break
except:
    print(traceback.print_exc())
    writer.close()
    env.close()
# Out:
# running reward: -283.40 at episode 1980, frame count 24400
# running reward: -279.08 at episode 1990, frame count 24500
# running reward: -277.40 at episode 2000, frame count 24600
# running reward: -275.36 at episode 2010, frame count 24700
# running reward: -265.72 at episode 2030, frame count 24800
# running reward: -263.22 at episode 2040, frame count 24900
# running reward: -261.08 at episode 2050, frame count 25000
# running reward: -260.14 at episode 2060, frame count 25100
# running reward: -260.14 at episode 2060, frame count 25200
# running reward: -260.14 at episode 2060, frame count 25300
# running reward: -260.14 at episode 2060, frame count 25400
# running reward: -260.14 at episode 2060, frame count 25500
# running reward: -263.54 at episode 2070, frame count 25600
# running reward: -263.54 at episode 2070, frame count 25700
# running reward: -254.50 at episode 2090, frame count 25800
# running reward: -254.50 at episode 2090, frame count 25900
# running reward: -247.82 at episode 2110, frame count 26000
# running reward: -244.88 at episode 2120, frame count 26100
# running reward: -242.32 at episode 2130, frame count 26200
# running reward: -240.40 at episode 2140, frame count 26300
# running reward: -238.92 at episode 2150, frame count 26400
# running reward: -236.82 at episode 2160, frame count 26500
# running reward: -232.94 at episode 2170, frame count 26600
# running reward: -223.40 at episode 2190, frame count 26700
# running reward: -219.04 at episode 2200, frame count 26800
# running reward: -208.18 at episode 2210, frame count 26900
# running reward: -197.18 at episode 2220, frame count 27000
# running reward: -196.44 at episode 2230, frame count 27100
# running reward: -186.24 at episode 2250, frame count 27200
# running reward: -186.24 at episode 2250, frame count 27300
# running reward: -176.86 at episode 2260, frame count 27400
# running reward: -169.16 at episode 2280, frame count 27500
# running reward: -168.86 at episode 2290, frame count 27600
# running reward: -162.32 at episode 2310, frame count 27700
# running reward: -160.50 at episode 2320, frame count 27800
# running reward: -160.72 at episode 2330, frame count 27900
# running reward: -151.36 at episode 2350, frame count 28000
# running reward: -151.36 at episode 2350, frame count 28100
# running reward: -145.46 at episode 2370, frame count 28200
# running reward: -142.34 at episode 2380, frame count 28300
# running reward: -140.16 at episode 2390, frame count 28400
# running reward: -132.20 at episode 2410, frame count 28500
# running reward: -130.14 at episode 2420, frame count 28600
# running reward: -125.40 at episode 2440, frame count 28700
# running reward: -124.26 at episode 2450, frame count 28800
# running reward: -121.88 at episode 2460, frame count 28900
# running reward: -119.28 at episode 2470, frame count 29000
# running reward: -109.74 at episode 2490, frame count 29100
# running reward: -106.20 at episode 2500, frame count 29200
# running reward: -98.42 at episode 2510, frame count 29300
# running reward: -93.38 at episode 2530, frame count 29400
# running reward: -91.74 at episode 2540, frame count 29500
# running reward: -88.26 at episode 2550, frame count 29600
# running reward: -85.64 at episode 2560, frame count 29700
# running reward: -85.64 at episode 2560, frame count 29800
# running reward: -81.42 at episode 2570, frame count 29900
# running reward: -77.06 at episode 2580, frame count 30000
# running reward: -74.52 at episode 2590, frame count 30100
# running reward: -71.28 at episode 2600, frame count 30200
# running reward: -68.42 at episode 2610, frame count 30300
# running reward: -65.38 at episode 2630, frame count 30400
# running reward: -60.44 at episode 2640, frame count 30500
# running reward: -56.62 at episode 2650, frame count 30600
# running reward: -32.32 at episode 2670, frame count 30700
# running reward: -32.36 at episode 2680, frame count 30800
# running reward: -22.90 at episode 2700, frame count 30900
# running reward: -20.56 at episode 2710, frame count 31000
# running reward: -20.56 at episode 2710, frame count 31100
# running reward: -14.30 at episode 2720, frame count 31200
# running reward: -10.60 at episode 2730, frame count 31300
# running reward: -6.82 at episode 2740, frame count 31400
# running reward: -2.06 at episode 2750, frame count 31500
# running reward: -0.32 at episode 2760, frame count 31600
# running reward: 4.00 at episode 2770, frame count 31700
# running reward: 7.16 at episode 2780, frame count 31800
# running reward: 17.60 at episode 2800, frame count 31900
# running reward: 19.92 at episode 2810, frame count 32000
# running reward: 43.80 at episode 2830, frame count 32100
# running reward: 47.46 at episode 2840, frame count 32200
# running reward: 51.70 at episode 2860, frame count 32300
# running reward: 57.84 at episode 2880, frame count 32400
# running reward: 65.40 at episode 2900, frame count 32500
# running reward: 73.54 at episode 2920, frame count 32600
# running reward: 86.34 at episode 2960, frame count 32800
# running reward: 97.24 at episode 2990, frame count 32900
# running reward: 98.12 at episode 3000, frame count 33000
# running reward: 100.48 at episode 3020, frame count 33100
# running reward: 100.44 at episode 3030, frame count 33200
# running reward: 103.24 at episode 3050, frame count 33300
# running reward: 104.68 at episode 3060, frame count 33400
# running reward: 110.40 at episode 3070, frame count 33500
# running reward: 107.00 at episode 3090, frame count 33600
# running reward: 107.86 at episode 3100, frame count 33700
# running reward: 107.72 at episode 3110, frame count 33800
# running reward: 108.46 at episode 3120, frame count 33900
# running reward: 108.32 at episode 3130, frame count 34000
# running reward: 108.92 at episode 3140, frame count 34100
# running reward: 109.80 at episode 3150, frame count 34200
# running reward: 111.10 at episode 3160, frame count 34300
# running reward: 113.44 at episode 3170, frame count 34400
# running reward: 110.70 at episode 3180, frame count 34500
# running reward: 110.70 at episode 3180, frame count 34600
# running reward: 106.94 at episode 3190, frame count 34700
# running reward: 106.94 at episode 3190, frame count 34800
# running reward: 106.94 at episode 3190, frame count 34900
# running reward: 106.94 at episode 3190, frame count 35000
# running reward: 101.34 at episode 3200, frame count 35100
# running reward: 102.62 at episode 3220, frame count 35200
# running reward: 102.62 at episode 3220, frame count 35300
# running reward: 101.30 at episode 3240, frame count 35400
# running reward: 99.42 at episode 3250, frame count 35500
# running reward: 99.42 at episode 3250, frame count 35600
# running reward: 95.20 at episode 3270, frame count 35700
# running reward: 93.72 at episode 3280, frame count 35800
# running reward: 93.60 at episode 3300, frame count 35900
# running reward: 91.84 at episode 3310, frame count 36000
# running reward: 90.22 at episode 3320, frame count 36100
# running reward: 90.04 at episode 3330, frame count 36200
# running reward: 90.04 at episode 3330, frame count 36300
# running reward: 90.04 at episode 3330, frame count 36400
# running reward: 90.04 at episode 3330, frame count 36500
# running reward: 90.04 at episode 3330, frame count 36600
# running reward: 72.78 at episode 3340, frame count 36700
# running reward: 72.78 at episode 3340, frame count 36800
# running reward: 72.78 at episode 3340, frame count 36900
# running reward: 72.78 at episode 3340, frame count 37000
# running reward: 72.78 at episode 3340, frame count 37100
# running reward: 65.44 at episode 3350, frame count 37200
# running reward: 65.44 at episode 3350, frame count 37300
# running reward: 63.48 at episode 3360, frame count 37400
# running reward: 61.34 at episode 3370, frame count 37500
# running reward: 59.78 at episode 3380, frame count 37600
# running reward: 59.86 at episode 3390, frame count 37700
# running reward: 58.84 at episode 3410, frame count 37800
# running reward: 57.82 at episode 3420, frame count 37900
# running reward: 58.50 at episode 3430, frame count 38000
# running reward: 57.38 at episode 3440, frame count 38100
# running reward: 57.38 at episode 3440, frame count 38200
# running reward: 57.52 at episode 3450, frame count 38300
# running reward: 57.96 at episode 3460, frame count 38400
# running reward: 57.38 at episode 3470, frame count 38500
# running reward: 58.56 at episode 3480, frame count 38600
# running reward: 60.66 at episode 3490, frame count 38700
# running reward: 61.60 at episode 3500, frame count 38800
# running reward: 61.68 at episode 3510, frame count 38900
# running reward: 65.48 at episode 3530, frame count 39000
# running reward: 67.00 at episode 3540, frame count 39100
# running reward: 69.66 at episode 3560, frame count 39200
# running reward: 69.60 at episode 3570, frame count 39300
# running reward: 68.42 at episode 3580, frame count 39400
# running reward: 68.42 at episode 3580, frame count 39500
# running reward: 64.98 at episode 3600, frame count 39600
# running reward: 64.98 at episode 3600, frame count 39700
# running reward: 69.90 at episode 3610, frame count 39800
# running reward: 73.20 at episode 3620, frame count 39900
# running reward: 73.84 at episode 3640, frame count 40000
# running reward: 73.20 at episode 3650, frame count 40100
# running reward: 73.24 at episode 3660, frame count 40200
# running reward: 71.06 at episode 3670, frame count 40300
# running reward: 70.46 at episode 3680, frame count 40400
# running reward: 70.46 at episode 3680, frame count 40500
# running reward: 70.46 at episode 3680, frame count 40600
# running reward: 68.88 at episode 3690, frame count 40700
# running reward: 71.54 at episode 3700, frame count 40800
# running reward: 71.54 at episode 3700, frame count 40900
# running reward: 71.54 at episode 3700, frame count 41000
# running reward: 71.54 at episode 3700, frame count 41100
# running reward: 66.22 at episode 3710, frame count 41200
# running reward: 66.22 at episode 3710, frame count 41300
# running reward: 66.22 at episode 3710, frame count 41400
# running reward: 66.22 at episode 3710, frame count 41500
# running reward: 60.40 at episode 3720, frame count 41600
# running reward: 58.38 at episode 3730, frame count 41700
# running reward: 60.42 at episode 3740, frame count 41800
# running reward: 60.42 at episode 3740, frame count 41900
# running reward: 60.42 at episode 3740, frame count 42000
# running reward: 53.10 at episode 3760, frame count 42100
# running reward: 50.78 at episode 3770, frame count 42200
# running reward: 50.58 at episode 3780, frame count 42300
# running reward: 49.66 at episode 3790, frame count 42400
# running reward: 53.04 at episode 3800, frame count 42500
# running reward: 55.00 at episode 3810, frame count 42600
# running reward: 55.58 at episode 3820, frame count 42700
# running reward: 55.58 at episode 3820, frame count 42800
# running reward: 55.58 at episode 3820, frame count 42900
# running reward: 54.86 at episode 3830, frame count 43000
# running reward: 58.12 at episode 3840, frame count 43100
# running reward: 62.14 at episode 3850, frame count 43200
# running reward: 62.14 at episode 3850, frame count 43300
# running reward: 62.14 at episode 3850, frame count 43400
# running reward: 62.14 at episode 3850, frame count 43500
# running reward: 65.76 at episode 3860, frame count 43600
# running reward: 63.94 at episode 3880, frame count 43700
# running reward: 65.28 at episode 3900, frame count 43800
# running reward: 66.22 at episode 3920, frame count 43900
# running reward: 66.54 at episode 3930, frame count 44000
# running reward: 65.76 at episode 3950, frame count 44100
# running reward: 65.70 at episode 3960, frame count 44200
# running reward: 64.32 at episode 3970, frame count 44300
# running reward: 61.74 at episode 3990, frame count 44400
# running reward: 61.14 at episode 4000, frame count 44500
# running reward: 59.16 at episode 4020, frame count 44600
# running reward: 59.20 at episode 4030, frame count 44700
# running reward: 57.54 at episode 4050, frame count 44800
# running reward: 56.14 at episode 4060, frame count 44900
# running reward: 55.46 at episode 4070, frame count 45000
# running reward: 57.18 at episode 4080, frame count 45100
# running reward: 58.14 at episode 4090, frame count 45200
# running reward: 58.72 at episode 4100, frame count 45300
# running reward: 58.72 at episode 4100, frame count 45400
# running reward: 60.34 at episode 4120, frame count 45500
# running reward: 60.34 at episode 4120, frame count 45600
# running reward: 61.26 at episode 4140, frame count 45700
# running reward: 60.74 at episode 4150, frame count 45800
# running reward: 60.32 at episode 4170, frame count 45900
# running reward: 60.32 at episode 4170, frame count 46000
# running reward: 68.46 at episode 4190, frame count 46100
# running reward: 72.68 at episode 4200, frame count 46300
# running reward: 72.68 at episode 4200, frame count 46400
# running reward: 67.54 at episode 4210, frame count 46500
# running reward: 70.72 at episode 4230, frame count 46600
# running reward: 70.44 at episode 4240, frame count 46700
# running reward: 71.42 at episode 4250, frame count 46800
# running reward: 71.42 at episode 4250, frame count 46900
# running reward: 71.42 at episode 4250, frame count 47000
# running reward: 71.42 at episode 4250, frame count 47100
# running reward: 67.66 at episode 4270, frame count 47200
# running reward: 67.66 at episode 4270, frame count 47300
# running reward: 65.90 at episode 4280, frame count 47400
# running reward: 66.56 at episode 4300, frame count 47500
# running reward: 67.26 at episode 4310, frame count 47600
# running reward: 67.10 at episode 4330, frame count 47700
# running reward: 91.24 at episode 4350, frame count 47800
# running reward: 92.20 at episode 4360, frame count 47900
# running reward: 95.56 at episode 4380, frame count 48000
# running reward: 95.56 at episode 4380, frame count 48100
# running reward: 98.58 at episode 4400, frame count 48200
# running reward: 98.34 at episode 4410, frame count 48300
# running reward: 97.70 at episode 4420, frame count 48400
# running reward: 102.58 at episode 4450, frame count 48500
# running reward: 102.58 at episode 4450, frame count 48600
# running reward: 102.58 at episode 4450, frame count 48700
# running reward: 98.70 at episode 4460, frame count 48800
# running reward: 98.70 at episode 4460, frame count 48900
# running reward: 101.88 at episode 4470, frame count 49000
# running reward: 101.84 at episode 4480, frame count 49100
# running reward: 100.10 at episode 4500, frame count 49200
# running reward: 99.32 at episode 4520, frame count 49300
# running reward: 101.22 at episode 4530, frame count 49400
# running reward: 100.64 at episode 4560, frame count 49500
# running reward: 102.90 at episode 4580, frame count 49600
# running reward: 102.90 at episode 4580, frame count 49700
# running reward: 102.32 at episode 4600, frame count 49800
# running reward: 96.06 at episode 4610, frame count 49900
# running reward: 93.22 at episode 4620, frame count 50000
# running reward: 93.22 at episode 4620, frame count 50100
# running reward: 93.22 at episode 4620, frame count 50200
# running reward: 90.56 at episode 4630, frame count 50300
# running reward: 90.56 at episode 4630, frame count 50400
# running reward: 88.98 at episode 4640, frame count 50500
# running reward: 88.88 at episode 4650, frame count 50600
# running reward: 88.66 at episode 4660, frame count 50700
# running reward: 90.08 at episode 4670, frame count 50800
# running reward: 90.08 at episode 4670, frame count 50900
# running reward: 90.08 at episode 4670, frame count 51000
# running reward: 90.08 at episode 4670, frame count 51100
# running reward: 90.08 at episode 4670, frame count 51200
# running reward: 90.08 at episode 4670, frame count 51300
# running reward: 79.52 at episode 4680, frame count 51400
# running reward: 79.86 at episode 4690, frame count 51500
# running reward: 84.80 at episode 4710, frame count 51600
# running reward: 88.38 at episode 4720, frame count 51700
# running reward: 87.76 at episode 4740, frame count 51800
# running reward: 93.98 at episode 4750, frame count 51900
# running reward: 93.30 at episode 4760, frame count 52000
# running reward: 95.10 at episode 4780, frame count 52100
# running reward: 95.74 at episode 4790, frame count 52200
# running reward: 91.76 at episode 4810, frame count 52300
# running reward: 91.76 at episode 4810, frame count 52400
# running reward: 91.76 at episode 4810, frame count 52500
# running reward: 91.76 at episode 4810, frame count 52600
# running reward: 91.76 at episode 4810, frame count 52700
# running reward: 91.76 at episode 4810, frame count 52800
# running reward: 74.30 at episode 4820, frame count 52900
# running reward: 75.48 at episode 4830, frame count 53000
# running reward: 72.08 at episode 4840, frame count 53100
# running reward: 64.68 at episode 4860, frame count 53200
# running reward: 65.46 at episode 4870, frame count 53300
# running reward: 65.30 at episode 4890, frame count 53400
# running reward: 64.68 at episode 4900, frame count 53500
# running reward: 63.64 at episode 4920, frame count 53600
# running reward: 63.98 at episode 4940, frame count 53700
# running reward: 65.10 at episode 4950, frame count 53800
# running reward: 65.84 at episode 4970, frame count 53900
# running reward: 67.56 at episode 4980, frame count 54000
# running reward: 69.52 at episode 5000, frame count 54100
# running reward: 70.46 at episode 5020, frame count 54200
# running reward: 71.10 at episode 5030, frame count 54300
# running reward: 71.10 at episode 5030, frame count 54400
# running reward: 66.70 at episode 5040, frame count 54500
# running reward: 68.36 at episode 5050, frame count 54600
# running reward: 68.36 at episode 5050, frame count 54700
# running reward: 68.36 at episode 5050, frame count 54800
# running reward: 68.36 at episode 5050, frame count 54900
# running reward: 68.36 at episode 5050, frame count 55000
# running reward: 54.36 at episode 5060, frame count 55100
# running reward: 54.36 at episode 5060, frame count 55200
# running reward: 54.36 at episode 5060, frame count 55300
# running reward: 48.86 at episode 5070, frame count 55400
# running reward: 48.88 at episode 5080, frame count 55500
# running reward: 48.58 at episode 5090, frame count 55600
# running reward: 48.26 at episode 5100, frame count 55700
# running reward: 48.26 at episode 5100, frame count 55800
# running reward: 41.18 at episode 5110, frame count 55900
# running reward: 40.36 at episode 5120, frame count 56000
# running reward: 40.36 at episode 5120, frame count 56100
# running reward: 39.58 at episode 5140, frame count 56200
# running reward: 39.58 at episode 5140, frame count 56300
# running reward: 39.58 at episode 5140, frame count 56400
# running reward: 34.28 at episode 5150, frame count 56500
# running reward: 34.28 at episode 5150, frame count 56600
# running reward: 29.70 at episode 5160, frame count 56700
# running reward: 25.64 at episode 5170, frame count 56800
# running reward: 25.56 at episode 5180, frame count 56900
# running reward: 23.76 at episode 5190, frame count 57000
# running reward: 31.38 at episode 5210, frame count 57100
# running reward: 31.08 at episode 5220, frame count 57200
# running reward: 29.96 at episode 5230, frame count 57300
# running reward: 30.38 at episode 5240, frame count 57400
# running reward: 30.38 at episode 5240, frame count 57500
# running reward: 30.38 at episode 5240, frame count 57600
# running reward: 30.38 at episode 5240, frame count 57700
# running reward: 30.38 at episode 5240, frame count 57800
# running reward: 30.38 at episode 5240, frame count 57900
# running reward: 15.08 at episode 5250, frame count 58000
# running reward: 20.86 at episode 5260, frame count 58100
# running reward: 23.06 at episode 5280, frame count 58200
# running reward: 24.98 at episode 5290, frame count 58300
# running reward: 24.96 at episode 5310, frame count 58400
# running reward: 24.96 at episode 5310, frame count 58500
# running reward: 24.30 at episode 5320, frame count 58600
# running reward: 24.30 at episode 5320, frame count 58700
# running reward: 24.30 at episode 5320, frame count 58800
# running reward: 24.30 at episode 5320, frame count 58900
# running reward: 24.30 at episode 5320, frame count 59000
# running reward: 24.30 at episode 5320, frame count 59100
# running reward: 24.30 at episode 5320, frame count 59200
# running reward: 11.26 at episode 5330, frame count 59300
# running reward: 11.78 at episode 5340, frame count 59400
# running reward: 13.38 at episode 5350, frame count 59500
# running reward: 14.68 at episode 5370, frame count 59600
# running reward: 13.26 at episode 5390, frame count 59700
# running reward: 13.76 at episode 5400, frame count 59800
# running reward: 12.60 at episode 5410, frame count 59900
# running reward: 12.60 at episode 5410, frame count 60000
# running reward: 10.06 at episode 5430, frame count 60100
# running reward: 9.80 at episode 5440, frame count 60200
# running reward: 14.18 at episode 5470, frame count 60400
# running reward: 17.66 at episode 5480, frame count 60500
# running reward: 19.46 at episode 5490, frame count 60600
# running reward: 20.50 at episode 5500, frame count 60700
# running reward: 23.82 at episode 5520, frame count 60800
# running reward: 22.86 at episode 5530, frame count 60900
# running reward: 23.48 at episode 5560, frame count 61000
# running reward: 22.98 at episode 5580, frame count 61100
# running reward: 22.98 at episode 5580, frame count 61200
# running reward: 22.98 at episode 5580, frame count 61300
# running reward: 22.98 at episode 5580, frame count 61400
# running reward: 22.98 at episode 5580, frame count 61500
# running reward: 7.72 at episode 5590, frame count 61600
# running reward: 9.14 at episode 5600, frame count 61700
# running reward: 9.14 at episode 5600, frame count 61800
# running reward: 10.46 at episode 5620, frame count 61900
# running reward: 13.12 at episode 5630, frame count 62000
# running reward: 16.78 at episode 5650, frame count 62100
# running reward: 16.72 at episode 5660, frame count 62200
# running reward: 16.72 at episode 5660, frame count 62300
# running reward: 16.72 at episode 5660, frame count 62400
# running reward: 16.72 at episode 5660, frame count 62500
# running reward: 16.72 at episode 5660, frame count 62600
# running reward: 16.72 at episode 5660, frame count 62700
# running reward: -1.66 at episode 5670, frame count 62800
# running reward: 13.34 at episode 5680, frame count 62900
# running reward: 15.36 at episode 5690, frame count 63000
# running reward: 15.22 at episode 5700, frame count 63100
# running reward: 16.20 at episode 5720, frame count 63200
# running reward: 18.34 at episode 5740, frame count 63300
# running reward: 19.30 at episode 5760, frame count 63400
# running reward: 18.72 at episode 5770, frame count 63500
# running reward: 18.72 at episode 5770, frame count 63600
# running reward: 18.72 at episode 5770, frame count 63700
# running reward: 18.72 at episode 5770, frame count 63800
# running reward: 18.72 at episode 5770, frame count 63900
# running reward: 18.72 at episode 5770, frame count 64000
# running reward: 0.24 at episode 5790, frame count 64100
# running reward: 3.12 at episode 5810, frame count 64200
# running reward: 21.66 at episode 5820, frame count 64300
# running reward: 19.90 at episode 5830, frame count 64400
# running reward: 19.90 at episode 5830, frame count 64500
# running reward: 21.18 at episode 5850, frame count 64600
# running reward: 20.92 at episode 5860, frame count 64700
# running reward: 18.78 at episode 5870, frame count 64800
# running reward: 17.96 at episode 5880, frame count 64900
# running reward: 17.96 at episode 5880, frame count 65000
# running reward: 17.96 at episode 5880, frame count 65100
# running reward: 17.96 at episode 5880, frame count 65200
# running reward: 17.96 at episode 5880, frame count 65300
# running reward: 17.96 at episode 5880, frame count 65400
# running reward: -0.28 at episode 5890, frame count 65500
# running reward: -0.28 at episode 5890, frame count 65600
# running reward: -0.28 at episode 5890, frame count 65700
# running reward: -0.28 at episode 5890, frame count 65800
# running reward: -0.28 at episode 5890, frame count 65900
# running reward: -18.06 at episode 5900, frame count 66000
# running reward: -18.58 at episode 5920, frame count 66100
# running reward: -16.96 at episode 5930, frame count 66200
# running reward: -16.96 at episode 5930, frame count 66300
# running reward: -16.96 at episode 5930, frame count 66400
# running reward: -16.96 at episode 5930, frame count 66500
# running reward: -16.96 at episode 5930, frame count 66600
# running reward: -36.32 at episode 5940, frame count 66700
# running reward: -36.32 at episode 5940, frame count 66800
# running reward: -36.82 at episode 5960, frame count 66900
# running reward: -37.86 at episode 5970, frame count 67000
# running reward: -38.42 at episode 5990, frame count 67100
# running reward: -36.46 at episode 6000, frame count 67200
# running reward: -35.46 at episode 6010, frame count 67300
# running reward: -35.70 at episode 6020, frame count 67400
# running reward: -35.18 at episode 6030, frame count 67500
# running reward: -32.02 at episode 6050, frame count 67600
# running reward: -32.02 at episode 6050, frame count 67700
# running reward: -32.02 at episode 6050, frame count 67800
# running reward: -32.02 at episode 6050, frame count 67900
# running reward: -25.48 at episode 6060, frame count 68000
# running reward: -17.42 at episode 6080, frame count 68100
# running reward: -17.30 at episode 6090, frame count 68200
# running reward: -10.80 at episode 6110, frame count 68300
# running reward: -9.48 at episode 6120, frame count 68400
# running reward: -9.48 at episode 6120, frame count 68500
# running reward: -10.54 at episode 6130, frame count 68600
# running reward: -13.14 at episode 6140, frame count 68700
# running reward: -13.14 at episode 6140, frame count 68800
# running reward: -13.14 at episode 6140, frame count 68900
# running reward: -14.44 at episode 6150, frame count 69000
# running reward: -14.44 at episode 6150, frame count 69100
# running reward: -14.44 at episode 6150, frame count 69200
# running reward: -14.44 at episode 6150, frame count 69300
# running reward: -14.44 at episode 6150, frame count 69400
# running reward: -14.44 at episode 6150, frame count 69500
# running reward: -14.44 at episode 6150, frame count 69600
# running reward: -24.06 at episode 6160, frame count 69700
# running reward: -24.06 at episode 6160, frame count 69800
# running reward: -24.06 at episode 6160, frame count 69900
# running reward: -24.06 at episode 6160, frame count 70000
# running reward: -25.96 at episode 6170, frame count 70100
# running reward: -23.64 at episode 6190, frame count 70200
# running reward: -23.14 at episode 6210, frame count 70300
# running reward: -23.14 at episode 6210, frame count 70400
# running reward: -24.96 at episode 6230, frame count 70500
# running reward: -23.82 at episode 6240, frame count 70600
# running reward: -8.52 at episode 6270, frame count 70700
# running reward: -8.54 at episode 6280, frame count 70800
# running reward: -7.14 at episode 6300, frame count 70900
# running reward: -6.68 at episode 6310, frame count 71000
# running reward: -5.92 at episode 6320, frame count 71100
# running reward: 9.48 at episode 6330, frame count 71200
# running reward: 9.48 at episode 6330, frame count 71300
# running reward: 6.08 at episode 6340, frame count 71400
# running reward: 2.64 at episode 6350, frame count 71500
# running reward: 3.46 at episode 6360, frame count 71600
# running reward: 5.60 at episode 6380, frame count 71700
# running reward: 6.32 at episode 6390, frame count 71800
# running reward: 6.98 at episode 6400, frame count 71900
# running reward: 6.98 at episode 6400, frame count 72000
# running reward: 6.58 at episode 6410, frame count 72100
# running reward: 12.72 at episode 6430, frame count 72200
# running reward: 12.94 at episode 6440, frame count 72300
# running reward: 9.86 at episode 6460, frame count 72400
# running reward: 10.14 at episode 6470, frame count 72500
# running reward: 6.18 at episode 6480, frame count 72600
# running reward: 3.38 at episode 6500, frame count 72700
# running reward: -2.38 at episode 6520, frame count 72800
# running reward: -3.38 at episode 6530, frame count 72900
# running reward: -5.30 at episode 6550, frame count 73000
# running reward: -6.62 at episode 6560, frame count 73100
# running reward: -8.26 at episode 6580, frame count 73200
# running reward: 9.58 at episode 6590, frame count 73300
# running reward: 7.82 at episode 6610, frame count 73400
# running reward: 7.20 at episode 6630, frame count 73500
# running reward: 6.58 at episode 6640, frame count 73600
# running reward: 5.74 at episode 6660, frame count 73700
# running reward: 24.30 at episode 6670, frame count 73800
# running reward: 21.64 at episode 6690, frame count 73900
# running reward: 21.64 at episode 6690, frame count 74000
# running reward: 19.86 at episode 6710, frame count 74100
# running reward: 19.44 at episode 6730, frame count 74200
# running reward: 19.44 at episode 6730, frame count 74300
# running reward: 19.44 at episode 6730, frame count 74400
# running reward: 15.08 at episode 6740, frame count 74500
# running reward: 19.38 at episode 6750, frame count 74600
# running reward: 19.38 at episode 6750, frame count 74700
# running reward: 14.08 at episode 6760, frame count 74800
# running reward: 15.34 at episode 6770, frame count 74900
# running reward: 33.44 at episode 6800, frame count 75000
# running reward: 31.46 at episode 6820, frame count 75100
# running reward: 31.46 at episode 6820, frame count 75200
# running reward: 31.46 at episode 6820, frame count 75300
# running reward: 31.46 at episode 6820, frame count 75400
# running reward: 27.74 at episode 6840, frame count 75500
# running reward: 27.30 at episode 6850, frame count 75600
# running reward: 25.52 at episode 6860, frame count 75700
# running reward: 25.52 at episode 6860, frame count 75800
# running reward: 28.24 at episode 6880, frame count 75900
# running reward: 28.24 at episode 6880, frame count 76000
# running reward: 47.58 at episode 6890, frame count 76100
# running reward: 47.58 at episode 6890, frame count 76200
# running reward: 47.58 at episode 6890, frame count 76300
# running reward: 60.50 at episode 6900, frame count 76400
# running reward: 60.16 at episode 6920, frame count 76500
# running reward: 58.60 at episode 6930, frame count 76600
# running reward: 76.60 at episode 6940, frame count 76700
# running reward: 74.92 at episode 6960, frame count 76800
# running reward: 74.90 at episode 6980, frame count 76900
# running reward: 73.20 at episode 7000, frame count 77000
# running reward: 71.86 at episode 7010, frame count 77100
# running reward: 70.90 at episode 7040, frame count 77300
# running reward: 78.28 at episode 7060, frame count 77400
# running reward: 75.90 at episode 7070, frame count 77500
# running reward: 74.14 at episode 7080, frame count 77600
# running reward: 74.02 at episode 7090, frame count 77700
# running reward: 71.68 at episode 7110, frame count 77800
# running reward: 71.68 at episode 7110, frame count 77900
# running reward: 74.16 at episode 7130, frame count 78000
# running reward: 83.48 at episode 7150, frame count 78100
# running reward: 95.58 at episode 7160, frame count 78200
# running reward: 100.24 at episode 7190, frame count 78300
# running reward: 99.84 at episode 7200, frame count 78400
# running reward: 100.18 at episode 7210, frame count 78500
# running reward: 100.18 at episode 7210, frame count 78600
# running reward: 100.18 at episode 7210, frame count 78700
# running reward: 100.18 at episode 7210, frame count 78800
# running reward: 100.18 at episode 7210, frame count 78900
# running reward: 100.18 at episode 7210, frame count 79000
# running reward: 100.18 at episode 7210, frame count 79100
# running reward: 89.80 at episode 7220, frame count 79200
# running reward: 89.56 at episode 7240, frame count 79300
# running reward: 90.00 at episode 7250, frame count 79400
# running reward: 89.58 at episode 7260, frame count 79500
# running reward: 90.68 at episode 7270, frame count 79600
# running reward: 92.30 at episode 7280, frame count 79700
# running reward: 92.30 at episode 7280, frame count 79800
# running reward: 92.30 at episode 7280, frame count 79900
# running reward: 83.56 at episode 7290, frame count 80000
# running reward: 82.28 at episode 7300, frame count 80200
# running reward: 84.10 at episode 7310, frame count 80300
# running reward: 86.54 at episode 7320, frame count 80400
# running reward: 86.12 at episode 7330, frame count 80500
# running reward: 86.12 at episode 7330, frame count 80600
# running reward: 89.12 at episode 7350, frame count 80700
# running reward: 87.00 at episode 7370, frame count 80800
# running reward: 86.36 at episode 7380, frame count 80900
# running reward: 85.20 at episode 7390, frame count 81000
# running reward: 84.96 at episode 7400, frame count 81100
# running reward: 89.10 at episode 7410, frame count 81200
# running reward: 87.72 at episode 7420, frame count 81300
# running reward: 87.00 at episode 7440, frame count 81400
# running reward: 88.94 at episode 7460, frame count 81500
# running reward: 88.66 at episode 7470, frame count 81600
# running reward: 91.26 at episode 7480, frame count 81700
# running reward: 92.12 at episode 7500, frame count 81800
# running reward: 93.02 at episode 7510, frame count 81900
# running reward: 93.86 at episode 7520, frame count 82000
# running reward: 98.66 at episode 7530, frame count 82100
# running reward: 100.30 at episode 7540, frame count 82200
# running reward: 100.14 at episode 7550, frame count 82300
# running reward: 100.14 at episode 7550, frame count 82400
# running reward: 98.04 at episode 7560, frame count 82500
# running reward: 98.04 at episode 7560, frame count 82600
# running reward: 98.04 at episode 7560, frame count 82700
# running reward: 93.32 at episode 7570, frame count 82800
# running reward: 96.56 at episode 7590, frame count 82900
# running reward: 99.24 at episode 7620, frame count 83100
# running reward: 99.68 at episode 7640, frame count 83300
# running reward: 99.68 at episode 7640, frame count 83400
# running reward: 96.00 at episode 7660, frame count 83500
# running reward: 95.74 at episode 7680, frame count 83600
# running reward: 95.98 at episode 7690, frame count 83700
# running reward: 96.04 at episode 7710, frame count 83800
# running reward: 95.00 at episode 7720, frame count 83900
# running reward: 93.76 at episode 7730, frame count 84000
# running reward: 96.54 at episode 7740, frame count 84100
# running reward: 95.12 at episode 7760, frame count 84200
# running reward: 97.12 at episode 7770, frame count 84300
# running reward: 95.56 at episode 7780, frame count 84400
# running reward: 95.56 at episode 7780, frame count 84500
# running reward: 98.84 at episode 7790, frame count 84600
# running reward: 98.84 at episode 7790, frame count 84700
# running reward: 98.84 at episode 7790, frame count 84800
# running reward: 89.90 at episode 7800, frame count 84900
# running reward: 89.72 at episode 7810, frame count 85000
# running reward: 99.08 at episode 7830, frame count 85100
# running reward: 98.18 at episode 7850, frame count 85200
# running reward: 100.18 at episode 7860, frame count 85300
# running reward: 99.40 at episode 7870, frame count 85400
# running reward: 99.40 at episode 7870, frame count 85500
# running reward: 97.10 at episode 7890, frame count 85600
# running reward: 103.96 at episode 7910, frame count 85700
# running reward: 104.30 at episode 7920, frame count 85800
# running reward: 104.10 at episode 7930, frame count 85900
# running reward: 104.74 at episode 7940, frame count 86000
# running reward: 107.08 at episode 7950, frame count 86100
# running reward: 106.72 at episode 7960, frame count 86200
# running reward: 105.80 at episode 7970, frame count 86300
# running reward: 105.80 at episode 7970, frame count 86400
# running reward: 103.16 at episode 7990, frame count 86500
# running reward: 103.68 at episode 8000, frame count 86600
# running reward: 104.52 at episode 8020, frame count 86700
# running reward: 103.78 at episode 8030, frame count 86800
# running reward: 102.80 at episode 8050, frame count 86900
# running reward: 102.30 at episode 8060, frame count 87000
# running reward: 104.26 at episode 8080, frame count 87100
# running reward: 106.28 at episode 8100, frame count 87200
# running reward: 106.28 at episode 8100, frame count 87300
# running reward: 105.86 at episode 8130, frame count 87400
# running reward: 105.20 at episode 8140, frame count 87500
# running reward: 103.38 at episode 8150, frame count 87600
# running reward: 105.10 at episode 8160, frame count 87700
# running reward: 102.48 at episode 8180, frame count 87800
# running reward: 102.76 at episode 8190, frame count 87900
# running reward: 103.10 at episode 8210, frame count 88000
# running reward: 114.00 at episode 8240, frame count 88200
# running reward: 114.00 at episode 8240, frame count 88300
# running reward: 112.06 at episode 8260, frame count 88400
# running reward: 112.06 at episode 8260, frame count 88500
# running reward: 112.06 at episode 8260, frame count 88600
# running reward: 112.06 at episode 8260, frame count 88700
# running reward: 103.92 at episode 8280, frame count 88800
# running reward: 103.92 at episode 8280, frame count 88900
# running reward: 109.02 at episode 8290, frame count 89000
# running reward: 109.02 at episode 8290, frame count 89100
# running reward: 110.62 at episode 8310, frame count 89200
# running reward: 107.78 at episode 8330, frame count 89300
# running reward: 109.74 at episode 8340, frame count 89400
# running reward: 108.74 at episode 8350, frame count 89500
# running reward: 108.58 at episode 8370, frame count 89600
# running reward: 110.50 at episode 8390, frame count 89700
# running reward: 109.50 at episode 8400, frame count 89800
# running reward: 106.44 at episode 8420, frame count 89900
# running reward: 104.58 at episode 8430, frame count 90000
# running reward: 103.50 at episode 8460, frame count 90200
# running reward: 99.36 at episode 8480, frame count 90300
# running reward: 97.62 at episode 8490, frame count 90400
# running reward: 97.80 at episode 8510, frame count 90500
# running reward: 94.92 at episode 8530, frame count 90600
# running reward: 93.56 at episode 8540, frame count 90700
# running reward: 93.56 at episode 8540, frame count 90800
# running reward: 93.56 at episode 8540, frame count 90900
# running reward: 93.56 at episode 8540, frame count 91000
# running reward: 93.56 at episode 8540, frame count 91100
# running reward: 93.56 at episode 8540, frame count 91200
# running reward: 75.94 at episode 8550, frame count 91300
# running reward: 79.18 at episode 8560, frame count 91400
# running reward: 82.58 at episode 8580, frame count 91500
# running reward: 82.58 at episode 8580, frame count 91600
# running reward: 82.58 at episode 8580, frame count 91700
# running reward: 82.58 at episode 8580, frame count 91800
# running reward: 73.42 at episode 8600, frame count 91900
# running reward: 73.68 at episode 8610, frame count 92000
# running reward: 71.92 at episode 8620, frame count 92100
# running reward: 71.92 at episode 8620, frame count 92200
# running reward: 72.32 at episode 8630, frame count 92300
# running reward: 72.32 at episode 8630, frame count 92400
# running reward: 72.32 at episode 8630, frame count 92500
# running reward: 72.32 at episode 8630, frame count 92600
# running reward: 72.32 at episode 8630, frame count 92700
# running reward: 72.32 at episode 8630, frame count 92800
# running reward: 54.82 at episode 8640, frame count 92900
# running reward: 59.26 at episode 8650, frame count 93000
# running reward: 59.26 at episode 8650, frame count 93100
# running reward: 59.26 at episode 8650, frame count 93200
# running reward: 59.26 at episode 8650, frame count 93300
# running reward: 59.26 at episode 8650, frame count 93400
# running reward: 59.26 at episode 8650, frame count 93500
# running reward: 59.26 at episode 8650, frame count 93600
# running reward: 45.24 at episode 8660, frame count 93700
# running reward: 45.28 at episode 8680, frame count 93800
# running reward: 45.58 at episode 8700, frame count 93900
# running reward: 45.94 at episode 8710, frame count 94000
# running reward: 43.70 at episode 8720, frame count 94100
# running reward: 43.70 at episode 8720, frame count 94200
# running reward: 43.70 at episode 8720, frame count 94300
# running reward: 43.70 at episode 8720, frame count 94400
# running reward: 43.70 at episode 8720, frame count 94500
# running reward: 43.70 at episode 8720, frame count 94600
# running reward: 27.54 at episode 8740, frame count 94700
# running reward: 29.52 at episode 8760, frame count 94800
# running reward: 27.90 at episode 8770, frame count 94900
# running reward: 29.34 at episode 8780, frame count 95000
# running reward: 34.82 at episode 8800, frame count 95100
# running reward: 34.14 at episode 8810, frame count 95200
# running reward: 32.04 at episode 8820, frame count 95300
# running reward: 32.04 at episode 8820, frame count 95400
# running reward: 32.04 at episode 8820, frame count 95500
# running reward: 32.04 at episode 8820, frame count 95600
# running reward: 32.04 at episode 8820, frame count 95700
# running reward: 28.50 at episode 8840, frame count 95800
# running reward: 28.50 at episode 8840, frame count 95900
# running reward: 25.66 at episode 8860, frame count 96000
# running reward: 29.56 at episode 8880, frame count 96100
# running reward: 30.48 at episode 8890, frame count 96200
# running reward: 28.96 at episode 8910, frame count 96300
# running reward: 30.10 at episode 8940, frame count 96400
# running reward: 29.54 at episode 8960, frame count 96500
# running reward: 31.66 at episode 8970, frame count 96600
# running reward: 36.16 at episode 8980, frame count 96700
# running reward: 36.62 at episode 8990, frame count 96800
# running reward: 36.62 at episode 8990, frame count 96900
# running reward: 36.62 at episode 8990, frame count 97000
# running reward: 36.62 at episode 8990, frame count 97100
# running reward: 36.62 at episode 8990, frame count 97200
# running reward: 36.62 at episode 8990, frame count 97300
# running reward: 18.98 at episode 9000, frame count 97400
# running reward: 18.22 at episode 9010, frame count 97500
# running reward: 17.52 at episode 9020, frame count 97600
# running reward: 18.58 at episode 9030, frame count 97700
# running reward: 18.26 at episode 9050, frame count 97800
# running reward: 19.12 at episode 9060, frame count 97900
# running reward: 19.12 at episode 9060, frame count 98000
# running reward: 19.12 at episode 9060, frame count 98100
# running reward: 18.62 at episode 9070, frame count 98200
# running reward: 18.62 at episode 9070, frame count 98300
# running reward: 18.62 at episode 9070, frame count 98400
# running reward: 18.62 at episode 9070, frame count 98500
# running reward: 18.62 at episode 9070, frame count 98600
# running reward: 0.04 at episode 9080, frame count 98700
# running reward: 0.04 at episode 9080, frame count 98800
# running reward: 0.04 at episode 9080, frame count 98900
# running reward: 0.04 at episode 9080, frame count 99000
# running reward: 0.04 at episode 9080, frame count 99100
# running reward: 0.04 at episode 9080, frame count 99200
# running reward: -18.22 at episode 9090, frame count 99300
# running reward: -14.48 at episode 9110, frame count 99400
# running reward: -15.58 at episode 9130, frame count 99500
# running reward: -16.02 at episode 9140, frame count 99600
# running reward: -14.92 at episode 9160, frame count 99700
# running reward: -13.34 at episode 9170, frame count 99800
# running reward: -13.34 at episode 9190, frame count 99900
# running reward: -12.36 at episode 9210, frame count 100100
# running reward: -13.30 at episode 9230, frame count 100200
# running reward: -12.82 at episode 9240, frame count 100300
# running reward: -12.82 at episode 9240, frame count 100400
# running reward: -12.82 at episode 9240, frame count 100500
# running reward: -12.82 at episode 9240, frame count 100600
# running reward: -12.82 at episode 9240, frame count 100700
# running reward: -27.56 at episode 9250, frame count 100800
# running reward: -27.72 at episode 9260, frame count 100900
# running reward: -27.72 at episode 9260, frame count 101000
# running reward: -27.72 at episode 9260, frame count 101100
# running reward: -27.72 at episode 9260, frame count 101200
# running reward: -27.72 at episode 9260, frame count 101300
# running reward: -39.90 at episode 9270, frame count 101400
# running reward: -39.90 at episode 9270, frame count 101500
# running reward: -33.64 at episode 9290, frame count 101700
# running reward: -33.64 at episode 9290, frame count 101800
# running reward: -33.64 at episode 9290, frame count 101900
# running reward: -33.64 at episode 9290, frame count 102000
# running reward: -33.64 at episode 9290, frame count 102100
# running reward: -46.80 at episode 9300, frame count 102200
# running reward: -46.80 at episode 9300, frame count 102300
# running reward: -48.04 at episode 9310, frame count 102400
# running reward: -48.04 at episode 9310, frame count 102500
# running reward: -49.62 at episode 9320, frame count 102600
# running reward: -49.62 at episode 9320, frame count 102700
# running reward: -49.62 at episode 9320, frame count 102800
# running reward: -49.62 at episode 9320, frame count 102900
# running reward: -49.62 at episode 9320, frame count 103000
# running reward: -49.62 at episode 9320, frame count 103100
# running reward: -49.62 at episode 9320, frame count 103200
# running reward: -49.62 at episode 9320, frame count 103300
# running reward: -49.62 at episode 9320, frame count 103400
# running reward: -49.62 at episode 9320, frame count 103500
# running reward: -57.92 at episode 9330, frame count 103600
# running reward: -55.88 at episode 9340, frame count 103700
# running reward: -58.16 at episode 9350, frame count 103800
# running reward: -58.16 at episode 9350, frame count 103900
# running reward: -58.16 at episode 9350, frame count 104000
# running reward: -58.16 at episode 9350, frame count 104100
# running reward: -65.58 at episode 9360, frame count 104200
# running reward: -65.58 at episode 9360, frame count 104300
# running reward: -65.58 at episode 9360, frame count 104400
# running reward: -65.58 at episode 9360, frame count 104500
# running reward: -65.58 at episode 9360, frame count 104600
# running reward: -65.58 at episode 9360, frame count 104700
# running reward: -83.56 at episode 9370, frame count 104800
# running reward: -83.56 at episode 9370, frame count 104900
# running reward: -83.56 at episode 9370, frame count 105000
# running reward: -87.32 at episode 9380, frame count 105100
# running reward: -87.32 at episode 9380, frame count 105200
# running reward: -87.32 at episode 9380, frame count 105300
# running reward: -87.32 at episode 9380, frame count 105400
# running reward: -93.50 at episode 9400, frame count 105500
# running reward: -92.16 at episode 9420, frame count 105600
# running reward: -90.42 at episode 9450, frame count 105700
# running reward: -88.08 at episode 9470, frame count 105800
# running reward: -84.36 at episode 9490, frame count 105900
# running reward: -82.78 at episode 9500, frame count 106000
# running reward: -84.30 at episode 9510, frame count 106100
# running reward: -84.28 at episode 9520, frame count 106200
# running reward: -83.48 at episode 9530, frame count 106300
# running reward: -82.26 at episode 9540, frame count 106400
# running reward: -62.50 at episode 9550, frame count 106500
# running reward: -62.50 at episode 9550, frame count 106600
# running reward: -62.50 at episode 9550, frame count 106700
# running reward: -62.50 at episode 9550, frame count 106800
# running reward: -62.50 at episode 9550, frame count 106900
# running reward: -62.50 at episode 9550, frame count 107000
# running reward: -79.08 at episode 9570, frame count 107100
# running reward: -79.56 at episode 9580, frame count 107200
# running reward: -69.50 at episode 9600, frame count 107300
# running reward: -70.26 at episode 9610, frame count 107400
# running reward: -70.26 at episode 9610, frame count 107500
# running reward: -70.34 at episode 9620, frame count 107600
# running reward: -52.18 at episode 9640, frame count 107700
# running reward: -52.18 at episode 9640, frame count 107800
# running reward: -39.96 at episode 9660, frame count 107900
# running reward: -39.42 at episode 9680, frame count 108000
# running reward: -41.08 at episode 9690, frame count 108100
# running reward: -42.38 at episode 9700, frame count 108200
# running reward: -42.34 at episode 9710, frame count 108300
# running reward: -21.06 at episode 9740, frame count 108400
# running reward: -20.14 at episode 9760, frame count 108500
# running reward: -20.14 at episode 9760, frame count 108600
# running reward: -22.88 at episode 9780, frame count 108700
# running reward: -22.88 at episode 9780, frame count 108800
# ...
# running reward: -29.02 at episode 38350, frame count 455000
# running reward: -29.02 at episode 38350, frame count 455100
# running reward: -42.38 at episode 38370, frame count 455200
# running reward: -42.66 at episode 38380, frame count 455300
# running reward: -23.54 at episode 38400, frame count 455400
# running reward: -23.28 at episode 38420, frame count 455500
# running reward: -22.60 at episode 38440, frame count 455600
# running reward: -22.60 at episode 38440, frame count 455700
# running reward: -22.60 at episode 38440, frame count 455800
# running reward: -30.22 at episode 38450, frame count 455900
# running reward: -29.72 at episode 38460, frame count 456000
# running reward: -29.72 at episode 38460, frame count 456100
# running reward: -29.72 at episode 38460, frame count 456200
# running reward: -29.72 at episode 38460, frame count 456300
# running reward: -29.72 at episode 38460, frame count 456400
# running reward: -43.54 at episode 38470, frame count 456500
# running reward: -43.54 at episode 38470, frame count 456600
# running reward: -43.54 at episode 38470, frame count 456700
# running reward: -43.54 at episode 38470, frame count 456800
# running reward: -43.54 at episode 38470, frame count 456900
# running reward: -62.30 at episode 38480, frame count 457000
# running reward: -63.04 at episode 38490, frame count 457100
# running reward: -60.44 at episode 38510, frame count 457200
# running reward: -61.10 at episode 38520, frame count 457300
# running reward: -59.08 at episode 38530, frame count 457400
# running reward: -58.98 at episode 38550, frame count 457500
# running reward: -58.98 at episode 38550, frame count 457600
# running reward: -58.98 at episode 38550, frame count 457700
# running reward: -58.98 at episode 38550, frame count 457800
# running reward: -58.98 at episode 38550, frame count 457900
# running reward: -58.98 at episode 38550, frame count 458000
# running reward: -76.92 at episode 38570, frame count 458100
# running reward: -76.92 at episode 38570, frame count 458200
# running reward: -76.92 at episode 38570, frame count 458300
# running reward: -76.92 at episode 38570, frame count 458400
# running reward: -76.92 at episode 38570, frame count 458500
# running reward: -76.92 at episode 38570, frame count 458600
# running reward: -96.78 at episode 38580, frame count 458700
# running reward: -96.78 at episode 38580, frame count 458800
# running reward: -96.78 at episode 38580, frame count 458900
# running reward: -96.78 at episode 38580, frame count 459000
# running reward: -105.76 at episode 38590, frame count 459100
# running reward: -105.76 at episode 38590, frame count 459200
# running reward: -107.84 at episode 38600, frame count 459300
# running reward: -107.84 at episode 38600, frame count 459400
# running reward: -107.84 at episode 38600, frame count 459500
# running reward: -107.84 at episode 38600, frame count 459600
# running reward: -107.84 at episode 38600, frame count 459700
# running reward: -126.02 at episode 38610, frame count 459800
# running reward: -126.02 at episode 38610, frame count 459900
# running reward: -126.02 at episode 38610, frame count 460000
# running reward: -126.02 at episode 38610, frame count 460100
# running reward: -126.02 at episode 38610, frame count 460200
# running reward: -126.02 at episode 38610, frame count 460300
# running reward: -144.58 at episode 38620, frame count 460400
# running reward: -144.58 at episode 38620, frame count 460500
# running reward: -144.58 at episode 38620, frame count 460600
# running reward: -144.58 at episode 38620, frame count 460700
# running reward: -144.58 at episode 38620, frame count 460800
# running reward: -163.36 at episode 38640, frame count 460900
# running reward: -163.54 at episode 38660, frame count 461000
# running reward: -163.54 at episode 38660, frame count 461100
# running reward: -163.54 at episode 38660, frame count 461200
# running reward: -163.54 at episode 38660, frame count 461300
# running reward: -163.54 at episode 38660, frame count 461400
# running reward: -163.54 at episode 38660, frame count 461500
# running reward: -180.30 at episode 38680, frame count 461600
# running reward: -182.50 at episode 38690, frame count 461700
# running reward: -182.50 at episode 38690, frame count 461800
# running reward: -183.84 at episode 38700, frame count 461900
# running reward: -185.18 at episode 38720, frame count 462000
# running reward: -184.74 at episode 38740, frame count 462100
# running reward: -167.30 at episode 38760, frame count 462200
# running reward: -148.46 at episode 38770, frame count 462300
# running reward: -147.34 at episode 38780, frame count 462400
# running reward: -147.34 at episode 38780, frame count 462500
# running reward: -135.48 at episode 38790, frame count 462600
# running reward: -133.22 at episode 38810, frame count 462700
# running reward: -132.82 at episode 38820, frame count 462800
# running reward: -132.52 at episode 38830, frame count 462900
# running reward: -132.52 at episode 38830, frame count 463000
# running reward: -111.62 at episode 38880, frame count 463200
# running reward: -112.76 at episode 38890, frame count 463300
# running reward: -113.86 at episode 38900, frame count 463400
# running reward: -94.12 at episode 38930, frame count 463500
# running reward: -57.16 at episode 38950, frame count 463600
# running reward: -55.64 at episode 38970, frame count 463700
# running reward: -51.30 at episode 38990, frame count 463800
# running reward: -51.30 at episode 38990, frame count 463900
# running reward: -51.32 at episode 39000, frame count 464000
# running reward: -51.40 at episode 39010, frame count 464100
# running reward: -35.12 at episode 39020, frame count 464200
# running reward: -35.12 at episode 39020, frame count 464300
# running reward: -35.12 at episode 39020, frame count 464400
# running reward: -35.12 at episode 39020, frame count 464500
# running reward: -35.12 at episode 39020, frame count 464600
# running reward: -35.12 at episode 39020, frame count 464700
# running reward: -48.62 at episode 39030, frame count 464800
# running reward: -48.62 at episode 39030, frame count 464900
# running reward: -48.62 at episode 39030, frame count 465000
# running reward: -48.62 at episode 39030, frame count 465100
# running reward: -48.62 at episode 39030, frame count 465200
# running reward: -66.66 at episode 39040, frame count 465300
# running reward: -66.66 at episode 39040, frame count 465400
# running reward: -66.66 at episode 39040, frame count 465500
# running reward: -66.66 at episode 39040, frame count 465600
# running reward: -66.66 at episode 39040, frame count 465700
# running reward: -66.66 at episode 39040, frame count 465800
# running reward: -85.38 at episode 39050, frame count 465900
# running reward: -86.44 at episode 39060, frame count 466000
# running reward: -88.50 at episode 39070, frame count 466100
# running reward: -89.84 at episode 39080, frame count 466200
# running reward: -90.06 at episode 39090, frame count 466300
# running reward: -90.06 at episode 39090, frame count 466400
# running reward: -90.06 at episode 39090, frame count 466500
# running reward: -90.06 at episode 39090, frame count 466600
# running reward: -90.06 at episode 39090, frame count 466700
# running reward: -90.06 at episode 39090, frame count 466800
# running reward: -108.96 at episode 39100, frame count 466900
# running reward: -109.36 at episode 39110, frame count 467000
# running reward: -109.28 at episode 39130, frame count 467100
# running reward: -110.98 at episode 39140, frame count 467200
# running reward: -113.00 at episode 39150, frame count 467300
# running reward: -114.00 at episode 39160, frame count 467400
# running reward: -115.56 at episode 39170, frame count 467500
# running reward: -117.12 at episode 39180, frame count 467600
# running reward: -118.64 at episode 39190, frame count 467700
# running reward: -120.38 at episode 39200, frame count 467800
# running reward: -117.24 at episode 39210, frame count 467900
# running reward: -117.24 at episode 39210, frame count 468000
# running reward: -117.24 at episode 39210, frame count 468100
# running reward: -117.24 at episode 39210, frame count 468200
# running reward: -117.24 at episode 39210, frame count 468300
# running reward: -135.90 at episode 39220, frame count 468400
# running reward: -137.34 at episode 39230, frame count 468500
# running reward: -137.34 at episode 39230, frame count 468600
# running reward: -137.34 at episode 39230, frame count 468700
# running reward: -137.34 at episode 39230, frame count 468800
# running reward: -137.34 at episode 39230, frame count 468900
# running reward: -137.34 at episode 39230, frame count 469000
# running reward: -155.80 at episode 39260, frame count 469100
# running reward: -154.08 at episode 39280, frame count 469200
# running reward: -153.64 at episode 39290, frame count 469300
# running reward: -153.64 at episode 39290, frame count 469400
# running reward: -153.64 at episode 39290, frame count 469500
# running reward: -162.80 at episode 39300, frame count 469600
# running reward: -163.14 at episode 39310, frame count 469700
# running reward: -161.82 at episode 39330, frame count 469800
# running reward: -162.12 at episode 39340, frame count 469900
# running reward: -162.12 at episode 39340, frame count 470000
# running reward: -162.12 at episode 39340, frame count 470100
# running reward: -162.12 at episode 39340, frame count 470200
# running reward: -162.12 at episode 39340, frame count 470300
# running reward: -181.14 at episode 39350, frame count 470400
# running reward: -181.14 at episode 39350, frame count 470500
# running reward: -170.26 at episode 39360, frame count 470600
# running reward: -175.30 at episode 39370, frame count 470700
# running reward: -175.30 at episode 39370, frame count 470800
# running reward: -177.60 at episode 39380, frame count 470900
# running reward: -177.08 at episode 39390, frame count 471000
# running reward: -177.08 at episode 39390, frame count 471100
# running reward: -178.96 at episode 39400, frame count 471200
# running reward: -178.96 at episode 39400, frame count 471300
# running reward: -178.96 at episode 39400, frame count 471400
# running reward: -178.96 at episode 39400, frame count 471500
# running reward: -178.96 at episode 39400, frame count 471600
# running reward: -197.64 at episode 39410, frame count 471700
# running reward: -199.20 at episode 39420, frame count 471800
# running reward: -200.94 at episode 39430, frame count 471900
# running reward: -195.12 at episode 39450, frame count 472000
# running reward: -193.30 at episode 39460, frame count 472100
# running reward: -193.30 at episode 39460, frame count 472200
# running reward: -181.38 at episode 39470, frame count 472300
# running reward: -163.34 at episode 39490, frame count 472400
# running reward: -164.74 at episode 39500, frame count 472500
# running reward: -166.22 at episode 39510, frame count 472600
# running reward: -167.24 at episode 39520, frame count 472700
# running reward: -171.28 at episode 39530, frame count 472800
# running reward: -171.28 at episode 39530, frame count 472900
# running reward: -172.68 at episode 39540, frame count 473000
# running reward: -175.44 at episode 39550, frame count 473100
# running reward: -157.20 at episode 39560, frame count 473200
# running reward: -157.20 at episode 39560, frame count 473300
# running reward: -157.20 at episode 39560, frame count 473400
# running reward: -157.20 at episode 39560, frame count 473500
# running reward: -157.20 at episode 39560, frame count 473600
# running reward: -175.72 at episode 39570, frame count 473700
# running reward: -144.20 at episode 39590, frame count 473800
# running reward: -123.86 at episode 39610, frame count 473900
# running reward: -105.98 at episode 39620, frame count 474000
# running reward: -86.16 at episode 39640, frame count 474100
# running reward: -85.02 at episode 39660, frame count 474200
# running reward: -66.96 at episode 39680, frame count 474300
# running reward: -63.18 at episode 39700, frame count 474400
# running reward: -60.74 at episode 39710, frame count 474500
# running reward: -60.86 at episode 39720, frame count 474600
# running reward: -62.68 at episode 39740, frame count 474700
# running reward: -63.76 at episode 39760, frame count 474800
# running reward: -62.60 at episode 39780, frame count 474900
# running reward: -55.94 at episode 39790, frame count 475000
# running reward: -56.82 at episode 39800, frame count 475100
# running reward: -57.94 at episode 39820, frame count 475200
# running reward: -57.94 at episode 39820, frame count 475300
# running reward: -57.94 at episode 39820, frame count 475400
# running reward: -57.94 at episode 39820, frame count 475500
# running reward: -57.94 at episode 39820, frame count 475600
# running reward: -76.12 at episode 39830, frame count 475700
# running reward: -73.18 at episode 39840, frame count 475800
# running reward: -75.00 at episode 39850, frame count 475900
# running reward: -76.44 at episode 39860, frame count 476000
# running reward: -76.44 at episode 39860, frame count 476100
# running reward: -76.44 at episode 39860, frame count 476200
# running reward: -76.44 at episode 39860, frame count 476300
# running reward: -76.44 at episode 39860, frame count 476400
# running reward: -76.44 at episode 39860, frame count 476500
# running reward: -76.44 at episode 39860, frame count 476600
# running reward: -91.74 at episode 39870, frame count 476700
# running reward: -91.74 at episode 39870, frame count 476800
# running reward: -91.74 at episode 39870, frame count 476900
# running reward: -91.74 at episode 39870, frame count 477000
# running reward: -91.74 at episode 39870, frame count 477100
# running reward: -91.74 at episode 39870, frame count 477200
# running reward: -110.22 at episode 39880, frame count 477300
# running reward: -110.22 at episode 39880, frame count 477400
# running reward: -110.22 at episode 39880, frame count 477500
# running reward: -110.22 at episode 39880, frame count 477600
# running reward: -110.22 at episode 39880, frame count 477700
# running reward: -127.60 at episode 39890, frame count 477800
# running reward: -126.82 at episode 39910, frame count 477900
# running reward: -126.84 at episode 39920, frame count 478000
# running reward: -127.00 at episode 39940, frame count 478100
# running reward: -126.94 at episode 39950, frame count 478200
# running reward: -128.78 at episode 39970, frame count 478300
# running reward: -125.86 at episode 39990, frame count 478400
# running reward: -121.36 at episode 40020, frame count 478500
# running reward: -121.36 at episode 40020, frame count 478600
# running reward: -108.56 at episode 40030, frame count 478700
# running reward: -89.54 at episode 40040, frame count 478800
# running reward: -89.54 at episode 40040, frame count 478900
# running reward: -89.54 at episode 40040, frame count 479000
# running reward: -89.54 at episode 40040, frame count 479100
# running reward: -89.54 at episode 40040, frame count 479200
# running reward: -89.76 at episode 40050, frame count 479300
# running reward: -86.54 at episode 40070, frame count 479400
# running reward: -86.54 at episode 40070, frame count 479500
# running reward: -65.64 at episode 40100, frame count 479600
# running reward: -65.46 at episode 40120, frame count 479700
# running reward: -61.88 at episode 40140, frame count 479800
# running reward: -59.56 at episode 40160, frame count 479900
# running reward: -57.88 at episode 40180, frame count 480000
# running reward: -54.68 at episode 40200, frame count 480100
# running reward: -54.68 at episode 40200, frame count 480200
# running reward: -56.08 at episode 40210, frame count 480300
# running reward: -40.84 at episode 40220, frame count 480400
# running reward: -39.52 at episode 40230, frame count 480500
# running reward: -21.48 at episode 40240, frame count 480600
# running reward: -21.48 at episode 40240, frame count 480700
# running reward: -21.48 at episode 40240, frame count 480800
# running reward: -21.48 at episode 40240, frame count 480900
# running reward: -21.48 at episode 40240, frame count 481000
# running reward: -39.96 at episode 40250, frame count 481100
# running reward: -39.96 at episode 40250, frame count 481200
# running reward: -39.96 at episode 40250, frame count 481300
# running reward: -39.96 at episode 40250, frame count 481400

# %%
from collections import Counter
c = Counter(action_history)
sum_actions = 0
d = dict(c)
for k,v in d.items():
    sum_actions += v
print("Total:", sum_actions)

for k,v in d.items():
    print(f"{k}:{v/sum_actions}")
# Out:
# Total: 237609
# 3:0.029994655084613797
# 2:0.0166449924034864
# 7:0.017558257473412203
# 1:0.6622644765139367
# 4:0.022200337529302342
# 9:0.018909216401735623
# 8:0.017974908357848398
# 6:0.040124742749643325
# 5:0.17432841348602116

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x24cc10b1670>,
#  <keras.layers.convolutional.Conv2D at 0x24d451973a0>,
#  <keras.layers.pooling.MaxPooling2D at 0x24d45197d90>,
#  <keras.layers.convolutional.Conv2D at 0x24be5009c40>,
#  <keras.layers.pooling.MaxPooling2D at 0x24d3d862130>,
#  <keras.layers.core.dropout.Dropout at 0x24d3d86bb20>,
#  <keras.engine.input_layer.InputLayer at 0x24d394944c0>,
#  <keras.layers.core.flatten.Flatten at 0x24d45035eb0>,
#  <keras.layers.core.dense.Dense at 0x24d2e90c6d0>,
#  <keras.layers.core.dense.Dense at 0x24d3d765160>,
#  <keras.layers.core.dense.Dense at 0x24bff4b1c40>,
#  <keras.layers.core.dense.Dense at 0x24d2a6bc1c0>,
#  <keras.layers.core.dense.Dense at 0x24be4d32f10>,
#  <keras.layers.merge.Concatenate at 0x24cf663d3d0>,
#  <keras.layers.core.dense.Dense at 0x24d3d85fdf0>,
#  <keras.layers.core.dense.Dense at 0x24cf663d9d0>,
#  <keras.layers.core.dense.Dense at 0x24d4968b6d0>]

# %%
model.layers[3].get_weights()[0].shape
# Out:
# (12, 12, 3, 3)

# %%
plt.imshow(model.layers[3].get_weights()[0][:,:,1,1], cmap="gray")

# %%
resh = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))

# %%
for i in range(3):
    plt.figure(figsize=(10,8))
    plt.imshow(model.layers[3].get_weights()[0][:,:,3,i], cmap="gray")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13976/3028376312.py in <module>
#       1 for i in range(3):
#       2     plt.figure(figsize=(10,8))
# ----> 3     plt.imshow(model.layers[3].get_weights()[0][:,:,3,i], cmap="gray")
#       4     plt.show()
#
# IndexError: index 3 is out of bounds for axis 2 with size 3

# %%
plt.imshow(state_history[0], cmap='gray')

# %%
resh.shape
# Out:
# (16384, 9, 9, 1)

# %%
plt.imshow(resh[6, :,:,:])

# %%
env.close()
