# %%
try:
    import mlagents
    print("ml-agents already installed")
except ImportError:
    # !python -m pip install -q mlagents==0.27.0
    print("Installed ml-agents")
# Out:
# ml-agents already installed

# %% [markdown]
# # Q-Learning Keras

# %%
import random
import tensorflow as tf
import numpy as np
import datetime
import traceback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Conv2D, Flatten, concatenate
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import Huber, LogCosh, CategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.environment import ActionTuple, BaseEnv

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Deep Q-Learning

# %%
behavior_name = 'AlphaRomeo?team=0'

# %%
num_actions = 8


def create_q_model():
    with tf.device('GPU:0'):
        
        inputs = Input(shape=(84, 84, 3,))

        layer1 = Conv2D(32, 8, strides=4, activation="relu")(inputs)
        layer2 = Conv2D(64, 4, strides=2, activation="relu")(layer1)
        layer3 = Conv2D(64, 3, strides=1, activation="relu")(layer2)

        conv_output = Flatten()(layer3)
        
        conv_output_model = Model(inputs=inputs, outputs=conv_output)
        
        numerical_inputs = Input(shape=(2))
        layer4 = Dense(64, activation="relu")(numerical_inputs)
        numerical_output = Dense(128, activation="relu")(layer4)
        
        numerical_output_model = Model(inputs=numerical_inputs, outputs=numerical_output)
        
        combined = concatenate([conv_output_model.output, numerical_output_model.output])

        layer5 = Dense(512, activation="relu")(combined)
        action = Dense(num_actions, activation="linear")(layer5)

        return Model(inputs=[conv_output_model.input, numerical_output_model.input], outputs=action)


model = create_q_model()

model_target = create_q_model()

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 84, 84, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 20, 20, 32)   6176        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 9, 9, 64)     32832       ['conv2d[0][0]']
#
#  input_2 (InputLayer)           [(None, 2)]          0           []
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 64)     36928       ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 64)           192         ['input_2[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['conv2d_2[0][0]']
#
#  dense_1 (Dense)                (None, 128)          8320        ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 3264)         0           ['flatten[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          1671680     ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 8)            4104        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 1,760,232
# Trainable params: 1,760,232
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_target, show_shapes=True, show_dtype=True, show_layer_activations=True)

# %%
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

# Configuration paramaters for the whole setup
gamma = 0.01  # Discount factor for past rewards
epsilon = 0.5  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
max_steps_per_episode = 10000
batch_size = 128

# Memórias de repetição de experiência
action_history = []
state_conv_history = []
state_num_history = []
state_conv_next_history = []
state_num_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 100
# Number of frames for exploration
epsilon_greedy_frames = 1000000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 10000
# Train the model after 4 actions
update_after_actions = 20
# How often to update the target network
update_target_network = 100
# Using huber loss for stability
loss_function =Huber()

# %%
env = UnityEnvironment(file_name="Alpha Romeo", seed=1, side_channels=[], worker_id=1)

log_folder = 'logs/{}'.format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
writer = tf.summary.create_file_writer(log_folder)

# tf.debugging.experimental.enable_dump_debug_info(log_folder, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)

try:
    while True:  # Run until solvedloss_function
        with writer.as_default():
            env.reset()
            done = False
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            if decision_steps:
                state_conv = decision_steps[0].obs[0]
                state_num = decision_steps[0].obs[1]
            if terminal_steps:
                done = True                
                state_conv = decision_steps[0].obs[0]
                state_numerical = decision_steps[0].obs[1]
                         
            episode_reward = 0

            for timestep in range(1, max_steps_per_episode):
                # env.render(); Adding this line would show the attempts
                # of the agent in a pop up window.
                frame_count += 1

                # Use epsilon-greedy for exploration
                if  epsilon > np.random.rand(1)[0]:
                    # Take random action
                    action = random.choice([1,2,3,4,5,6,7,8])
                    
                else:
                    # Predict action Q-values
                    # From environment state
                    state_conv_tensor = tf.convert_to_tensor(state_conv)
                    state_num_tensor = tf.convert_to_tensor(state_num)
                    state_conv_tensor = tf.expand_dims(state_conv_tensor, 0)
                    state_num_tensor = tf.expand_dims(state_num_tensor, 0)
                    action_probs = model([state_conv_tensor, state_num_tensor], training=False)
                    # Take best action
                    action = action_probs[0]
                    action = int(tf.argmax(action)+1)
                    

                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                # Apply the sampled action in our environment

                action_tuple = ActionTuple()
                action_tuple.add_discrete(np.array([[action]]))
                
                env.set_actions(behavior_name, action_tuple)
                
                env.step()

                decision_steps, terminal_steps = env.get_steps(behavior_name)

                if terminal_steps:
                    done = True
                    env.reset()
                    decision_steps, terminal_steps = env.get_steps(behavior_name)
                    state_conv_next = decision_steps[0].obs[0]
                    state_num_next = decision_steps[0].obs[1]
    #                 decision_steps, terminal_steps = env.get_steps(behavior_name)
                    break

                else:
                    state_conv_next = decision_steps[0].obs[0]
                    state_num_next = decision_steps[0].obs[1]


                reward = decision_steps[0].reward
        #         state_next = np.array(state_next)

                episode_reward += reward
                # Save actions and states in replay buffer
                action_history.append(action)
                state_conv_history.append(state_conv)
                state_num_history.append(state_num)
                state_conv_next_history.append(state_conv_next)
                state_num_next_history.append(state_num_next)
                done_history.append(done) 
                rewards_history.append(reward)
                state_conv = state_conv_next
                state_num = state_num_next

                # Update every fourth frame and once batch size is over 32
                if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

                    # Selecionar índices aleatóriamente
                    indices = np.random.choice(range(len(done_history)), size=batch_size)

                    # Usando list comprehension para buscar os valores dos índices selecionados
                    state_conv_sample = np.array([state_conv_history[i] for i in indices])
                    state_num_sample = np.array([state_num_history[i] for i in indices])
                    state_conv_next_sample = np.array([state_conv_next_history[i] for i in indices])
                    state_num_next_sample = np.array([state_num_next_history[i] for i in indices])
                    rewards_sample = [rewards_history[i] for i in indices]
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor(
                        [float(done_history[i]) for i in indices]
                    )

                    # Build the updated Q-values for the sampled future states
                    # Use the target model for stability
                    state_num_next_sample = tf.reshape(state_num_next_sample, [-1, 2])
                    future_rewards = model_target.predict([np.array(state_conv_next_sample), np.array(state_num_next_sample)])

                    # Q value = reward + discount factor * expected future reward
                    updated_q_values = rewards_sample + gamma * tf.reduce_max(
                        future_rewards, axis=1
                    )

                    # If final frame set the last value to -1
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values

                    masks = tf.one_hot(action_sample, num_actions)

                    with tf.GradientTape() as tape:
                        # Train the model on the states and updated Q-values
                        q_values = model([np.array(state_conv_sample), np.array(state_num_sample)])


                        # Apply the masks to the Q-values to get the Q-value for action taken
                        q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)

                        # Calculate loss between new Q-value and old Q-value

                        loss = loss_function(updated_q_values, q_action)

                    # Backpropagation
                    grads = tape.gradient(loss, model.trainable_variables)
                    optimizer.apply_gradients(zip(grads, model.trainable_variables))

                if frame_count % update_target_network == 0:
                    # update the the target network with new weights
                    model_target.set_weights(model.get_weights())
                    # Log details
                    template = "running reward: {:.2f} at episode {}, frame count {}"
                    print(template.format(running_reward, episode_count, frame_count))
                    tf.summary.scalar(name="reward", data=running_reward, step=episode_count)
                    tf.summary.scalar(name="epsilon", data=epsilon, step=episode_count)
                    tf.summary.scalar(name="frame_count", data=frame_count, step=episode_count)
                    dqn_variable = model.trainable_variables
                    tf.summary.histogram(name="dqn_variables", data=tf.convert_to_tensor(dqn_variable[0]), step=episode_count)
                    tf.summary.histogram(name="actions", data=action, step=episode_count)
#                     convs = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))
#                     tf.summary.image("Training data", data=convs[:5, :, :, :], step=episode_count)
                    writer.flush()
                    
            # Limit the state and reward history
            if len(rewards_history) > max_memory_length:
                del rewards_history[:1]
                del state_conv_history[:1]
                del state_num_history[:1]
                del state_conv_next_history[:1]
                del state_num_next_history[:1]
                del action_history[:1]
                del done_history[:1]

            if done:
                env.reset()
                done = False


            # Update running reward to check condition for solving
            episode_reward_history.append(episode_reward)
            if len(episode_reward_history) > 100:
                del episode_reward_history[:1]
            running_reward = np.mean(episode_reward_history)

            episode_count += 10

            if running_reward > 500000:  # Condition to consider the task solved
                print("Solved at episode {}!".format(episode_count))
                break
except:
    print(traceback.print_exc())
    writer.close()
    env.close()
# Out:
# running reward: 0.00 at episode 0, frame count 100
# running reward: 0.00 at episode 0, frame count 200
# running reward: -670000.00 at episode 10, frame count 300
# running reward: -417000.00 at episode 20, frame count 400
# running reward: -320666.67 at episode 30, frame count 500
# running reward: -214400.00 at episode 50, frame count 600
# running reward: -177666.67 at episode 60, frame count 700
# running reward: -134444.44 at episode 90, frame count 800
# running reward: -134444.44 at episode 90, frame count 900
# running reward: -128363.64 at episode 110, frame count 1000
# running reward: -114461.54 at episode 130, frame count 1100
# running reward: -123000.00 at episode 140, frame count 1200
# running reward: -123000.00 at episode 140, frame count 1300
# running reward: -151066.67 at episode 150, frame count 1400
# running reward: -148000.00 at episode 160, frame count 1500
# running reward: -131000.00 at episode 180, frame count 1600
# running reward: -125684.21 at episode 190, frame count 1700
# running reward: -125809.52 at episode 210, frame count 1800
# running reward: -122909.09 at episode 220, frame count 1900
# running reward: -113217.39 at episode 230, frame count 2000
# running reward: -110583.33 at episode 240, frame count 2100
# running reward: -119200.00 at episode 250, frame count 2200
# running reward: -122538.46 at episode 260, frame count 2300
# running reward: -117333.33 at episode 270, frame count 2400
# running reward: -115714.29 at episode 280, frame count 2500
# running reward: -112827.59 at episode 290, frame count 2600
# running reward: -113800.00 at episode 300, frame count 2700
# running reward: -112322.58 at episode 310, frame count 2800
# running reward: -110250.00 at episode 320, frame count 2900
# running reward: -107764.71 at episode 340, frame count 3000
# running reward: -104057.14 at episode 350, frame count 3100
# running reward: -100777.78 at episode 360, frame count 3200
# running reward: -100210.53 at episode 380, frame count 3300
# running reward: -101435.90 at episode 390, frame count 3400
# running reward: -98350.00 at episode 400, frame count 3500
# running reward: -94878.05 at episode 410, frame count 3600
# running reward: -96571.43 at episode 420, frame count 3700
# running reward: -98976.74 at episode 430, frame count 3800
# running reward: -100000.00 at episode 440, frame count 3900
# running reward: -100382.98 at episode 470, frame count 4100
# running reward: -98333.33 at episode 480, frame count 4200
# running reward: -98204.08 at episode 490, frame count 4300
# running reward: -96600.00 at episode 500, frame count 4400
# running reward: -92038.46 at episode 520, frame count 4500
# running reward: -91358.49 at episode 530, frame count 4600
# running reward: -91407.41 at episode 540, frame count 4700
# running reward: -90509.09 at episode 550, frame count 4800
# running reward: -91965.52 at episode 580, frame count 5000
# running reward: -91965.52 at episode 580, frame count 5100
# running reward: -93728.81 at episode 590, frame count 5200
# running reward: -93728.81 at episode 590, frame count 5300
# running reward: -97639.34 at episode 610, frame count 5400
# running reward: -95523.81 at episode 630, frame count 5500
# running reward: -95523.81 at episode 630, frame count 5600
# running reward: -96687.50 at episode 640, frame count 5700
# running reward: -97046.15 at episode 650, frame count 5800
# running reward: -97046.15 at episode 650, frame count 5900
# running reward: -99909.09 at episode 660, frame count 6000
# running reward: -97761.19 at episode 670, frame count 6100
# running reward: -97761.19 at episode 670, frame count 6200
# running reward: -97761.19 at episode 670, frame count 6300
# running reward: -97761.19 at episode 670, frame count 6400
# running reward: -109676.47 at episode 680, frame count 6500
# running reward: -109676.47 at episode 680, frame count 6600
# running reward: -113014.49 at episode 690, frame count 6700
# running reward: -112563.38 at episode 710, frame count 6900
# running reward: -110054.79 at episode 730, frame count 7000
# running reward: -110054.79 at episode 730, frame count 7100
# running reward: -110054.79 at episode 730, frame count 7200
# running reward: -115054.05 at episode 740, frame count 7300
# running reward: -116157.89 at episode 760, frame count 7400
# running reward: -115324.68 at episode 770, frame count 7500
# running reward: -115324.68 at episode 770, frame count 7600
# running reward: -116692.31 at episode 780, frame count 7700
# running reward: -116692.31 at episode 780, frame count 7800
# running reward: -116692.31 at episode 780, frame count 7900
# running reward: -121215.19 at episode 790, frame count 8000
# running reward: -121215.19 at episode 790, frame count 8100
# running reward: -120975.00 at episode 800, frame count 8200
# running reward: -121901.23 at episode 810, frame count 8300
# running reward: -121243.90 at episode 820, frame count 8400
# running reward: -122698.80 at episode 830, frame count 8500
# running reward: -122698.80 at episode 830, frame count 8600
# running reward: -124214.29 at episode 840, frame count 8700
# running reward: -123882.35 at episode 850, frame count 8800
# running reward: -123930.23 at episode 860, frame count 8900
# running reward: -123816.09 at episode 870, frame count 9000
# running reward: -121886.36 at episode 880, frame count 9100
# running reward: -121730.34 at episode 890, frame count 9200
# running reward: -121730.34 at episode 890, frame count 9300
# running reward: -121777.78 at episode 900, frame count 9400
# running reward: -120923.08 at episode 910, frame count 9500
# running reward: -120923.08 at episode 910, frame count 9600
# running reward: -119255.32 at episode 940, frame count 9800
# running reward: -117326.32 at episode 950, frame count 9900
# running reward: -117326.32 at episode 950, frame count 10000
# running reward: -117326.32 at episode 950, frame count 10100
# running reward: -117326.32 at episode 950, frame count 10200
# running reward: -122020.83 at episode 960, frame count 10300
# running reward: -122824.74 at episode 970, frame count 10400
# running reward: -120755.10 at episode 980, frame count 10500
# running reward: -121535.35 at episode 990, frame count 10600
# running reward: -121535.35 at episode 990, frame count 10700
# running reward: -122160.00 at episode 1000, frame count 10800
# running reward: -122160.00 at episode 1000, frame count 10900
# running reward: -122160.00 at episode 1000, frame count 11000
# running reward: -122160.00 at episode 1000, frame count 11100
# running reward: -122020.00 at episode 1010, frame count 11200
# running reward: -122740.00 at episode 1020, frame count 11300
# running reward: -123620.00 at episode 1030, frame count 11400
# running reward: -125120.00 at episode 1040, frame count 11500
# running reward: -125960.00 at episode 1050, frame count 11600
# running reward: -125960.00 at episode 1050, frame count 11700
# running reward: -129000.00 at episode 1060, frame count 11800
# running reward: -129000.00 at episode 1060, frame count 11900
# running reward: -130300.00 at episode 1080, frame count 12000
# running reward: -132180.00 at episode 1090, frame count 12100
# running reward: -132180.00 at episode 1090, frame count 12200
# running reward: -133060.00 at episode 1100, frame count 12300
# running reward: -135560.00 at episode 1110, frame count 12400
# running reward: -138480.00 at episode 1120, frame count 12500
# running reward: -138060.00 at episode 1130, frame count 12600
# running reward: -134780.00 at episode 1140, frame count 12700
# running reward: -134780.00 at episode 1140, frame count 12800
# running reward: -130620.00 at episode 1150, frame count 12900
# running reward: -129580.00 at episode 1160, frame count 13000
# running reward: -132020.00 at episode 1170, frame count 13100
# running reward: -132560.00 at episode 1180, frame count 13200
# running reward: -133800.00 at episode 1190, frame count 13300
# running reward: -135840.00 at episode 1200, frame count 13400
# running reward: -137780.00 at episode 1210, frame count 13500
# running reward: -137200.00 at episode 1220, frame count 13600
# running reward: -139040.00 at episode 1230, frame count 13700
# running reward: -140800.00 at episode 1240, frame count 13800
# running reward: -138360.00 at episode 1250, frame count 13900
# running reward: -138360.00 at episode 1250, frame count 14000
# running reward: -137540.00 at episode 1260, frame count 14100
# running reward: -138980.00 at episode 1290, frame count 14200
# running reward: -139340.00 at episode 1300, frame count 14300
# running reward: -139840.00 at episode 1310, frame count 14400
# running reward: -139840.00 at episode 1310, frame count 14500
# running reward: -139840.00 at episode 1310, frame count 14600
# running reward: -141420.00 at episode 1320, frame count 14700
# running reward: -140600.00 at episode 1330, frame count 14800
# running reward: -143240.00 at episode 1340, frame count 14900
# running reward: -145580.00 at episode 1350, frame count 15000
# running reward: -146940.00 at episode 1360, frame count 15100
# running reward: -146940.00 at episode 1360, frame count 15200
# running reward: -146060.00 at episode 1370, frame count 15300
# running reward: -146900.00 at episode 1380, frame count 15400
# running reward: -146320.00 at episode 1390, frame count 15500
# running reward: -148260.00 at episode 1400, frame count 15600
# running reward: -150240.00 at episode 1410, frame count 15700
# running reward: -149980.00 at episode 1420, frame count 15800
# running reward: -151040.00 at episode 1430, frame count 15900
# running reward: -152000.00 at episode 1440, frame count 16000
# running reward: -149040.00 at episode 1450, frame count 16100
# running reward: -147460.00 at episode 1460, frame count 16200
# running reward: -147060.00 at episode 1470, frame count 16300
# running reward: -149440.00 at episode 1490, frame count 16400
# running reward: -149440.00 at episode 1490, frame count 16500
# running reward: -151700.00 at episode 1500, frame count 16600
# running reward: -151280.00 at episode 1510, frame count 16700
# running reward: -151280.00 at episode 1510, frame count 16800
# running reward: -153680.00 at episode 1520, frame count 16900
# running reward: -153680.00 at episode 1520, frame count 17000
# running reward: -153680.00 at episode 1520, frame count 17100
# running reward: -159440.00 at episode 1530, frame count 17200
# running reward: -159220.00 at episode 1540, frame count 17300
# running reward: -160060.00 at episode 1550, frame count 17400
# running reward: -158780.00 at episode 1560, frame count 17500
# running reward: -160300.00 at episode 1570, frame count 17600
# running reward: -160320.00 at episode 1580, frame count 17700
# running reward: -160900.00 at episode 1590, frame count 17800
# running reward: -158580.00 at episode 1610, frame count 17900
# running reward: -159660.00 at episode 1630, frame count 18000
# running reward: -159980.00 at episode 1640, frame count 18100
# running reward: -156880.00 at episode 1660, frame count 18200
# running reward: -158260.00 at episode 1670, frame count 18300
# running reward: -151160.00 at episode 1680, frame count 18400
# running reward: -151160.00 at episode 1680, frame count 18500
# running reward: -151160.00 at episode 1680, frame count 18600
# running reward: -150940.00 at episode 1700, frame count 18700
# running reward: -149480.00 at episode 1710, frame count 18800
# running reward: -149780.00 at episode 1730, frame count 18900
# running reward: -149780.00 at episode 1730, frame count 19000
# running reward: -144780.00 at episode 1750, frame count 19100
# running reward: -146680.00 at episode 1760, frame count 19300
# running reward: -147740.00 at episode 1770, frame count 19400
# running reward: -147740.00 at episode 1770, frame count 19500
# running reward: -143300.00 at episode 1790, frame count 19600
# running reward: -142500.00 at episode 1810, frame count 19700
# running reward: -141040.00 at episode 1830, frame count 19800
# running reward: -139600.00 at episode 1840, frame count 19900
# running reward: -138700.00 at episode 1850, frame count 20000
# running reward: -140120.00 at episode 1860, frame count 20100
# running reward: -139980.00 at episode 1870, frame count 20200
# running reward: -138060.00 at episode 1890, frame count 20300
# running reward: -138060.00 at episode 1890, frame count 20400
# running reward: -138200.00 at episode 1900, frame count 20500
# running reward: -139620.00 at episode 1910, frame count 20600
# running reward: -139620.00 at episode 1910, frame count 20700
# running reward: -141680.00 at episode 1920, frame count 20800
# running reward: -141680.00 at episode 1920, frame count 20900
# running reward: -143820.00 at episode 1930, frame count 21000
# running reward: -149040.00 at episode 1950, frame count 21100
# running reward: -149040.00 at episode 1950, frame count 21200
# running reward: -145880.00 at episode 1960, frame count 21300
# running reward: -145360.00 at episode 1970, frame count 21400
# running reward: -148220.00 at episode 1980, frame count 21500
# running reward: -148960.00 at episode 1990, frame count 21600
# running reward: -143080.00 at episode 2010, frame count 21700
# running reward: -143080.00 at episode 2010, frame count 21800
# running reward: -144860.00 at episode 2020, frame count 21900
# running reward: -144880.00 at episode 2030, frame count 22000
# running reward: -144520.00 at episode 2040, frame count 22100
# running reward: -145760.00 at episode 2050, frame count 22200
# running reward: -143960.00 at episode 2070, frame count 22300
# running reward: -143880.00 at episode 2080, frame count 22400
# running reward: -143460.00 at episode 2090, frame count 22500
# running reward: -143460.00 at episode 2090, frame count 22600
# running reward: -143400.00 at episode 2100, frame count 22700
# running reward: -138120.00 at episode 2120, frame count 22800
# running reward: -138120.00 at episode 2120, frame count 22900
# running reward: -144060.00 at episode 2130, frame count 23000
# running reward: -146320.00 at episode 2140, frame count 23100
# running reward: -147380.00 at episode 2150, frame count 23200
# running reward: -149820.00 at episode 2160, frame count 23300
# running reward: -150500.00 at episode 2170, frame count 23400
# running reward: -150500.00 at episode 2170, frame count 23500
# running reward: -152080.00 at episode 2180, frame count 23600
# running reward: -148140.00 at episode 2200, frame count 23700
# running reward: -147200.00 at episode 2220, frame count 23800
# running reward: -144920.00 at episode 2240, frame count 23900
# running reward: -143300.00 at episode 2260, frame count 24000
# running reward: -143040.00 at episode 2280, frame count 24100
# running reward: -144500.00 at episode 2300, frame count 24200
# running reward: -143240.00 at episode 2310, frame count 24300
# running reward: -142420.00 at episode 2330, frame count 24400
# running reward: -138360.00 at episode 2360, frame count 24500
# running reward: -137660.00 at episode 2380, frame count 24600
# running reward: -137200.00 at episode 2390, frame count 24700
# running reward: -137500.00 at episode 2410, frame count 24800
# running reward: -134220.00 at episode 2430, frame count 24900
# running reward: -132380.00 at episode 2450, frame count 25000
# running reward: -136060.00 at episode 2470, frame count 25100
# running reward: -135860.00 at episode 2480, frame count 25200
# running reward: -134360.00 at episode 2500, frame count 25300
# running reward: -135020.00 at episode 2520, frame count 25400
# running reward: -129360.00 at episode 2540, frame count 25500
# running reward: -131320.00 at episode 2560, frame count 25600
# running reward: -130320.00 at episode 2570, frame count 25700
# running reward: -129200.00 at episode 2590, frame count 25900
# running reward: -129200.00 at episode 2600, frame count 26000
# running reward: -130980.00 at episode 2610, frame count 26100
# running reward: -130500.00 at episode 2620, frame count 26200
# running reward: -130680.00 at episode 2630, frame count 26300
# running reward: -130680.00 at episode 2630, frame count 26400
# running reward: -128120.00 at episode 2640, frame count 26500
# running reward: -128120.00 at episode 2640, frame count 26600
# running reward: -128220.00 at episode 2650, frame count 26700
# running reward: -131140.00 at episode 2670, frame count 26800
# running reward: -131600.00 at episode 2680, frame count 26900
# running reward: -130720.00 at episode 2690, frame count 27000
# running reward: -130940.00 at episode 2700, frame count 27100
# running reward: -132360.00 at episode 2720, frame count 27200
# running reward: -134060.00 at episode 2730, frame count 27300
# running reward: -134560.00 at episode 2740, frame count 27400
# running reward: -135560.00 at episode 2750, frame count 27500
# running reward: -132060.00 at episode 2760, frame count 27600
# running reward: -132460.00 at episode 2770, frame count 27700
# running reward: -131420.00 at episode 2780, frame count 27800
# running reward: -133700.00 at episode 2790, frame count 27900
# running reward: -134900.00 at episode 2800, frame count 28000
# running reward: -134900.00 at episode 2800, frame count 28100
# running reward: -137900.00 at episode 2810, frame count 28200
# running reward: -139840.00 at episode 2820, frame count 28300
# running reward: -139020.00 at episode 2830, frame count 28400
# running reward: -139760.00 at episode 2840, frame count 28500
# running reward: -141360.00 at episode 2850, frame count 28600
# running reward: -139780.00 at episode 2880, frame count 28700
# running reward: -140660.00 at episode 2890, frame count 28800
# running reward: -137160.00 at episode 2920, frame count 28900
# running reward: -132620.00 at episode 2940, frame count 29000
# running reward: -129620.00 at episode 2960, frame count 29100
# running reward: -128200.00 at episode 2980, frame count 29200
# running reward: -126020.00 at episode 3000, frame count 29300
# running reward: -123120.00 at episode 3020, frame count 29400
# running reward: -122860.00 at episode 3030, frame count 29500
# running reward: -123780.00 at episode 3040, frame count 29600
# running reward: -123780.00 at episode 3040, frame count 29700
# running reward: -123780.00 at episode 3040, frame count 29800
# running reward: -121080.00 at episode 3050, frame count 29900
# running reward: -120540.00 at episode 3060, frame count 30000
# running reward: -121720.00 at episode 3070, frame count 30100
# running reward: -120160.00 at episode 3090, frame count 30200
# running reward: -120160.00 at episode 3090, frame count 30300
# running reward: -120160.00 at episode 3090, frame count 30400
# running reward: -122440.00 at episode 3100, frame count 30500
# running reward: -123000.00 at episode 3110, frame count 30700
# running reward: -125720.00 at episode 3120, frame count 30800
# running reward: -125720.00 at episode 3120, frame count 30900
# running reward: -125720.00 at episode 3120, frame count 31000
# running reward: -117740.00 at episode 3130, frame count 31100
# running reward: -118660.00 at episode 3140, frame count 31200
# running reward: -117740.00 at episode 3150, frame count 31300
# running reward: -118760.00 at episode 3160, frame count 31400
# running reward: -116740.00 at episode 3170, frame count 31500
# running reward: -116740.00 at episode 3170, frame count 31600
# running reward: -113880.00 at episode 3180, frame count 31700
# running reward: -115820.00 at episode 3190, frame count 31800
# running reward: -115820.00 at episode 3190, frame count 31900
# running reward: -115820.00 at episode 3190, frame count 32000
# running reward: -117740.00 at episode 3210, frame count 32100
# running reward: -118140.00 at episode 3220, frame count 32200
# running reward: -117220.00 at episode 3240, frame count 32300
# running reward: -117220.00 at episode 3240, frame count 32400
# running reward: -120800.00 at episode 3250, frame count 32500
# running reward: -121340.00 at episode 3260, frame count 32600
# running reward: -121120.00 at episode 3280, frame count 32700
# running reward: -119900.00 at episode 3290, frame count 32800
# running reward: -120060.00 at episode 3300, frame count 32900
# running reward: -123160.00 at episode 3310, frame count 33000
# running reward: -121980.00 at episode 3320, frame count 33100
# running reward: -120420.00 at episode 3330, frame count 33200
# running reward: -123440.00 at episode 3340, frame count 33300
# running reward: -124800.00 at episode 3350, frame count 33400
# running reward: -125960.00 at episode 3360, frame count 33500
# running reward: -127380.00 at episode 3370, frame count 33600
# running reward: -130420.00 at episode 3380, frame count 33700
# running reward: -132040.00 at episode 3390, frame count 33800
# running reward: -130720.00 at episode 3410, frame count 33900
# running reward: -130160.00 at episode 3440, frame count 34000
# running reward: -131260.00 at episode 3460, frame count 34100
# running reward: -131060.00 at episode 3470, frame count 34200
# running reward: -128340.00 at episode 3480, frame count 34300
# running reward: -127980.00 at episode 3490, frame count 34400
# running reward: -127980.00 at episode 3490, frame count 34500
# running reward: -127980.00 at episode 3490, frame count 34600
# running reward: -127980.00 at episode 3490, frame count 34700
# running reward: -133560.00 at episode 3510, frame count 34800
# running reward: -131680.00 at episode 3550, frame count 35000
# running reward: -132580.00 at episode 3560, frame count 35100
# running reward: -132720.00 at episode 3570, frame count 35200
# running reward: -132220.00 at episode 3580, frame count 35300
# running reward: -132580.00 at episode 3600, frame count 35400
# running reward: -130820.00 at episode 3620, frame count 35500
# running reward: -130380.00 at episode 3630, frame count 35600
# running reward: -130660.00 at episode 3660, frame count 35800
# running reward: -128820.00 at episode 3670, frame count 35900
# running reward: -127420.00 at episode 3680, frame count 36000
# running reward: -124740.00 at episode 3730, frame count 36200
# running reward: -122360.00 at episode 3750, frame count 36300
# running reward: -124460.00 at episode 3760, frame count 36400
# running reward: -124100.00 at episode 3780, frame count 36500
# running reward: -124100.00 at episode 3780, frame count 36600
# running reward: -118820.00 at episode 3810, frame count 36700
# running reward: -116340.00 at episode 3820, frame count 36800
# running reward: -118640.00 at episode 3830, frame count 36900
# running reward: -117040.00 at episode 3840, frame count 37000
# running reward: -117000.00 at episode 3850, frame count 37100
# running reward: -119260.00 at episode 3860, frame count 37200
# running reward: -119540.00 at episode 3870, frame count 37300
# running reward: -120840.00 at episode 3890, frame count 37400
# running reward: -120300.00 at episode 3900, frame count 37500
# running reward: -122620.00 at episode 3910, frame count 37600
# running reward: -123000.00 at episode 3920, frame count 37700
# running reward: -123980.00 at episode 3930, frame count 37800
# running reward: -125680.00 at episode 3940, frame count 37900
# running reward: -128220.00 at episode 3960, frame count 38000
# running reward: -128220.00 at episode 3960, frame count 38100
# running reward: -130240.00 at episode 3970, frame count 38200
# running reward: -130260.00 at episode 3990, frame count 38300
# running reward: -130680.00 at episode 4000, frame count 38400
# running reward: -131640.00 at episode 4010, frame count 38500
# running reward: -132060.00 at episode 4020, frame count 38600
# running reward: -129660.00 at episode 4030, frame count 38700
# running reward: -129280.00 at episode 4050, frame count 38800
# running reward: -129280.00 at episode 4050, frame count 38900
# running reward: -129060.00 at episode 4060, frame count 39000
# running reward: -129360.00 at episode 4070, frame count 39100
# running reward: -133000.00 at episode 4090, frame count 39200
# running reward: -133000.00 at episode 4090, frame count 39300
# running reward: -133580.00 at episode 4100, frame count 39400
# running reward: -133580.00 at episode 4100, frame count 39500
# running reward: -130860.00 at episode 4110, frame count 39600
# running reward: -130300.00 at episode 4120, frame count 39700
# running reward: -133780.00 at episode 4140, frame count 39800
# running reward: -129020.00 at episode 4160, frame count 39900
# running reward: -130500.00 at episode 4170, frame count 40000
# running reward: -128200.00 at episode 4190, frame count 40100
# running reward: -127940.00 at episode 4210, frame count 40200
# running reward: -128940.00 at episode 4230, frame count 40300
# running reward: -129100.00 at episode 4240, frame count 40400
# running reward: -127400.00 at episode 4260, frame count 40500
# running reward: -128360.00 at episode 4270, frame count 40600
# running reward: -129940.00 at episode 4280, frame count 40700
# running reward: -129940.00 at episode 4280, frame count 40800
# running reward: -131740.00 at episode 4290, frame count 40900
# running reward: -131480.00 at episode 4300, frame count 41000
# running reward: -128220.00 at episode 4310, frame count 41100
# running reward: -129580.00 at episode 4320, frame count 41200
# running reward: -129580.00 at episode 4320, frame count 41300
# running reward: -135520.00 at episode 4330, frame count 41400
# running reward: -131520.00 at episode 4350, frame count 41500
# running reward: -127300.00 at episode 4370, frame count 41600
# running reward: -122460.00 at episode 4390, frame count 41700
# running reward: -120120.00 at episode 4410, frame count 41800
# running reward: -121100.00 at episode 4420, frame count 41900
# running reward: -122880.00 at episode 4440, frame count 42000
# running reward: -122880.00 at episode 4440, frame count 42100
# running reward: -122560.00 at episode 4460, frame count 42200
# running reward: -122440.00 at episode 4470, frame count 42300
# running reward: -125120.00 at episode 4480, frame count 42400
# running reward: -125320.00 at episode 4490, frame count 42500
# running reward: -119680.00 at episode 4500, frame count 42600
# running reward: -119680.00 at episode 4500, frame count 42700
# running reward: -120380.00 at episode 4520, frame count 42800
# running reward: -121260.00 at episode 4530, frame count 42900
# running reward: -119860.00 at episode 4550, frame count 43000
# running reward: -119860.00 at episode 4550, frame count 43100
# running reward: -120000.00 at episode 4560, frame count 43200
# running reward: -121840.00 at episode 4570, frame count 43300
# running reward: -121080.00 at episode 4580, frame count 43400
# running reward: -118940.00 at episode 4600, frame count 43500
# running reward: -120480.00 at episode 4620, frame count 43600
# running reward: -120480.00 at episode 4620, frame count 43700
# running reward: -121960.00 at episode 4640, frame count 43800
# running reward: -121940.00 at episode 4650, frame count 43900
# running reward: -122300.00 at episode 4660, frame count 44000
# running reward: -124540.00 at episode 4670, frame count 44100
# running reward: -123020.00 at episode 4690, frame count 44200
# running reward: -122040.00 at episode 4710, frame count 44300
# running reward: -120420.00 at episode 4720, frame count 44400
# running reward: -120960.00 at episode 4730, frame count 44500
# running reward: -122900.00 at episode 4740, frame count 44600
# running reward: -124380.00 at episode 4750, frame count 44700
# running reward: -125340.00 at episode 4760, frame count 44800
# running reward: -126000.00 at episode 4770, frame count 44900
# running reward: -124540.00 at episode 4780, frame count 45000
# running reward: -123260.00 at episode 4790, frame count 45100
# running reward: -124980.00 at episode 4800, frame count 45200
# running reward: -124980.00 at episode 4810, frame count 45300
# running reward: -124540.00 at episode 4820, frame count 45400
# running reward: -122400.00 at episode 4840, frame count 45500
# running reward: -123240.00 at episode 4850, frame count 45600
# running reward: -123500.00 at episode 4860, frame count 45700
# running reward: -125660.00 at episode 4870, frame count 45800
# running reward: -125660.00 at episode 4870, frame count 45900
# running reward: -125660.00 at episode 4870, frame count 46000
# running reward: -124240.00 at episode 4880, frame count 46100
# running reward: -124180.00 at episode 4900, frame count 46200
# running reward: -122600.00 at episode 4910, frame count 46300
# running reward: -122600.00 at episode 4910, frame count 46400
# running reward: -122220.00 at episode 4920, frame count 46500
# running reward: -121040.00 at episode 4940, frame count 46600
# running reward: -119600.00 at episode 4960, frame count 46700
# running reward: -117160.00 at episode 4970, frame count 46800
# running reward: -117160.00 at episode 4970, frame count 46900
# running reward: -120200.00 at episode 4980, frame count 47000
# running reward: -121860.00 at episode 4990, frame count 47100
# running reward: -121700.00 at episode 5000, frame count 47200
# running reward: -121700.00 at episode 5000, frame count 47300
# running reward: -124260.00 at episode 5010, frame count 47400
# running reward: -125200.00 at episode 5030, frame count 47500
# running reward: -125900.00 at episode 5040, frame count 47600
# running reward: -126080.00 at episode 5050, frame count 47700
# running reward: -125660.00 at episode 5060, frame count 47800
# running reward: -125540.00 at episode 5070, frame count 47900
# running reward: -123960.00 at episode 5080, frame count 48000
# running reward: -121080.00 at episode 5090, frame count 48100
# running reward: -117540.00 at episode 5100, frame count 48200
# running reward: -119340.00 at episode 5110, frame count 48300
# running reward: -119340.00 at episode 5110, frame count 48400
# running reward: -117080.00 at episode 5120, frame count 48500
# running reward: -114700.00 at episode 5130, frame count 48600
# running reward: -115500.00 at episode 5140, frame count 48700
# running reward: -118360.00 at episode 5150, frame count 48800
# running reward: -119260.00 at episode 5160, frame count 48900
# running reward: -119260.00 at episode 5160, frame count 49000
# running reward: -119940.00 at episode 5170, frame count 49100
# running reward: -118860.00 at episode 5180, frame count 49200
# running reward: -120220.00 at episode 5190, frame count 49300
# running reward: -120740.00 at episode 5200, frame count 49400
# running reward: -121260.00 at episode 5210, frame count 49500
# running reward: -119780.00 at episode 5220, frame count 49600
# running reward: -119040.00 at episode 5230, frame count 49700
# running reward: -120220.00 at episode 5240, frame count 49800
# running reward: -121300.00 at episode 5250, frame count 49900
# running reward: -121660.00 at episode 5260, frame count 50000
# running reward: -121720.00 at episode 5270, frame count 50100
# running reward: -121300.00 at episode 5280, frame count 50200
# running reward: -117640.00 at episode 5290, frame count 50300
# running reward: -117640.00 at episode 5290, frame count 50400
# running reward: -120880.00 at episode 5300, frame count 50500
# running reward: -120880.00 at episode 5300, frame count 50600
# running reward: -120820.00 at episode 5310, frame count 50700
# running reward: -120820.00 at episode 5310, frame count 50800
# running reward: -119200.00 at episode 5320, frame count 50900
# running reward: -114200.00 at episode 5330, frame count 51000
# running reward: -112720.00 at episode 5340, frame count 51100
# running reward: -112640.00 at episode 5360, frame count 51200
# running reward: -115420.00 at episode 5380, frame count 51300
# running reward: -115100.00 at episode 5390, frame count 51400
# running reward: -115100.00 at episode 5390, frame count 51500
# running reward: -118660.00 at episode 5400, frame count 51600
# running reward: -118660.00 at episode 5400, frame count 51700
# running reward: -118660.00 at episode 5400, frame count 51800
# running reward: -118660.00 at episode 5400, frame count 51900
# running reward: -118660.00 at episode 5400, frame count 52000
# running reward: -118660.00 at episode 5400, frame count 52100
# running reward: -134880.00 at episode 5410, frame count 52200
# running reward: -134880.00 at episode 5410, frame count 52300
# running reward: -138100.00 at episode 5420, frame count 52400
# running reward: -138920.00 at episode 5430, frame count 52500
# running reward: -139060.00 at episode 5440, frame count 52600
# running reward: -138320.00 at episode 5450, frame count 52700
# running reward: -138320.00 at episode 5450, frame count 52800
# running reward: -139860.00 at episode 5460, frame count 52900
# running reward: -142480.00 at episode 5470, frame count 53000
# running reward: -140960.00 at episode 5480, frame count 53100
# running reward: -142040.00 at episode 5490, frame count 53200
# running reward: -144300.00 at episode 5500, frame count 53300
# running reward: -143520.00 at episode 5510, frame count 53400
# running reward: -143800.00 at episode 5520, frame count 53500
# running reward: -144980.00 at episode 5530, frame count 53600
# running reward: -149540.00 at episode 5550, frame count 53700
# running reward: -150260.00 at episode 5560, frame count 53800
# running reward: -149960.00 at episode 5570, frame count 53900
# running reward: -148860.00 at episode 5590, frame count 54000
# running reward: -147900.00 at episode 5610, frame count 54100
# running reward: -147900.00 at episode 5610, frame count 54200
# running reward: -147900.00 at episode 5610, frame count 54300
# running reward: -147900.00 at episode 5610, frame count 54400
# running reward: -150300.00 at episode 5620, frame count 54500
# running reward: -150300.00 at episode 5620, frame count 54600
# running reward: -151000.00 at episode 5630, frame count 54700
# running reward: -150360.00 at episode 5650, frame count 54800
# running reward: -147900.00 at episode 5670, frame count 54900
# running reward: -147900.00 at episode 5670, frame count 55000
# running reward: -147900.00 at episode 5670, frame count 55100
# running reward: -148360.00 at episode 5680, frame count 55200
# running reward: -149820.00 at episode 5690, frame count 55300
# running reward: -149820.00 at episode 5690, frame count 55400
# running reward: -152320.00 at episode 5700, frame count 55500
# running reward: -155320.00 at episode 5720, frame count 55600
# running reward: -156020.00 at episode 5730, frame count 55700
# running reward: -153280.00 at episode 5750, frame count 55800
# running reward: -149160.00 at episode 5760, frame count 55900
# running reward: -146500.00 at episode 5770, frame count 56000
# running reward: -148740.00 at episode 5780, frame count 56100
# running reward: -147260.00 at episode 5790, frame count 56200
# running reward: -147660.00 at episode 5800, frame count 56300
# running reward: -150740.00 at episode 5820, frame count 56500
# running reward: -151180.00 at episode 5830, frame count 56600
# running reward: -148820.00 at episode 5840, frame count 56700
# running reward: -147460.00 at episode 5850, frame count 56800
# running reward: -146760.00 at episode 5860, frame count 56900
# running reward: -143900.00 at episode 5870, frame count 57000
# running reward: -145640.00 at episode 5890, frame count 57100
# running reward: -145680.00 at episode 5900, frame count 57200
# running reward: -146400.00 at episode 5910, frame count 57300
# running reward: -147200.00 at episode 5920, frame count 57400
# running reward: -147020.00 at episode 5930, frame count 57500
# running reward: -144780.00 at episode 5950, frame count 57600
# running reward: -144780.00 at episode 5950, frame count 57700
# running reward: -144780.00 at episode 5950, frame count 57800
# running reward: -149900.00 at episode 5970, frame count 57900
# running reward: -149900.00 at episode 5970, frame count 58000
# running reward: -145960.00 at episode 5980, frame count 58100
# running reward: -144360.00 at episode 5990, frame count 58200
# running reward: -137420.00 at episode 6020, frame count 58300
# running reward: -135080.00 at episode 6040, frame count 58400
# running reward: -135080.00 at episode 6040, frame count 58500
# running reward: -137460.00 at episode 6050, frame count 58600
# running reward: -137460.00 at episode 6050, frame count 58700
# running reward: -138020.00 at episode 6060, frame count 58800
# running reward: -139500.00 at episode 6070, frame count 58900
# running reward: -141000.00 at episode 6080, frame count 59000
# running reward: -143300.00 at episode 6090, frame count 59100
# running reward: -143300.00 at episode 6090, frame count 59200
# running reward: -144340.00 at episode 6100, frame count 59300
# running reward: -143920.00 at episode 6110, frame count 59400
# running reward: -146660.00 at episode 6120, frame count 59500
# running reward: -148060.00 at episode 6130, frame count 59600
# running reward: -146800.00 at episode 6140, frame count 59700
# running reward: -145780.00 at episode 6150, frame count 59800
# running reward: -143500.00 at episode 6170, frame count 59900
# running reward: -143500.00 at episode 6170, frame count 60000
# running reward: -148000.00 at episode 6180, frame count 60100
# running reward: -148300.00 at episode 6190, frame count 60200
# running reward: -148660.00 at episode 6210, frame count 60400
# running reward: -151720.00 at episode 6230, frame count 60500
# running reward: -152620.00 at episode 6240, frame count 60600
# running reward: -152200.00 at episode 6250, frame count 60700
# running reward: -152640.00 at episode 6260, frame count 60800
# running reward: -152900.00 at episode 6270, frame count 60900
# running reward: -154560.00 at episode 6280, frame count 61000
# running reward: -157100.00 at episode 6290, frame count 61100
# running reward: -157100.00 at episode 6290, frame count 61200
# running reward: -157100.00 at episode 6290, frame count 61300
# running reward: -157100.00 at episode 6290, frame count 61400
# running reward: -153540.00 at episode 6300, frame count 61500
# running reward: -153540.00 at episode 6300, frame count 61600
# running reward: -153120.00 at episode 6310, frame count 61700
# running reward: -153580.00 at episode 6320, frame count 61800
# running reward: -155240.00 at episode 6330, frame count 61900
# running reward: -155240.00 at episode 6330, frame count 62000
# running reward: -158500.00 at episode 6340, frame count 62100
# running reward: -158020.00 at episode 6360, frame count 62200
# running reward: -157000.00 at episode 6370, frame count 62300
# running reward: -157000.00 at episode 6370, frame count 62400
# running reward: -155780.00 at episode 6380, frame count 62500
# running reward: -155780.00 at episode 6380, frame count 62600
# running reward: -155780.00 at episode 6380, frame count 62700
# running reward: -153300.00 at episode 6400, frame count 62800
# running reward: -131620.00 at episode 6430, frame count 62900
# running reward: -131120.00 at episode 6440, frame count 63000
# running reward: -128820.00 at episode 6470, frame count 63100
# running reward: -130000.00 at episode 6480, frame count 63200
# running reward: -126440.00 at episode 6500, frame count 63300
# running reward: -123720.00 at episode 6520, frame count 63400
# running reward: -123200.00 at episode 6530, frame count 63500
# running reward: -123180.00 at episode 6540, frame count 63600
# running reward: -123360.00 at episode 6550, frame count 63700
# running reward: -122740.00 at episode 6560, frame count 63800
# running reward: -121120.00 at episode 6570, frame count 63900
# running reward: -121120.00 at episode 6570, frame count 64000
# running reward: -126580.00 at episode 6580, frame count 64100
# running reward: -126580.00 at episode 6580, frame count 64200
# running reward: -126580.00 at episode 6580, frame count 64300
# running reward: -124560.00 at episode 6590, frame count 64400
# running reward: -126120.00 at episode 6600, frame count 64500
# running reward: -127920.00 at episode 6610, frame count 64600
# running reward: -126060.00 at episode 6620, frame count 64700
# running reward: -121560.00 at episode 6640, frame count 64800
# running reward: -121560.00 at episode 6640, frame count 64900
# running reward: -123920.00 at episode 6650, frame count 65000
# running reward: -124940.00 at episode 6660, frame count 65100
# running reward: -126540.00 at episode 6670, frame count 65200
# running reward: -127920.00 at episode 6680, frame count 65300
# running reward: -127920.00 at episode 6690, frame count 65400
# running reward: -127140.00 at episode 6700, frame count 65500
# running reward: -127060.00 at episode 6720, frame count 65600
# running reward: -127060.00 at episode 6720, frame count 65700
# running reward: -129740.00 at episode 6730, frame count 65800
# running reward: -131120.00 at episode 6740, frame count 65900
# running reward: -132520.00 at episode 6750, frame count 66000
# running reward: -134000.00 at episode 6760, frame count 66100
# running reward: -132380.00 at episode 6780, frame count 66200
# running reward: -132380.00 at episode 6780, frame count 66300
# running reward: -134540.00 at episode 6790, frame count 66400
# running reward: -130480.00 at episode 6810, frame count 66500
# running reward: -130480.00 at episode 6810, frame count 66600
# running reward: -130180.00 at episode 6820, frame count 66700
# running reward: -129860.00 at episode 6830, frame count 66800
# running reward: -132600.00 at episode 6850, frame count 66900
# running reward: -131240.00 at episode 6860, frame count 67000
# running reward: -131240.00 at episode 6860, frame count 67100
# running reward: -134340.00 at episode 6870, frame count 67200
# running reward: -136840.00 at episode 6880, frame count 67300
# running reward: -137180.00 at episode 6890, frame count 67400
# running reward: -133420.00 at episode 6900, frame count 67500
# running reward: -132700.00 at episode 6910, frame count 67600
# running reward: -132540.00 at episode 6920, frame count 67700
# running reward: -131420.00 at episode 6940, frame count 67800
# running reward: -126160.00 at episode 6960, frame count 67900
# running reward: -126880.00 at episode 6990, frame count 68000
# running reward: -129700.00 at episode 7010, frame count 68100
# running reward: -130860.00 at episode 7020, frame count 68200
# running reward: -132600.00 at episode 7030, frame count 68300
# running reward: -132360.00 at episode 7040, frame count 68400
# running reward: -132360.00 at episode 7040, frame count 68500
# running reward: -133020.00 at episode 7050, frame count 68600
# running reward: -133760.00 at episode 7060, frame count 68700
# running reward: -132820.00 at episode 7070, frame count 68800
# running reward: -131940.00 at episode 7090, frame count 68900
# running reward: -130940.00 at episode 7100, frame count 69000
# running reward: -128200.00 at episode 7120, frame count 69100
# running reward: -128760.00 at episode 7140, frame count 69200
# running reward: -129160.00 at episode 7160, frame count 69300
# running reward: -130040.00 at episode 7170, frame count 69400
# running reward: -128220.00 at episode 7180, frame count 69500
# running reward: -126840.00 at episode 7190, frame count 69600
# running reward: -124240.00 at episode 7200, frame count 69700
# running reward: -124240.00 at episode 7200, frame count 69800
# running reward: -124240.00 at episode 7200, frame count 69900
# running reward: -124240.00 at episode 7200, frame count 70000
# running reward: -124240.00 at episode 7200, frame count 70100
# running reward: -124240.00 at episode 7200, frame count 70200
# running reward: -124240.00 at episode 7200, frame count 70300
# running reward: -124240.00 at episode 7200, frame count 70400
# running reward: -126060.00 at episode 7210, frame count 70500
# running reward: -125600.00 at episode 7220, frame count 70600
# running reward: -125600.00 at episode 7220, frame count 70700
# running reward: -126840.00 at episode 7230, frame count 70800
# running reward: -126200.00 at episode 7240, frame count 70900
# running reward: -126580.00 at episode 7250, frame count 71000
# running reward: -126300.00 at episode 7260, frame count 71100
# running reward: -124680.00 at episode 7270, frame count 71200
# running reward: -121960.00 at episode 7280, frame count 71300
# running reward: -122760.00 at episode 7290, frame count 71400
# running reward: -124080.00 at episode 7300, frame count 71500
# running reward: -124080.00 at episode 7300, frame count 71600
# running reward: -130700.00 at episode 7320, frame count 71700
# running reward: -129960.00 at episode 7330, frame count 71800
# running reward: -128780.00 at episode 7340, frame count 71900
# running reward: -130920.00 at episode 7350, frame count 72000
# running reward: -132720.00 at episode 7360, frame count 72100
# running reward: -135900.00 at episode 7370, frame count 72200
# running reward: -135900.00 at episode 7370, frame count 72300
# running reward: -138220.00 at episode 7380, frame count 72400
# running reward: -138220.00 at episode 7380, frame count 72500
# running reward: -140860.00 at episode 7390, frame count 72600
# running reward: -142440.00 at episode 7400, frame count 72700
# running reward: -142440.00 at episode 7400, frame count 72800
# running reward: -142000.00 at episode 7410, frame count 72900
# running reward: -143760.00 at episode 7420, frame count 73000
# running reward: -144360.00 at episode 7430, frame count 73100
# running reward: -145640.00 at episode 7440, frame count 73200
# running reward: -142200.00 at episode 7450, frame count 73300
# running reward: -141440.00 at episode 7470, frame count 73400
# running reward: -139580.00 at episode 7490, frame count 73500
# running reward: -140420.00 at episode 7500, frame count 73600
# running reward: -142500.00 at episode 7510, frame count 73700
# running reward: -145020.00 at episode 7520, frame count 73800
# running reward: -146120.00 at episode 7530, frame count 73900
# running reward: -145700.00 at episode 7540, frame count 74000
# running reward: -144880.00 at episode 7550, frame count 74100
# running reward: -145520.00 at episode 7560, frame count 74200
# running reward: -144720.00 at episode 7570, frame count 74300
# running reward: -144720.00 at episode 7570, frame count 74400
# running reward: -139640.00 at episode 7580, frame count 74500
# running reward: -143260.00 at episode 7590, frame count 74600
# running reward: -144220.00 at episode 7600, frame count 74700
# running reward: -144100.00 at episode 7610, frame count 74800
# running reward: -143820.00 at episode 7620, frame count 74900
# running reward: -143820.00 at episode 7620, frame count 75000
# running reward: -145660.00 at episode 7630, frame count 75100
# running reward: -145660.00 at episode 7630, frame count 75200
# running reward: -143240.00 at episode 7650, frame count 75300
# running reward: -141800.00 at episode 7670, frame count 75400
# running reward: -141160.00 at episode 7680, frame count 75500
# running reward: -141060.00 at episode 7690, frame count 75600
# running reward: -141080.00 at episode 7700, frame count 75700
# running reward: -141080.00 at episode 7700, frame count 75800
# running reward: -141420.00 at episode 7710, frame count 75900
# running reward: -143980.00 at episode 7720, frame count 76000
# running reward: -141480.00 at episode 7730, frame count 76100
# running reward: -141480.00 at episode 7730, frame count 76200
# running reward: -137440.00 at episode 7740, frame count 76300
# running reward: -136640.00 at episode 7750, frame count 76400
# running reward: -136480.00 at episode 7760, frame count 76500
# running reward: -139460.00 at episode 7770, frame count 76600
# running reward: -140280.00 at episode 7780, frame count 76700
# running reward: -137080.00 at episode 7800, frame count 76800
# running reward: -137080.00 at episode 7800, frame count 76900
# running reward: -141100.00 at episode 7810, frame count 77000
# running reward: -141280.00 at episode 7820, frame count 77100
# running reward: -141020.00 at episode 7830, frame count 77200
# running reward: -139940.00 at episode 7840, frame count 77300
# running reward: -142160.00 at episode 7850, frame count 77400
# running reward: -142720.00 at episode 7860, frame count 77500
# running reward: -142800.00 at episode 7870, frame count 77600
# running reward: -142800.00 at episode 7870, frame count 77700
# running reward: -140420.00 at episode 7880, frame count 77800
# running reward: -137700.00 at episode 7890, frame count 77900
# running reward: -142200.00 at episode 7900, frame count 78000
# running reward: -142920.00 at episode 7910, frame count 78100
# running reward: -144340.00 at episode 7920, frame count 78200
# running reward: -147220.00 at episode 7930, frame count 78300
# running reward: -147220.00 at episode 7930, frame count 78400
# running reward: -146780.00 at episode 7950, frame count 78500
# running reward: -146780.00 at episode 7950, frame count 78600
# running reward: -147880.00 at episode 7960, frame count 78700
# running reward: -147880.00 at episode 7960, frame count 78800
# running reward: -150200.00 at episode 7970, frame count 78900
# running reward: -152200.00 at episode 7980, frame count 79000
# running reward: -153900.00 at episode 7990, frame count 79100
# running reward: -151420.00 at episode 8010, frame count 79200
# running reward: -149400.00 at episode 8020, frame count 79300
# running reward: -148540.00 at episode 8030, frame count 79400
# running reward: -147520.00 at episode 8040, frame count 79500
# running reward: -143820.00 at episode 8050, frame count 79600
# running reward: -143820.00 at episode 8050, frame count 79700
# running reward: -143820.00 at episode 8050, frame count 79800
# running reward: -147120.00 at episode 8060, frame count 79900
# running reward: -144420.00 at episode 8070, frame count 80000
# running reward: -140720.00 at episode 8080, frame count 80100
# running reward: -140720.00 at episode 8080, frame count 80200
# running reward: -137360.00 at episode 8100, frame count 80300
# running reward: -137460.00 at episode 8120, frame count 80400
# running reward: -137620.00 at episode 8140, frame count 80500
# running reward: -136080.00 at episode 8160, frame count 80600
# running reward: -136080.00 at episode 8160, frame count 80700
# running reward: -137700.00 at episode 8170, frame count 80800
# running reward: -139360.00 at episode 8190, frame count 81000
# running reward: -139820.00 at episode 8200, frame count 81100
# running reward: -137540.00 at episode 8210, frame count 81200
# running reward: -138580.00 at episode 8230, frame count 81300
# running reward: -138960.00 at episode 8240, frame count 81400
# running reward: -138960.00 at episode 8240, frame count 81500
# running reward: -135900.00 at episode 8250, frame count 81600
# running reward: -136420.00 at episode 8260, frame count 81700
# running reward: -136420.00 at episode 8260, frame count 81800
# running reward: -138780.00 at episode 8270, frame count 81900
# running reward: -139080.00 at episode 8280, frame count 82000
# running reward: -136060.00 at episode 8300, frame count 82100
# running reward: -130760.00 at episode 8320, frame count 82200
# running reward: -130040.00 at episode 8330, frame count 82300
# running reward: -130160.00 at episode 8340, frame count 82400
# running reward: -130160.00 at episode 8340, frame count 82500
# running reward: -130160.00 at episode 8340, frame count 82600
# running reward: -132480.00 at episode 8350, frame count 82700
# running reward: -132480.00 at episode 8350, frame count 82800
# running reward: -129740.00 at episode 8370, frame count 82900
# running reward: -129740.00 at episode 8370, frame count 83000
# running reward: -129740.00 at episode 8370, frame count 83100
# running reward: -129740.00 at episode 8370, frame count 83200
# running reward: -129740.00 at episode 8370, frame count 83300
# running reward: -129740.00 at episode 8370, frame count 83400
# running reward: -129740.00 at episode 8370, frame count 83500
# running reward: -128180.00 at episode 8380, frame count 83600
# running reward: -129080.00 at episode 8390, frame count 83700
# running reward: -128900.00 at episode 8400, frame count 83800
# running reward: -128900.00 at episode 8400, frame count 83900
# running reward: -132300.00 at episode 8410, frame count 84000
# running reward: -132300.00 at episode 8410, frame count 84100
# running reward: -134980.00 at episode 8420, frame count 84200
# running reward: -135000.00 at episode 8430, frame count 84300
# running reward: -135500.00 at episode 8440, frame count 84400
# running reward: -138280.00 at episode 8450, frame count 84500
# running reward: -138600.00 at episode 8460, frame count 84600
# running reward: -142520.00 at episode 8480, frame count 84700
# running reward: -141580.00 at episode 8500, frame count 84800
# running reward: -139040.00 at episode 8530, frame count 85000
# running reward: -138320.00 at episode 8540, frame count 85100
# running reward: -134640.00 at episode 8560, frame count 85200
# running reward: -135980.00 at episode 8580, frame count 85300
# running reward: -134420.00 at episode 8590, frame count 85400
# running reward: -134420.00 at episode 8590, frame count 85500
# running reward: -133720.00 at episode 8600, frame count 85600
# running reward: -134900.00 at episode 8610, frame count 85700
# running reward: -134160.00 at episode 8620, frame count 85800
# running reward: -137560.00 at episode 8630, frame count 85900
# running reward: -137400.00 at episode 8640, frame count 86000
# running reward: -141480.00 at episode 8650, frame count 86100
# running reward: -141480.00 at episode 8650, frame count 86200
# running reward: -140240.00 at episode 8660, frame count 86300
# running reward: -141240.00 at episode 8670, frame count 86400
# running reward: -141240.00 at episode 8670, frame count 86500
# running reward: -140800.00 at episode 8680, frame count 86600
# running reward: -140280.00 at episode 8690, frame count 86700
# running reward: -139200.00 at episode 8700, frame count 86800
# running reward: -138100.00 at episode 8710, frame count 86900
# running reward: -136880.00 at episode 8730, frame count 87000
# running reward: -136880.00 at episode 8730, frame count 87100
# running reward: -140880.00 at episode 8740, frame count 87200
# running reward: -140880.00 at episode 8740, frame count 87300
# running reward: -142240.00 at episode 8750, frame count 87400
# running reward: -140620.00 at episode 8770, frame count 87500
# running reward: -140880.00 at episode 8780, frame count 87600
# running reward: -140880.00 at episode 8780, frame count 87700
# running reward: -142160.00 at episode 8790, frame count 87800
# running reward: -138900.00 at episode 8810, frame count 87900
# Traceback (most recent call last):
#   File "C:\Users\carlo\AppData\Local\Temp/ipykernel_19900/2913799929.py", line 58, in <module>
#     env.step()
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\environment.py", line 333, in step
#     outputs = self._communicator.exchange(step_input, self._poll_process)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_communicator.py", line 137, in exchange
#     self.poll_for_timeout(poll_callback)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_communicator.py", line 103, in poll_for_timeout
#     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 330, in _poll
#     return bool(wait([self], timeout))
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 879, in wait
#     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#   File "C:\Users\carlo\anaconda3\lib\multiprocessing\connection.py", line 811, in _exhaustive_wait
#     res = _winapi.WaitForMultipleObjects(L, False, timeout)
# KeyboardInterrupt
# None

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
model.layers[4].get_weights()[0].shape
# Out:
# (9, 9, 128, 128)

# %%
resh = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))

# %%
# for i in 
plt.imshow(model.layers[4].get_weights()[0][:,:,127,127])

# %%
plt.imshow(state_history[0], cmap='gray')

# %%
resh.shape
# Out:
# (16384, 9, 9, 1)

# %%
plt.imshow(resh[6, :,:,:])

# %%
env.close()
