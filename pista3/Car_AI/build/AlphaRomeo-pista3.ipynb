# %%
try:
    import mlagents
    print("ml-agents already installed")
except ImportError:
    # !python -m pip install -q mlagents==0.27.0
    print("Installed ml-agents")
# Out:
# ml-agents already installed

# %% [markdown]
# # Q-Learning Keras

# %%
import random
import tensorflow as tf
import numpy as np
import datetime
import traceback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Conv2D, Flatten, concatenate
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import Huber, LogCosh, CategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.environment import ActionTuple, BaseEnv

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Deep Q-Learning

# %%
# Configuration paramaters for the whole setup
gamma = 0.01  # Discount factor for past rewards
epsilon = 0.5  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
max_steps_per_episode = 10000
batch_size = 128
behavior_name = 'AlphaRomeo?team=0'

# %%
num_actions = 8


def create_q_model():
    with tf.device('GPU:0'):
        
        inputs = Input(shape=(84, 84, 1,))

        layer1 = Conv2D(64, 8, strides=4, activation="relu")(inputs)
        layer2 = Conv2D(128, 4, strides=2, activation="relu")(layer1)
        layer3 = Conv2D(128, 9, strides=1, activation="relu")(layer2)

        conv_output = Flatten()(layer3)
        
        conv_output_model = Model(inputs=inputs, outputs=conv_output)
        
        numerical_inputs = Input(shape=(2))
        layer4 = Dense(64, activation="relu")(numerical_inputs)
        numerical_output = Dense(128, activation="relu")(layer4)
        
        numerical_output_model = Model(inputs=numerical_inputs, outputs=numerical_output)
        
        combined = concatenate([conv_output_model.output, numerical_output_model.output])

        layer5 = Dense(512, activation="relu")(combined)
        action = Dense(num_actions, activation="linear")(layer5)

        return Model(inputs=[conv_output_model.input, numerical_output_model.input], outputs=action)


model = create_q_model()

model_target = create_q_model()

model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 84, 84, 1)]  0           []
#
#  conv2d_33 (Conv2D)             (None, 20, 20, 64)   4160        ['input_22[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 9, 9, 128)    131200      ['conv2d_33[0][0]']
#
#  input_23 (InputLayer)          [(None, 2)]          0           []
#
#  conv2d_35 (Conv2D)             (None, 1, 1, 128)    1327232     ['conv2d_34[0][0]']
#
#  dense_38 (Dense)               (None, 64)           192         ['input_23[0][0]']
#
#  flatten_11 (Flatten)           (None, 128)          0           ['conv2d_35[0][0]']
#
#  dense_39 (Dense)               (None, 128)          8320        ['dense_38[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 256)          0           ['flatten_11[0][0]',
#                                                                   'dense_39[0][0]']
#
#  dense_40 (Dense)               (None, 512)          131584      ['concatenate_2[0][0]']
#
#  dense_41 (Dense)               (None, 8)            4104        ['dense_40[0][0]']
#
# ==================================================================================================
# Total params: 1,606,792
# Trainable params: 1,606,792
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_target, show_shapes=True, show_dtype=True, show_layer_activations=True)

# %%
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

# Memórias de repetição de experiência
action_history = []
state_conv_history = []
state_num_history = []
state_conv_next_history = []
state_num_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 100
# Number of frames for exploration
epsilon_greedy_frames = 1000000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 10000
# Train the model after 4 actions
update_after_actions = 20
# How often to update the target network
update_target_network = 100
# Using huber loss for stability
loss_function =Huber()

# %%
env = UnityEnvironment(file_name="Alpha Romeo", seed=1, side_channels=[])

log_folder = 'logs/{}'.format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
writer = tf.summary.create_file_writer(log_folder)

# tf.debugging.experimental.enable_dump_debug_info(log_folder, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)

try:
    while True:  # Run until solvedloss_function
        with writer.as_default():
            env.reset()
            done = False
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            if decision_steps:
                state_conv = decision_steps[0].obs[0]
                state_num = decision_steps[0].obs[1]
            if terminal_steps:
                done = True                
                state_conv = decision_steps[0].obs[0]
                state_numerical = decision_steps[0].obs[1]
                         
            episode_reward = 0

            for timestep in range(1, max_steps_per_episode):
                # env.render(); Adding this line would show the attempts
                # of the agent in a pop up window.
                frame_count += 1

                # Use epsilon-greedy for exploration
                if  epsilon > np.random.rand(1)[0]:
                    # Take random action
                    action = random.choice([1,2,3,4,5,6,7,8])
                    
                else:
                    # Predict action Q-values
                    # From environment state
                    state_conv_tensor = tf.convert_to_tensor(state_conv)
                    state_num_tensor = tf.convert_to_tensor(state_num)
                    state_conv_tensor = tf.expand_dims(state_conv_tensor, 0)
                    state_num_tensor = tf.expand_dims(state_num_tensor, 0)
                    action_probs = model([state_conv_tensor, state_num_tensor], training=False)
                    # Take best action
                    action = action_probs[0]
                    action = int(tf.argmax(action)+1)
                    

                # Decay probability of taking random action
                epsilon -= epsilon_interval / epsilon_greedy_frames
                epsilon = max(epsilon, epsilon_min)

                # Apply the sampled action in our environment

                action_tuple = ActionTuple()
                action_tuple.add_discrete(np.array([[action]]))
                
                env.set_actions(behavior_name, action_tuple)
                
                env.step()

                decision_steps, terminal_steps = env.get_steps(behavior_name)

                if terminal_steps:
                    done = True
                    env.reset()
                    decision_steps, terminal_steps = env.get_steps(behavior_name)
                    state_conv_next = decision_steps[0].obs[0]
                    state_num_next = decision_steps[0].obs[1]
    #                 decision_steps, terminal_steps = env.get_steps(behavior_name)
                    break

                else:
                    state_conv_next = decision_steps[0].obs[0]
                    state_num_next = decision_steps[0].obs[1]


                reward = decision_steps[0].reward
        #         state_next = np.array(state_next)

                episode_reward += reward
                # Save actions and states in replay buffer
                action_history.append(action)
                state_conv_history.append(state_conv)
                state_num_history.append(state_num)
                state_conv_next_history.append(state_conv_next)
                state_num_next_history.append(state_num_next)
                done_history.append(done) 
                rewards_history.append(reward)
                state_conv = state_conv_next
                state_num = state_num_next

                # Update every fourth frame and once batch size is over 32
                if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

                    # Selecionar índices aleatóriamente
                    indices = np.random.choice(range(len(done_history)), size=batch_size)

                    # Usando list comprehension para buscar os valores dos índices selecionados
                    state_conv_sample = np.array([state_conv_history[i] for i in indices])
                    state_num_sample = np.array([state_num_history[i] for i in indices])
                    state_conv_next_sample = np.array([state_conv_next_history[i] for i in indices])
                    state_num_next_sample = np.array([state_num_next_history[i] for i in indices])
                    rewards_sample = [rewards_history[i] for i in indices]
                    action_sample = [action_history[i] for i in indices]
                    done_sample = tf.convert_to_tensor(
                        [float(done_history[i]) for i in indices]
                    )

                    # Build the updated Q-values for the sampled future states
                    # Use the target model for stability
                    state_num_next_sample = tf.reshape(state_num_next_sample, [-1, 2])
                    future_rewards = model_target.predict([np.array(state_conv_next_sample), np.array(state_num_next_sample)])

                    # Q value = reward + discount factor * expected future reward
                    updated_q_values = rewards_sample + gamma * tf.reduce_max(
                        future_rewards, axis=1
                    )

                    # If final frame set the last value to -1
                    updated_q_values = updated_q_values * (1 - done_sample) - done_sample

                    # Create a mask so we only calculate loss on the updated Q-values

                    masks = tf.one_hot(action_sample, num_actions)

                    with tf.GradientTape() as tape:
                        # Train the model on the states and updated Q-values
                        q_values = model([np.array(state_conv_sample), np.array(state_num_sample)])


                        # Apply the masks to the Q-values to get the Q-value for action taken
                        q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)

                        # Calculate loss between new Q-value and old Q-value

                        loss = loss_function(updated_q_values, q_action)

                    # Backpropagation
                    grads = tape.gradient(loss, model.trainable_variables)
                    optimizer.apply_gradients(zip(grads, model.trainable_variables))

                if frame_count % update_target_network == 0:
                    # update the the target network with new weights
                    model_target.set_weights(model.get_weights())
                    # Log details
                    template = "running reward: {:.2f} at episode {}, frame count {}"
                    print(template.format(running_reward, episode_count, frame_count))
                    tf.summary.scalar(name="reward", data=running_reward, step=episode_count)
                    tf.summary.scalar(name="epsilon", data=epsilon, step=episode_count)
                    tf.summary.scalar(name="frame_count", data=frame_count, step=episode_count)
                    dqn_variable = model.trainable_variables
                    tf.summary.histogram(name="dqn_variables", data=tf.convert_to_tensor(dqn_variable[0]), step=episode_count)
                    tf.summary.histogram(name="actions", data=action, step=episode_count)
                    convs = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))
                    tf.summary.image("Training data", data=convs[:5, :, :, :], step=episode_count)
                    writer.flush()
                    
            # Limit the state and reward history
            if len(rewards_history) > max_memory_length:
                del rewards_history[:1]
                del state_conv_history[:1]
                del state_num_history[:1]
                del state_conv_next_history[:1]
                del state_num_next_history[:1]
                del action_history[:1]
                del done_history[:1]

            if done:
                env.reset()
                done = False


            # Update running reward to check condition for solving
            episode_reward_history.append(episode_reward)
            if len(episode_reward_history) > 100:
                del episode_reward_history[:1]
            running_reward = np.mean(episode_reward_history)

            episode_count += 10

            if running_reward > 500000:  # Condition to consider the task solved
                print("Solved at episode {}!".format(episode_count))
                break
except:
    print(traceback.print_exc())
    writer.close()
    env.close()
# Out:
# running reward: 0.00 at episode 0, frame count 200
# running reward: 0.00 at episode 0, frame count 300
# running reward: -150000.00 at episode 10, frame count 400
# running reward: -83000.00 at episode 20, frame count 500
# running reward: -53750.00 at episode 40, frame count 600
# running reward: -53750.00 at episode 40, frame count 700
# running reward: -42166.67 at episode 60, frame count 800
# running reward: -38428.57 at episode 70, frame count 900
# running reward: -40750.00 at episode 80, frame count 1000
# running reward: -41000.00 at episode 90, frame count 1100
# running reward: -41500.00 at episode 100, frame count 1200
# running reward: -43545.45 at episode 110, frame count 1300
# running reward: -41250.00 at episode 120, frame count 1400
# running reward: -39615.38 at episode 130, frame count 1500
# running reward: -36071.43 at episode 140, frame count 1600
# running reward: -37800.00 at episode 150, frame count 1700
# running reward: -33529.41 at episode 170, frame count 1800
# running reward: -33529.41 at episode 170, frame count 1900
# running reward: -35722.22 at episode 180, frame count 2000
# running reward: -36550.00 at episode 200, frame count 2100
# running reward: -35000.00 at episode 210, frame count 2200
# running reward: -33409.09 at episode 220, frame count 2300
# running reward: -30666.67 at episode 240, frame count 2400
# running reward: -31320.00 at episode 250, frame count 2500
# running reward: -28576.92 at episode 260, frame count 2600
# running reward: -28111.11 at episode 270, frame count 2700
# running reward: -28500.00 at episode 280, frame count 2800
# running reward: -27931.03 at episode 290, frame count 2900
# running reward: -28966.67 at episode 300, frame count 3000
# running reward: -28903.23 at episode 310, frame count 3100
# running reward: -28750.00 at episode 320, frame count 3200
# running reward: -28060.61 at episode 330, frame count 3300
# running reward: -26542.86 at episode 350, frame count 3400
# running reward: -26500.00 at episode 360, frame count 3500
# running reward: -26297.30 at episode 370, frame count 3600
# running reward: -26157.89 at episode 380, frame count 3700
# running reward: -25923.08 at episode 390, frame count 3800
# running reward: -23825.00 at episode 400, frame count 3900
# running reward: -22238.10 at episode 420, frame count 4100
# running reward: -21372.09 at episode 430, frame count 4200
# running reward: -21372.09 at episode 430, frame count 4300
# running reward: -20204.55 at episode 440, frame count 4400
# running reward: -20204.55 at episode 440, frame count 4500
# running reward: -20733.33 at episode 450, frame count 4600
# running reward: -21826.09 at episode 460, frame count 4700
# running reward: -21826.09 at episode 460, frame count 4800
# running reward: -22744.68 at episode 470, frame count 4900
# running reward: -23645.83 at episode 480, frame count 5000
# running reward: -24510.20 at episode 490, frame count 5100
# running reward: -25020.00 at episode 500, frame count 5200
# running reward: -25058.82 at episode 510, frame count 5300
# running reward: -25509.43 at episode 530, frame count 5400
# running reward: -25685.19 at episode 540, frame count 5500
# running reward: -25945.45 at episode 550, frame count 5600
# running reward: -25607.14 at episode 560, frame count 5700
# running reward: -24372.88 at episode 590, frame count 5800
# running reward: -24066.67 at episode 600, frame count 5900
# running reward: -24066.67 at episode 600, frame count 6000
# running reward: -22655.74 at episode 610, frame count 6100
# running reward: -22655.74 at episode 610, frame count 6200
# running reward: -22806.45 at episode 620, frame count 6300
# running reward: -22806.45 at episode 620, frame count 6400
# running reward: -22806.45 at episode 620, frame count 6500
# running reward: -22806.45 at episode 620, frame count 6600
# running reward: -23492.06 at episode 630, frame count 6700
# running reward: -24031.25 at episode 640, frame count 6800
# running reward: -23969.23 at episode 650, frame count 6900
# running reward: -24500.00 at episode 660, frame count 7000
# running reward: -24500.00 at episode 660, frame count 7100
# running reward: -24500.00 at episode 660, frame count 7200
# running reward: -24500.00 at episode 660, frame count 7300
# running reward: -26544.12 at episode 680, frame count 7400
# running reward: -26492.75 at episode 690, frame count 7500
# running reward: -26428.57 at episode 700, frame count 7600
# running reward: -26428.57 at episode 700, frame count 7700
# running reward: -26591.55 at episode 710, frame count 7800
# running reward: -26055.56 at episode 720, frame count 7900
# running reward: -26301.37 at episode 730, frame count 8000
# running reward: -26567.57 at episode 740, frame count 8100
# running reward: -26866.67 at episode 750, frame count 8200
# running reward: -27223.68 at episode 760, frame count 8300
# running reward: -26884.62 at episode 780, frame count 8400
# running reward: -26475.00 at episode 800, frame count 8500
# running reward: -26518.52 at episode 810, frame count 8600
# running reward: -26109.76 at episode 820, frame count 8700
# running reward: -26433.73 at episode 830, frame count 8800
# running reward: -26523.81 at episode 840, frame count 8900
# running reward: -26823.53 at episode 850, frame count 9000
# running reward: -26116.28 at episode 860, frame count 9100
# running reward: -25850.57 at episode 870, frame count 9200
# running reward: -25850.57 at episode 870, frame count 9300
# running reward: -26886.36 at episode 880, frame count 9400
# running reward: -26886.36 at episode 880, frame count 9500
# running reward: -27179.78 at episode 890, frame count 9600
# running reward: -27179.78 at episode 890, frame count 9700
# running reward: -27277.78 at episode 900, frame count 9800
# running reward: -27277.78 at episode 900, frame count 9900
# running reward: -27277.78 at episode 900, frame count 10000
# running reward: -27769.23 at episode 910, frame count 10100
# running reward: -27456.52 at episode 920, frame count 10200
# running reward: -27456.52 at episode 920, frame count 10300
# running reward: -27322.58 at episode 930, frame count 10400
# running reward: -27574.47 at episode 940, frame count 10500
# running reward: -27684.21 at episode 950, frame count 10600
# running reward: -27684.21 at episode 950, frame count 10700
# running reward: -28000.00 at episode 960, frame count 10800
# running reward: -28000.00 at episode 960, frame count 10900
# running reward: -28000.00 at episode 960, frame count 11000
# running reward: -28010.31 at episode 970, frame count 11100
# running reward: -28408.16 at episode 980, frame count 11200
# running reward: -28408.16 at episode 980, frame count 11300
# running reward: -28363.64 at episode 990, frame count 11400
# running reward: -28710.00 at episode 1000, frame count 11500
# running reward: -27600.00 at episode 1010, frame count 11600
# running reward: -27690.00 at episode 1030, frame count 11700
# running reward: -27690.00 at episode 1030, frame count 11800
# running reward: -27690.00 at episode 1030, frame count 11900
# running reward: -28860.00 at episode 1040, frame count 12000
# running reward: -28540.00 at episode 1050, frame count 12100
# running reward: -28270.00 at episode 1070, frame count 12200
# running reward: -28080.00 at episode 1080, frame count 12300
# running reward: -28080.00 at episode 1080, frame count 12400
# running reward: -28080.00 at episode 1080, frame count 12500
# running reward: -28080.00 at episode 1080, frame count 12600
# running reward: -29490.00 at episode 1090, frame count 12700
# running reward: -29320.00 at episode 1100, frame count 12800
# running reward: -29320.00 at episode 1100, frame count 12900
# running reward: -29850.00 at episode 1110, frame count 13000
# running reward: -29820.00 at episode 1120, frame count 13100
# running reward: -29820.00 at episode 1120, frame count 13200
# running reward: -30590.00 at episode 1130, frame count 13300
# running reward: -29900.00 at episode 1150, frame count 13400
# running reward: -30060.00 at episode 1160, frame count 13500
# running reward: -30480.00 at episode 1170, frame count 13600
# running reward: -30480.00 at episode 1170, frame count 13700
# running reward: -30510.00 at episode 1180, frame count 13800
# running reward: -30510.00 at episode 1180, frame count 13900
# running reward: -31170.00 at episode 1190, frame count 14000
# running reward: -31220.00 at episode 1210, frame count 14100
# running reward: -31320.00 at episode 1220, frame count 14200
# running reward: -31580.00 at episode 1230, frame count 14300
# running reward: -31580.00 at episode 1230, frame count 14400
# running reward: -31580.00 at episode 1230, frame count 14500
# running reward: -31580.00 at episode 1230, frame count 14600
# running reward: -31920.00 at episode 1240, frame count 14700
# running reward: -31520.00 at episode 1250, frame count 14800
# running reward: -32390.00 at episode 1260, frame count 14900
# running reward: -32390.00 at episode 1260, frame count 15000
# running reward: -32790.00 at episode 1270, frame count 15100
# running reward: -32410.00 at episode 1280, frame count 15200
# running reward: -32410.00 at episode 1280, frame count 15300
# running reward: -32250.00 at episode 1300, frame count 15400
# running reward: -32250.00 at episode 1300, frame count 15500
# running reward: -32010.00 at episode 1310, frame count 15600
# running reward: -32040.00 at episode 1320, frame count 15700
# running reward: -32420.00 at episode 1330, frame count 15800
# running reward: -32420.00 at episode 1330, frame count 15900
# running reward: -33110.00 at episode 1340, frame count 16000
# running reward: -33080.00 at episode 1350, frame count 16100
# running reward: -33080.00 at episode 1350, frame count 16200
# running reward: -33610.00 at episode 1370, frame count 16300
# running reward: -33390.00 at episode 1380, frame count 16400
# running reward: -33870.00 at episode 1390, frame count 16500
# running reward: -33870.00 at episode 1390, frame count 16600
# running reward: -33870.00 at episode 1390, frame count 16700
# running reward: -34900.00 at episode 1400, frame count 16800
# running reward: -34900.00 at episode 1400, frame count 16900
# running reward: -34900.00 at episode 1400, frame count 17000
# running reward: -36430.00 at episode 1420, frame count 17100
# running reward: -36430.00 at episode 1420, frame count 17200
# running reward: -36430.00 at episode 1420, frame count 17300
# running reward: -36430.00 at episode 1420, frame count 17400
# running reward: -37410.00 at episode 1430, frame count 17500
# running reward: -38240.00 at episode 1440, frame count 17600
# running reward: -37380.00 at episode 1460, frame count 17700
# running reward: -36750.00 at episode 1470, frame count 17800
# running reward: -36250.00 at episode 1480, frame count 17900
# running reward: -36250.00 at episode 1480, frame count 18000
# running reward: -36850.00 at episode 1490, frame count 18100
# running reward: -36850.00 at episode 1490, frame count 18200
# running reward: -36970.00 at episode 1500, frame count 18300
# running reward: -37220.00 at episode 1510, frame count 18400
# running reward: -37220.00 at episode 1510, frame count 18500
# running reward: -37220.00 at episode 1510, frame count 18600
# running reward: -37790.00 at episode 1530, frame count 18700
# running reward: -37790.00 at episode 1530, frame count 18800
# running reward: -37890.00 at episode 1540, frame count 18900
# running reward: -37510.00 at episode 1550, frame count 19000
# running reward: -37510.00 at episode 1550, frame count 19100
# running reward: -38670.00 at episode 1570, frame count 19200
# running reward: -38670.00 at episode 1570, frame count 19300
# running reward: -38670.00 at episode 1570, frame count 19400
# running reward: -39830.00 at episode 1580, frame count 19500
# running reward: -40510.00 at episode 1590, frame count 19600
# running reward: -41140.00 at episode 1600, frame count 19700
# running reward: -42200.00 at episode 1610, frame count 19800
# running reward: -41510.00 at episode 1630, frame count 19900
# running reward: -41500.00 at episode 1650, frame count 20000
# running reward: -41110.00 at episode 1660, frame count 20100
# running reward: -39460.00 at episode 1670, frame count 20200
# running reward: -39580.00 at episode 1680, frame count 20300
# running reward: -39580.00 at episode 1680, frame count 20400
# running reward: -39580.00 at episode 1680, frame count 20500
# running reward: -40510.00 at episode 1690, frame count 20600
# running reward: -40510.00 at episode 1690, frame count 20700
# running reward: -40610.00 at episode 1710, frame count 20800
# running reward: -40750.00 at episode 1720, frame count 20900
# running reward: -40750.00 at episode 1720, frame count 21000
# running reward: -41060.00 at episode 1740, frame count 21100
# running reward: -40780.00 at episode 1750, frame count 21200
# running reward: -40720.00 at episode 1760, frame count 21300
# running reward: -40720.00 at episode 1760, frame count 21400
# running reward: -41840.00 at episode 1770, frame count 21500
# running reward: -41840.00 at episode 1770, frame count 21600
# running reward: -42320.00 at episode 1780, frame count 21700
# running reward: -42920.00 at episode 1790, frame count 21800
# running reward: -43100.00 at episode 1800, frame count 21900
# running reward: -43100.00 at episode 1820, frame count 22000
# running reward: -42530.00 at episode 1830, frame count 22100
# running reward: -41890.00 at episode 1850, frame count 22200
# running reward: -42660.00 at episode 1860, frame count 22300
# running reward: -42660.00 at episode 1860, frame count 22400
# running reward: -43080.00 at episode 1870, frame count 22500
# running reward: -42540.00 at episode 1880, frame count 22600
# running reward: -41900.00 at episode 1890, frame count 22700
# running reward: -41960.00 at episode 1900, frame count 22800
# running reward: -41680.00 at episode 1910, frame count 22900
# running reward: -41910.00 at episode 1920, frame count 23000
# running reward: -41910.00 at episode 1920, frame count 23100
# running reward: -42590.00 at episode 1940, frame count 23200
# running reward: -42590.00 at episode 1940, frame count 23300
# running reward: -41870.00 at episode 1950, frame count 23400
# running reward: -41870.00 at episode 1950, frame count 23500
# running reward: -41490.00 at episode 1960, frame count 23600
# running reward: -40540.00 at episode 1980, frame count 23800
# running reward: -40730.00 at episode 1990, frame count 23900
# running reward: -40030.00 at episode 2000, frame count 24000
# running reward: -39150.00 at episode 2030, frame count 24100
# running reward: -39150.00 at episode 2030, frame count 24200
# running reward: -37430.00 at episode 2040, frame count 24300
# running reward: -38330.00 at episode 2060, frame count 24400
# running reward: -38330.00 at episode 2060, frame count 24500
# running reward: -38970.00 at episode 2070, frame count 24600
# running reward: -36470.00 at episode 2090, frame count 24700
# running reward: -36360.00 at episode 2100, frame count 24800
# running reward: -35000.00 at episode 2120, frame count 24900
# running reward: -34610.00 at episode 2130, frame count 25000
# running reward: -35330.00 at episode 2140, frame count 25100
# running reward: -35200.00 at episode 2150, frame count 25200
# running reward: -35210.00 at episode 2160, frame count 25300
# running reward: -34180.00 at episode 2180, frame count 25400
# running reward: -34180.00 at episode 2180, frame count 25500
# running reward: -33010.00 at episode 2190, frame count 25600
# running reward: -33340.00 at episode 2200, frame count 25700
# running reward: -34100.00 at episode 2210, frame count 25800
# running reward: -33930.00 at episode 2230, frame count 25900
# running reward: -33590.00 at episode 2240, frame count 26000
# running reward: -33800.00 at episode 2250, frame count 26100
# running reward: -33660.00 at episode 2270, frame count 26200
# running reward: -33450.00 at episode 2280, frame count 26300
# running reward: -33450.00 at episode 2280, frame count 26400
# running reward: -31720.00 at episode 2290, frame count 26500
# running reward: -32050.00 at episode 2300, frame count 26600
# running reward: -31160.00 at episode 2310, frame count 26700
# running reward: -31160.00 at episode 2310, frame count 26800
# running reward: -30820.00 at episode 2340, frame count 27000
# running reward: -30690.00 at episode 2350, frame count 27100
# running reward: -30220.00 at episode 2360, frame count 27200
# running reward: -30220.00 at episode 2360, frame count 27300
# running reward: -29540.00 at episode 2370, frame count 27400
# running reward: -29820.00 at episode 2380, frame count 27500
# running reward: -29590.00 at episode 2390, frame count 27600
# running reward: -29320.00 at episode 2400, frame count 27700
# running reward: -27940.00 at episode 2420, frame count 27800
# running reward: -26490.00 at episode 2440, frame count 27900
# running reward: -25940.00 at episode 2450, frame count 28000
# running reward: -26520.00 at episode 2460, frame count 28100
# running reward: -26970.00 at episode 2470, frame count 28200
# running reward: -25620.00 at episode 2490, frame count 28300
# running reward: -24810.00 at episode 2510, frame count 28400
# running reward: -24810.00 at episode 2510, frame count 28500
# running reward: -24800.00 at episode 2520, frame count 28600
# running reward: -25100.00 at episode 2530, frame count 28700
# running reward: -25290.00 at episode 2540, frame count 28800
# running reward: -25760.00 at episode 2550, frame count 28900
# running reward: -25760.00 at episode 2550, frame count 29000
# running reward: -25760.00 at episode 2550, frame count 29100
# running reward: -25760.00 at episode 2550, frame count 29200
# running reward: -25100.00 at episode 2570, frame count 29300
# running reward: -24280.00 at episode 2580, frame count 29400
# running reward: -24370.00 at episode 2590, frame count 29500
# running reward: -23720.00 at episode 2600, frame count 29600
# running reward: -23500.00 at episode 2610, frame count 29700
# running reward: -23120.00 at episode 2620, frame count 29800
# running reward: -22640.00 at episode 2630, frame count 29900
# running reward: -22790.00 at episode 2640, frame count 30000
# running reward: -22550.00 at episode 2650, frame count 30100
# running reward: -22550.00 at episode 2650, frame count 30200
# running reward: -22550.00 at episode 2650, frame count 30300
# running reward: -22100.00 at episode 2660, frame count 30400
# running reward: -22100.00 at episode 2660, frame count 30500
# running reward: -22710.00 at episode 2670, frame count 30600
# running reward: -23090.00 at episode 2680, frame count 30700
# running reward: -22240.00 at episode 2690, frame count 30800
# running reward: -22240.00 at episode 2690, frame count 30900
# running reward: -22070.00 at episode 2710, frame count 31000
# running reward: -22460.00 at episode 2720, frame count 31100
# running reward: -21450.00 at episode 2740, frame count 31200
# running reward: -21730.00 at episode 2750, frame count 31300
# running reward: -21710.00 at episode 2760, frame count 31400
# running reward: -19990.00 at episode 2780, frame count 31500
# running reward: -19350.00 at episode 2790, frame count 31600
# running reward: -19350.00 at episode 2790, frame count 31700
# running reward: -19670.00 at episode 2800, frame count 31800
# running reward: -19670.00 at episode 2800, frame count 31900
# running reward: -19880.00 at episode 2810, frame count 32000
# running reward: -20050.00 at episode 2830, frame count 32100
# running reward: -20050.00 at episode 2830, frame count 32200
# running reward: -19920.00 at episode 2840, frame count 32300
# running reward: -20510.00 at episode 2850, frame count 32400
# running reward: -20430.00 at episode 2860, frame count 32500
# running reward: -20430.00 at episode 2860, frame count 32600
# running reward: -20430.00 at episode 2860, frame count 32700
# running reward: -20570.00 at episode 2870, frame count 32800
# running reward: -20570.00 at episode 2870, frame count 32900
# running reward: -20530.00 at episode 2880, frame count 33000
# running reward: -20420.00 at episode 2890, frame count 33100
# running reward: -20420.00 at episode 2890, frame count 33200
# running reward: -19670.00 at episode 2910, frame count 33300
# running reward: -19870.00 at episode 2920, frame count 33400
# running reward: -18810.00 at episode 2930, frame count 33500
# running reward: -18490.00 at episode 2940, frame count 33600
# running reward: -18490.00 at episode 2940, frame count 33700
# running reward: -18940.00 at episode 2950, frame count 33800
# running reward: -18930.00 at episode 2970, frame count 33900
# running reward: -19030.00 at episode 2980, frame count 34000
# running reward: -19030.00 at episode 2980, frame count 34100
# running reward: -19030.00 at episode 2980, frame count 34200
# running reward: -19470.00 at episode 3000, frame count 34300
# running reward: -19580.00 at episode 3010, frame count 34400
# running reward: -19510.00 at episode 3020, frame count 34500
# running reward: -20050.00 at episode 3030, frame count 34600
# running reward: -20870.00 at episode 3040, frame count 34700
# running reward: -21000.00 at episode 3050, frame count 34800
# running reward: -21000.00 at episode 3050, frame count 34900
# running reward: -20630.00 at episode 3060, frame count 35000
# running reward: -20660.00 at episode 3070, frame count 35100
# running reward: -21300.00 at episode 3080, frame count 35200
# running reward: -21300.00 at episode 3080, frame count 35300
# running reward: -21560.00 at episode 3090, frame count 35400
# running reward: -21380.00 at episode 3100, frame count 35500
# running reward: -21380.00 at episode 3100, frame count 35600
# running reward: -21670.00 at episode 3110, frame count 35700
# running reward: -21670.00 at episode 3110, frame count 35800
# running reward: -21670.00 at episode 3110, frame count 35900
# running reward: -22730.00 at episode 3120, frame count 36000
# running reward: -22730.00 at episode 3120, frame count 36100
# running reward: -22540.00 at episode 3130, frame count 36200
# running reward: -22380.00 at episode 3140, frame count 36300
# running reward: -22380.00 at episode 3140, frame count 36400
# running reward: -22340.00 at episode 3150, frame count 36500
# running reward: -21380.00 at episode 3160, frame count 36700
# running reward: -21210.00 at episode 3170, frame count 36800
# running reward: -21210.00 at episode 3170, frame count 36900
# running reward: -20300.00 at episode 3200, frame count 37100
# running reward: -19570.00 at episode 3210, frame count 37200
# running reward: -19570.00 at episode 3210, frame count 37300
# running reward: -20100.00 at episode 3220, frame count 37400
# running reward: -20100.00 at episode 3220, frame count 37500
# running reward: -20070.00 at episode 3230, frame count 37600
# running reward: -20810.00 at episode 3240, frame count 37700
# running reward: -20160.00 at episode 3250, frame count 37800
# running reward: -19390.00 at episode 3260, frame count 37900
# running reward: -19860.00 at episode 3270, frame count 38000
# running reward: -21390.00 at episode 3290, frame count 38100
# running reward: -21020.00 at episode 3300, frame count 38200
# running reward: -21020.00 at episode 3300, frame count 38300
# running reward: -21020.00 at episode 3300, frame count 38400
# running reward: -22130.00 at episode 3310, frame count 38500
# running reward: -22450.00 at episode 3320, frame count 38600
# running reward: -22450.00 at episode 3320, frame count 38700
# running reward: -23110.00 at episode 3330, frame count 38800
# running reward: -22430.00 at episode 3340, frame count 38900
# running reward: -22390.00 at episode 3350, frame count 39000
# running reward: -22560.00 at episode 3360, frame count 39100
# running reward: -22560.00 at episode 3360, frame count 39200
# running reward: -22360.00 at episode 3370, frame count 39300
# running reward: -22360.00 at episode 3370, frame count 39400
# running reward: -23060.00 at episode 3380, frame count 39500
# running reward: -23060.00 at episode 3380, frame count 39600
# running reward: -23270.00 at episode 3390, frame count 39700
# running reward: -23310.00 at episode 3400, frame count 39800
# running reward: -23570.00 at episode 3410, frame count 39900
# running reward: -23570.00 at episode 3410, frame count 40000
# running reward: -24660.00 at episode 3420, frame count 40100
# running reward: -24780.00 at episode 3440, frame count 40200
# running reward: -25420.00 at episode 3450, frame count 40300
# running reward: -25420.00 at episode 3450, frame count 40400
# running reward: -24480.00 at episode 3460, frame count 40500
# running reward: -23810.00 at episode 3470, frame count 40600
# running reward: -24200.00 at episode 3480, frame count 40700
# running reward: -24100.00 at episode 3490, frame count 40800
# running reward: -24100.00 at episode 3490, frame count 40900
# running reward: -24480.00 at episode 3510, frame count 41000
# running reward: -23220.00 at episode 3520, frame count 41100
# running reward: -22880.00 at episode 3530, frame count 41200
# running reward: -22720.00 at episode 3540, frame count 41300
# running reward: -22560.00 at episode 3560, frame count 41400
# running reward: -22600.00 at episode 3570, frame count 41500
# running reward: -22410.00 at episode 3580, frame count 41600
# running reward: -22320.00 at episode 3590, frame count 41700
# running reward: -22270.00 at episode 3600, frame count 41800
# running reward: -22310.00 at episode 3610, frame count 41900
# running reward: -22970.00 at episode 3620, frame count 42000
# running reward: -22970.00 at episode 3620, frame count 42100
# running reward: -22920.00 at episode 3640, frame count 42200
# running reward: -22770.00 at episode 3660, frame count 42300
# running reward: -22280.00 at episode 3670, frame count 42400
# running reward: -22280.00 at episode 3670, frame count 42500
# running reward: -22270.00 at episode 3680, frame count 42600
# running reward: -22630.00 at episode 3690, frame count 42700
# running reward: -22630.00 at episode 3700, frame count 42800
# running reward: -22550.00 at episode 3710, frame count 42900
# running reward: -22230.00 at episode 3720, frame count 43000
# running reward: -22230.00 at episode 3720, frame count 43100
# running reward: -21050.00 at episode 3730, frame count 43200
# running reward: -21050.00 at episode 3730, frame count 43300
# running reward: -21860.00 at episode 3740, frame count 43400
# running reward: -21860.00 at episode 3740, frame count 43500
# running reward: -21770.00 at episode 3750, frame count 43600
# running reward: -22130.00 at episode 3770, frame count 43700
# running reward: -22460.00 at episode 3780, frame count 43800
# running reward: -21910.00 at episode 3800, frame count 43900
# running reward: -21910.00 at episode 3800, frame count 44000
# running reward: -22620.00 at episode 3810, frame count 44100
# running reward: -22620.00 at episode 3810, frame count 44200
# running reward: -22770.00 at episode 3820, frame count 44300
# running reward: -23210.00 at episode 3830, frame count 44400
# running reward: -23570.00 at episode 3840, frame count 44500
# running reward: -23330.00 at episode 3850, frame count 44600
# running reward: -23400.00 at episode 3860, frame count 44700
# running reward: -23250.00 at episode 3870, frame count 44800
# running reward: -22500.00 at episode 3890, frame count 44900
# running reward: -23000.00 at episode 3900, frame count 45000
# running reward: -22580.00 at episode 3910, frame count 45100
# running reward: -21840.00 at episode 3920, frame count 45200
# running reward: -21240.00 at episode 3930, frame count 45300
# running reward: -21480.00 at episode 3950, frame count 45400
# running reward: -20790.00 at episode 3970, frame count 45500
# running reward: -20790.00 at episode 3970, frame count 45600
# running reward: -21430.00 at episode 3980, frame count 45700
# running reward: -20770.00 at episode 3990, frame count 45800
# running reward: -20770.00 at episode 4000, frame count 45900
# running reward: -21110.00 at episode 4010, frame count 46000
# running reward: -21110.00 at episode 4010, frame count 46100
# running reward: -22670.00 at episode 4020, frame count 46200
# running reward: -22670.00 at episode 4020, frame count 46300
# running reward: -21780.00 at episode 4030, frame count 46400
# running reward: -21470.00 at episode 4050, frame count 46500
# running reward: -21490.00 at episode 4060, frame count 46600
# running reward: -21490.00 at episode 4060, frame count 46700
# running reward: -21490.00 at episode 4060, frame count 46800
# running reward: -22060.00 at episode 4080, frame count 47000
# running reward: -22440.00 at episode 4090, frame count 47100
# running reward: -22610.00 at episode 4110, frame count 47200
# running reward: -21650.00 at episode 4130, frame count 47300
# running reward: -21580.00 at episode 4140, frame count 47400
# running reward: -21870.00 at episode 4150, frame count 47500
# running reward: -21870.00 at episode 4150, frame count 47600
# running reward: -23450.00 at episode 4180, frame count 47700
# running reward: -23940.00 at episode 4190, frame count 47800
# running reward: -23120.00 at episode 4200, frame count 47900
# running reward: -23120.00 at episode 4200, frame count 48000
# running reward: -23320.00 at episode 4210, frame count 48100
# running reward: -23320.00 at episode 4210, frame count 48200
# running reward: -23320.00 at episode 4210, frame count 48300
# running reward: -23320.00 at episode 4210, frame count 48400
# running reward: -23870.00 at episode 4220, frame count 48500
# running reward: -23310.00 at episode 4230, frame count 48600
# running reward: -22690.00 at episode 4240, frame count 48700
# running reward: -22690.00 at episode 4240, frame count 48800
# running reward: -23840.00 at episode 4250, frame count 48900
# running reward: -24120.00 at episode 4260, frame count 49000
# running reward: -23840.00 at episode 4270, frame count 49100
# running reward: -24060.00 at episode 4280, frame count 49200
# running reward: -24120.00 at episode 4290, frame count 49300
# running reward: -24570.00 at episode 4310, frame count 49400
# running reward: -23370.00 at episode 4330, frame count 49500
# running reward: -23720.00 at episode 4340, frame count 49600
# running reward: -24790.00 at episode 4350, frame count 49700
# running reward: -23980.00 at episode 4360, frame count 49800
# running reward: -24980.00 at episode 4370, frame count 49900
# running reward: -24240.00 at episode 4380, frame count 50000
# running reward: -24240.00 at episode 4380, frame count 50100
# running reward: -23850.00 at episode 4390, frame count 50200
# running reward: -23850.00 at episode 4390, frame count 50300
# running reward: -23850.00 at episode 4390, frame count 50400
# running reward: -24800.00 at episode 4410, frame count 50500
# running reward: -24150.00 at episode 4420, frame count 50600
# running reward: -24270.00 at episode 4440, frame count 50700
# running reward: -23970.00 at episode 4450, frame count 50800
# running reward: -23970.00 at episode 4450, frame count 50900
# running reward: -25570.00 at episode 4460, frame count 51000
# running reward: -25570.00 at episode 4460, frame count 51100
# running reward: -25570.00 at episode 4460, frame count 51200
# running reward: -26200.00 at episode 4470, frame count 51300
# running reward: -26200.00 at episode 4470, frame count 51400
# running reward: -25830.00 at episode 4490, frame count 51500
# running reward: -25310.00 at episode 4500, frame count 51600
# running reward: -25470.00 at episode 4510, frame count 51700
# running reward: -25070.00 at episode 4520, frame count 51800
# running reward: -24960.00 at episode 4540, frame count 51900
# running reward: -24800.00 at episode 4550, frame count 52000
# running reward: -24800.00 at episode 4550, frame count 52100
# running reward: -24310.00 at episode 4570, frame count 52200
# running reward: -24430.00 at episode 4580, frame count 52300
# running reward: -24430.00 at episode 4580, frame count 52400
# running reward: -24430.00 at episode 4580, frame count 52500
# running reward: -24430.00 at episode 4580, frame count 52600
# running reward: -24800.00 at episode 4590, frame count 52700
# running reward: -24800.00 at episode 4590, frame count 52800
# running reward: -25620.00 at episode 4600, frame count 52900
# running reward: -25800.00 at episode 4610, frame count 53000
# running reward: -25720.00 at episode 4620, frame count 53100
# running reward: -25830.00 at episode 4640, frame count 53200
# running reward: -25830.00 at episode 4640, frame count 53300
# running reward: -25570.00 at episode 4650, frame count 53400
# running reward: -25570.00 at episode 4650, frame count 53500
# running reward: -25570.00 at episode 4650, frame count 53600
# running reward: -26250.00 at episode 4670, frame count 53700
# running reward: -25140.00 at episode 4690, frame count 53800
# running reward: -25140.00 at episode 4690, frame count 53900
# running reward: -24800.00 at episode 4700, frame count 54000
# running reward: -24960.00 at episode 4710, frame count 54100
# running reward: -25170.00 at episode 4720, frame count 54200
# running reward: -26210.00 at episode 4730, frame count 54300
# running reward: -26070.00 at episode 4740, frame count 54400
# running reward: -26130.00 at episode 4760, frame count 54500
# running reward: -26130.00 at episode 4760, frame count 54600
# running reward: -26390.00 at episode 4770, frame count 54700
# running reward: -24870.00 at episode 4780, frame count 54800
# running reward: -25320.00 at episode 4790, frame count 54900
# running reward: -26110.00 at episode 4800, frame count 55000
# running reward: -24890.00 at episode 4810, frame count 55100
# running reward: -24880.00 at episode 4830, frame count 55300
# running reward: -25050.00 at episode 4840, frame count 55400
# running reward: -25180.00 at episode 4850, frame count 55500
# running reward: -25180.00 at episode 4850, frame count 55600
# running reward: -25050.00 at episode 4860, frame count 55700
# running reward: -25050.00 at episode 4860, frame count 55800
# running reward: -25750.00 at episode 4880, frame count 55900
# running reward: -24980.00 at episode 4900, frame count 56000
# running reward: -25500.00 at episode 4910, frame count 56100
# running reward: -25850.00 at episode 4920, frame count 56200
# running reward: -26890.00 at episode 4930, frame count 56300
# running reward: -26500.00 at episode 4950, frame count 56400
# running reward: -26450.00 at episode 4960, frame count 56500
# running reward: -26350.00 at episode 4970, frame count 56600
# running reward: -25770.00 at episode 4980, frame count 56700
# running reward: -25770.00 at episode 4980, frame count 56800
# running reward: -25770.00 at episode 4980, frame count 56900
# running reward: -26070.00 at episode 4990, frame count 57000
# running reward: -26070.00 at episode 4990, frame count 57100
# running reward: -26500.00 at episode 5000, frame count 57200
# running reward: -26500.00 at episode 5000, frame count 57300
# running reward: -27420.00 at episode 5010, frame count 57400
# running reward: -26200.00 at episode 5020, frame count 57500
# running reward: -26200.00 at episode 5020, frame count 57600
# running reward: -26200.00 at episode 5020, frame count 57700
# running reward: -24750.00 at episode 5040, frame count 57800
# running reward: -24760.00 at episode 5060, frame count 57900
# running reward: -23830.00 at episode 5070, frame count 58000
# running reward: -23830.00 at episode 5070, frame count 58100
# running reward: -23770.00 at episode 5080, frame count 58200
# running reward: -23430.00 at episode 5090, frame count 58300
# running reward: -23430.00 at episode 5090, frame count 58400
# running reward: -22910.00 at episode 5100, frame count 58500
# running reward: -23270.00 at episode 5110, frame count 58600
# running reward: -23630.00 at episode 5120, frame count 58700
# running reward: -23260.00 at episode 5130, frame count 58800
# running reward: -23080.00 at episode 5150, frame count 58900
# running reward: -23080.00 at episode 5150, frame count 59000
# running reward: -22390.00 at episode 5160, frame count 59100
# running reward: -22390.00 at episode 5160, frame count 59200
# running reward: -22390.00 at episode 5160, frame count 59300
# running reward: -22370.00 at episode 5170, frame count 59400
# running reward: -22370.00 at episode 5170, frame count 59500
# running reward: -22480.00 at episode 5180, frame count 59600
# running reward: -22480.00 at episode 5180, frame count 59700
# running reward: -23540.00 at episode 5200, frame count 59800
# running reward: -23310.00 at episode 5210, frame count 59900
# running reward: -23310.00 at episode 5210, frame count 60000
# running reward: -22660.00 at episode 5220, frame count 60100
# running reward: -22660.00 at episode 5220, frame count 60200
# running reward: -22660.00 at episode 5220, frame count 60300
# running reward: -22660.00 at episode 5220, frame count 60400
# running reward: -24750.00 at episode 5240, frame count 60500
# running reward: -24750.00 at episode 5240, frame count 60600
# running reward: -24750.00 at episode 5240, frame count 60700
# running reward: -23350.00 at episode 5250, frame count 60800
# running reward: -23640.00 at episode 5260, frame count 60900
# running reward: -23640.00 at episode 5260, frame count 61000
# running reward: -23880.00 at episode 5280, frame count 61100
# running reward: -23880.00 at episode 5280, frame count 61200
# running reward: -22540.00 at episode 5300, frame count 61300
# running reward: -22280.00 at episode 5310, frame count 61400
# running reward: -22570.00 at episode 5320, frame count 61500
# running reward: -23390.00 at episode 5330, frame count 61600
# running reward: -22380.00 at episode 5350, frame count 61700
# running reward: -22600.00 at episode 5370, frame count 61800
# running reward: -22600.00 at episode 5370, frame count 61900
# running reward: -22600.00 at episode 5370, frame count 62000
# running reward: -23050.00 at episode 5380, frame count 62100
# running reward: -22500.00 at episode 5390, frame count 62200
# running reward: -21570.00 at episode 5410, frame count 62300
# running reward: -21400.00 at episode 5430, frame count 62400
# running reward: -21260.00 at episode 5440, frame count 62500
# running reward: -21300.00 at episode 5450, frame count 62600
# running reward: -20510.00 at episode 5460, frame count 62700
# running reward: -20510.00 at episode 5460, frame count 62800
# running reward: -20510.00 at episode 5460, frame count 62900
# running reward: -21060.00 at episode 5470, frame count 63000
# running reward: -21560.00 at episode 5480, frame count 63100
# running reward: -21560.00 at episode 5480, frame count 63200
# running reward: -21960.00 at episode 5490, frame count 63300
# running reward: -21960.00 at episode 5490, frame count 63400
# running reward: -23390.00 at episode 5500, frame count 63500
# running reward: -22930.00 at episode 5510, frame count 63600
# running reward: -23240.00 at episode 5520, frame count 63700
# running reward: -23720.00 at episode 5530, frame count 63800
# running reward: -23520.00 at episode 5540, frame count 63900
# running reward: -23520.00 at episode 5540, frame count 64000
# running reward: -23990.00 at episode 5550, frame count 64100
# running reward: -24200.00 at episode 5560, frame count 64200
# running reward: -24800.00 at episode 5570, frame count 64300
# running reward: -23990.00 at episode 5580, frame count 64400
# running reward: -21970.00 at episode 5600, frame count 64500
# running reward: -21970.00 at episode 5600, frame count 64600
# running reward: -21970.00 at episode 5600, frame count 64700
# running reward: -22510.00 at episode 5610, frame count 64800
# running reward: -22480.00 at episode 5620, frame count 64900
# running reward: -22480.00 at episode 5620, frame count 65000
# running reward: -22520.00 at episode 5630, frame count 65100
# running reward: -22520.00 at episode 5630, frame count 65200
# running reward: -22760.00 at episode 5640, frame count 65300
# running reward: -22890.00 at episode 5650, frame count 65400
# running reward: -22890.00 at episode 5650, frame count 65500
# running reward: -23100.00 at episode 5670, frame count 65600
# running reward: -23390.00 at episode 5680, frame count 65700
# running reward: -23880.00 at episode 5690, frame count 65800
# running reward: -24180.00 at episode 5700, frame count 65900
# running reward: -23930.00 at episode 5710, frame count 66000
# running reward: -23630.00 at episode 5720, frame count 66100
# running reward: -23220.00 at episode 5730, frame count 66200
# running reward: -23220.00 at episode 5730, frame count 66300
# running reward: -23250.00 at episode 5740, frame count 66400
# running reward: -23190.00 at episode 5750, frame count 66500
# running reward: -23520.00 at episode 5760, frame count 66600
# running reward: -22910.00 at episode 5770, frame count 66700
# running reward: -24390.00 at episode 5780, frame count 66800
# running reward: -24390.00 at episode 5780, frame count 66900
# running reward: -24390.00 at episode 5780, frame count 67000
# running reward: -24350.00 at episode 5790, frame count 67100
# running reward: -23630.00 at episode 5800, frame count 67200
# running reward: -24200.00 at episode 5810, frame count 67300
# running reward: -23300.00 at episode 5820, frame count 67400
# running reward: -22150.00 at episode 5840, frame count 67500
# running reward: -21760.00 at episode 5860, frame count 67600
# running reward: -21250.00 at episode 5870, frame count 67700
# running reward: -21800.00 at episode 5880, frame count 67800
# running reward: -21800.00 at episode 5880, frame count 67900
# running reward: -21670.00 at episode 5890, frame count 68000
# running reward: -22390.00 at episode 5900, frame count 68100
# running reward: -22490.00 at episode 5920, frame count 68200
# running reward: -22420.00 at episode 5940, frame count 68300
# running reward: -22340.00 at episode 5950, frame count 68400
# running reward: -23410.00 at episode 5970, frame count 68500
# running reward: -24020.00 at episode 5980, frame count 68600
# running reward: -24020.00 at episode 5980, frame count 68700
# running reward: -23860.00 at episode 5990, frame count 68800
# running reward: -23420.00 at episode 6000, frame count 68900
# running reward: -22060.00 at episode 6010, frame count 69000
# running reward: -21840.00 at episode 6020, frame count 69100
# running reward: -23590.00 at episode 6030, frame count 69200
# running reward: -24380.00 at episode 6040, frame count 69300
# running reward: -23770.00 at episode 6060, frame count 69400
# running reward: -23760.00 at episode 6070, frame count 69500
# running reward: -23180.00 at episode 6080, frame count 69600
# running reward: -23580.00 at episode 6090, frame count 69700
# running reward: -24100.00 at episode 6100, frame count 69800
# running reward: -24260.00 at episode 6110, frame count 69900
# running reward: -23620.00 at episode 6120, frame count 70000
# running reward: -23940.00 at episode 6130, frame count 70100
# running reward: -23940.00 at episode 6130, frame count 70200
# running reward: -24130.00 at episode 6150, frame count 70300
# running reward: -24370.00 at episode 6170, frame count 70400
# running reward: -23830.00 at episode 6180, frame count 70500
# running reward: -23110.00 at episode 6190, frame count 70600
# running reward: -23110.00 at episode 6190, frame count 70700
# running reward: -23860.00 at episode 6210, frame count 70800
# running reward: -23340.00 at episode 6220, frame count 70900
# running reward: -23340.00 at episode 6220, frame count 71000
# running reward: -23340.00 at episode 6220, frame count 71100
# running reward: -22970.00 at episode 6230, frame count 71200
# running reward: -23670.00 at episode 6250, frame count 71300
# running reward: -23170.00 at episode 6260, frame count 71400
# running reward: -22260.00 at episode 6270, frame count 71500
# running reward: -23080.00 at episode 6290, frame count 71600
# running reward: -23530.00 at episode 6310, frame count 71700
# running reward: -22640.00 at episode 6320, frame count 71800
# running reward: -21890.00 at episode 6330, frame count 71900
# running reward: -22240.00 at episode 6340, frame count 72000
# running reward: -22150.00 at episode 6350, frame count 72100
# running reward: -22080.00 at episode 6370, frame count 72200
# running reward: -21590.00 at episode 6380, frame count 72300
# running reward: -21220.00 at episode 6390, frame count 72400
# running reward: -20840.00 at episode 6400, frame count 72500
# running reward: -20820.00 at episode 6410, frame count 72600
# running reward: -20820.00 at episode 6410, frame count 72700
# running reward: -20340.00 at episode 6420, frame count 72800
# running reward: -20180.00 at episode 6430, frame count 72900
# running reward: -19580.00 at episode 6440, frame count 73000
# running reward: -19170.00 at episode 6460, frame count 73100
# running reward: -19170.00 at episode 6460, frame count 73200
# running reward: -18370.00 at episode 6470, frame count 73300
# running reward: -18090.00 at episode 6480, frame count 73400
# running reward: -17790.00 at episode 6490, frame count 73500
# running reward: -16790.00 at episode 6500, frame count 73600
# running reward: -16790.00 at episode 6500, frame count 73700
# running reward: -18290.00 at episode 6510, frame count 73800
# running reward: -18130.00 at episode 6530, frame count 73900
# running reward: -18150.00 at episode 6540, frame count 74000
# running reward: -18150.00 at episode 6540, frame count 74100
# running reward: -17700.00 at episode 6560, frame count 74200
# running reward: -18020.00 at episode 6580, frame count 74300
# running reward: -18020.00 at episode 6580, frame count 74400
# running reward: -18420.00 at episode 6590, frame count 74500
# running reward: -19010.00 at episode 6600, frame count 74600
# running reward: -17780.00 at episode 6620, frame count 74700
# running reward: -17260.00 at episode 6630, frame count 74800
# running reward: -17530.00 at episode 6640, frame count 74900
# running reward: -17530.00 at episode 6640, frame count 75000
# running reward: -17560.00 at episode 6650, frame count 75100
# running reward: -17560.00 at episode 6650, frame count 75200
# running reward: -17560.00 at episode 6650, frame count 75300
# running reward: -16760.00 at episode 6670, frame count 75400
# running reward: -16760.00 at episode 6670, frame count 75500
# running reward: -16760.00 at episode 6670, frame count 75600
# running reward: -15990.00 at episode 6690, frame count 75800
# running reward: -16480.00 at episode 6700, frame count 75900
# running reward: -16480.00 at episode 6700, frame count 76000
# running reward: -17270.00 at episode 6710, frame count 76100
# running reward: -17470.00 at episode 6720, frame count 76200
# running reward: -17470.00 at episode 6720, frame count 76300
# running reward: -17470.00 at episode 6720, frame count 76400
# running reward: -17470.00 at episode 6720, frame count 76500
# running reward: -17470.00 at episode 6720, frame count 76600
# running reward: -22480.00 at episode 6730, frame count 76700
# running reward: -22110.00 at episode 6740, frame count 76800
# running reward: -22240.00 at episode 6750, frame count 76900
# running reward: -22490.00 at episode 6760, frame count 77000
# running reward: -23320.00 at episode 6770, frame count 77100
# running reward: -23130.00 at episode 6780, frame count 77200
# running reward: -22680.00 at episode 6800, frame count 77300
# running reward: -22610.00 at episode 6810, frame count 77400
# running reward: -23540.00 at episode 6820, frame count 77500
# running reward: -23540.00 at episode 6820, frame count 77600
# running reward: -24090.00 at episode 6830, frame count 77700
# running reward: -24650.00 at episode 6850, frame count 77800
# running reward: -25070.00 at episode 6860, frame count 77900
# running reward: -24910.00 at episode 6870, frame count 78000
# running reward: -24910.00 at episode 6870, frame count 78100
# running reward: -24910.00 at episode 6870, frame count 78200
# running reward: -24520.00 at episode 6880, frame count 78300
# running reward: -25130.00 at episode 6890, frame count 78400
# running reward: -25130.00 at episode 6890, frame count 78500
# running reward: -25110.00 at episode 6900, frame count 78600
# running reward: -25110.00 at episode 6900, frame count 78700
# running reward: -23910.00 at episode 6910, frame count 78800
# running reward: -24280.00 at episode 6920, frame count 78900
# running reward: -23860.00 at episode 6930, frame count 79000
# running reward: -23650.00 at episode 6940, frame count 79100
# running reward: -23620.00 at episode 6960, frame count 79200
# running reward: -23320.00 at episode 6970, frame count 79300
# running reward: -23490.00 at episode 6980, frame count 79400
# running reward: -23650.00 at episode 6990, frame count 79500
# running reward: -23900.00 at episode 7000, frame count 79600
# running reward: -24320.00 at episode 7010, frame count 79700
# running reward: -23770.00 at episode 7020, frame count 79800
# running reward: -23770.00 at episode 7020, frame count 79900
# ...
# running reward: -24890.00 at episode 17120, frame count 190600
# running reward: -24890.00 at episode 17120, frame count 190700
# running reward: -23770.00 at episode 17130, frame count 190800
# running reward: -24440.00 at episode 17150, frame count 190900
# running reward: -24150.00 at episode 17160, frame count 191000
# running reward: -24540.00 at episode 17170, frame count 191100
# running reward: -23710.00 at episode 17180, frame count 191200
# running reward: -24970.00 at episode 17190, frame count 191300
# running reward: -24780.00 at episode 17200, frame count 191400
# running reward: -24760.00 at episode 17210, frame count 191500
# running reward: -24230.00 at episode 17230, frame count 191600
# running reward: -24780.00 at episode 17250, frame count 191700
# running reward: -24140.00 at episode 17260, frame count 191800
# running reward: -24140.00 at episode 17260, frame count 191900
# running reward: -24210.00 at episode 17270, frame count 192000
# running reward: -24290.00 at episode 17280, frame count 192100
# running reward: -24580.00 at episode 17290, frame count 192200
# running reward: -24580.00 at episode 17290, frame count 192300
# running reward: -24990.00 at episode 17300, frame count 192400
# running reward: -25520.00 at episode 17320, frame count 192500
# running reward: -25160.00 at episode 17330, frame count 192600
# running reward: -25060.00 at episode 17340, frame count 192700
# running reward: -24980.00 at episode 17350, frame count 192800
# running reward: -24390.00 at episode 17360, frame count 192900
# running reward: -25050.00 at episode 17380, frame count 193000
# running reward: -24950.00 at episode 17390, frame count 193100
# running reward: -25560.00 at episode 17410, frame count 193200
# running reward: -25300.00 at episode 17430, frame count 193300
# running reward: -25100.00 at episode 17440, frame count 193400
# running reward: -24920.00 at episode 17460, frame count 193500
# running reward: -24840.00 at episode 17470, frame count 193600
# running reward: -24010.00 at episode 17480, frame count 193700
# running reward: -23810.00 at episode 17490, frame count 193800
# running reward: -23900.00 at episode 17510, frame count 193900
# running reward: -23520.00 at episode 17520, frame count 194000
# running reward: -23510.00 at episode 17530, frame count 194100
# running reward: -23850.00 at episode 17540, frame count 194200
# running reward: -23610.00 at episode 17550, frame count 194300
# running reward: -23090.00 at episode 17560, frame count 194400
# running reward: -23090.00 at episode 17560, frame count 194500
# running reward: -23090.00 at episode 17560, frame count 194600
# running reward: -23430.00 at episode 17570, frame count 194700
# running reward: -24210.00 at episode 17590, frame count 194800
# running reward: -24110.00 at episode 17600, frame count 194900
# running reward: -24110.00 at episode 17600, frame count 195000
# running reward: -23440.00 at episode 17610, frame count 195100
# running reward: -22460.00 at episode 17620, frame count 195200
# running reward: -22890.00 at episode 17630, frame count 195300
# running reward: -23140.00 at episode 17640, frame count 195400
# running reward: -23070.00 at episode 17650, frame count 195500
# running reward: -23070.00 at episode 17650, frame count 195600
# running reward: -22910.00 at episode 17660, frame count 195700
# running reward: -22500.00 at episode 17680, frame count 195800
# running reward: -22500.00 at episode 17680, frame count 195900
# running reward: -23220.00 at episode 17690, frame count 196000
# running reward: -23490.00 at episode 17700, frame count 196100
# running reward: -23800.00 at episode 17730, frame count 196300
# running reward: -23800.00 at episode 17730, frame count 196400
# running reward: -23320.00 at episode 17740, frame count 196500
# running reward: -23320.00 at episode 17740, frame count 196600
# running reward: -23320.00 at episode 17740, frame count 196700
# running reward: -19240.00 at episode 17750, frame count 196800
# running reward: -19240.00 at episode 17750, frame count 196900
# running reward: -19320.00 at episode 17760, frame count 197000
# running reward: -19930.00 at episode 17780, frame count 197100
# running reward: -19490.00 at episode 17800, frame count 197200
# running reward: -18970.00 at episode 17810, frame count 197300
# running reward: -18970.00 at episode 17810, frame count 197400
# running reward: -18580.00 at episode 17840, frame count 197600
# running reward: -18420.00 at episode 17860, frame count 197700
# running reward: -18970.00 at episode 17870, frame count 197800
# running reward: -17590.00 at episode 17890, frame count 197900
# running reward: -18140.00 at episode 17900, frame count 198000
# running reward: -18610.00 at episode 17910, frame count 198100
# running reward: -19070.00 at episode 17920, frame count 198200
# running reward: -19450.00 at episode 17940, frame count 198300
# running reward: -19430.00 at episode 17950, frame count 198400
# running reward: -19430.00 at episode 17950, frame count 198500
# running reward: -21100.00 at episode 17960, frame count 198600
# running reward: -20820.00 at episode 17970, frame count 198700
# running reward: -20260.00 at episode 17980, frame count 198800
# running reward: -19520.00 at episode 17990, frame count 198900
# running reward: -19520.00 at episode 17990, frame count 199000
# running reward: -19980.00 at episode 18000, frame count 199100
# running reward: -19290.00 at episode 18010, frame count 199200
# running reward: -19790.00 at episode 18020, frame count 199300
# running reward: -19560.00 at episode 18040, frame count 199400
# running reward: -19440.00 at episode 18050, frame count 199500
# running reward: -19150.00 at episode 18060, frame count 199600
# running reward: -19150.00 at episode 18060, frame count 199700
# running reward: -19670.00 at episode 18070, frame count 199800
# running reward: -19670.00 at episode 18070, frame count 199900
# running reward: -19250.00 at episode 18090, frame count 200000
# running reward: -18730.00 at episode 18110, frame count 200100
# running reward: -17810.00 at episode 18140, frame count 200200
# running reward: -17950.00 at episode 18150, frame count 200300
# running reward: -18470.00 at episode 18160, frame count 200400
# running reward: -18470.00 at episode 18160, frame count 200500
# running reward: -17880.00 at episode 18170, frame count 200600
# running reward: -17380.00 at episode 18180, frame count 200700
# running reward: -17100.00 at episode 18190, frame count 200800
# running reward: -16890.00 at episode 18200, frame count 200900
# running reward: -17240.00 at episode 18210, frame count 201000
# running reward: -17460.00 at episode 18230, frame count 201100
# running reward: -17460.00 at episode 18230, frame count 201200
# running reward: -17880.00 at episode 18250, frame count 201300
# running reward: -17880.00 at episode 18250, frame count 201400
# running reward: -17940.00 at episode 18270, frame count 201500
# running reward: -17710.00 at episode 18280, frame count 201600
# running reward: -16860.00 at episode 18290, frame count 201700
# running reward: -16420.00 at episode 18300, frame count 201800
# running reward: -16550.00 at episode 18310, frame count 201900
# running reward: -16550.00 at episode 18310, frame count 202000
# running reward: -16470.00 at episode 18320, frame count 202100
# running reward: -16470.00 at episode 18320, frame count 202200
# running reward: -17040.00 at episode 18340, frame count 202300
# running reward: -16580.00 at episode 18360, frame count 202400
# running reward: -16130.00 at episode 18370, frame count 202500
# running reward: -16340.00 at episode 18380, frame count 202600
# running reward: -16340.00 at episode 18380, frame count 202700
# running reward: -16340.00 at episode 18380, frame count 202800
# running reward: -17410.00 at episode 18390, frame count 202900
# running reward: -17660.00 at episode 18400, frame count 203000
# running reward: -17660.00 at episode 18400, frame count 203100
# running reward: -17260.00 at episode 18430, frame count 203200
# running reward: -17050.00 at episode 18450, frame count 203300
# running reward: -17440.00 at episode 18460, frame count 203400
# running reward: -17230.00 at episode 18470, frame count 203500
# running reward: -17230.00 at episode 18470, frame count 203600
# running reward: -17450.00 at episode 18480, frame count 203700
# running reward: -17630.00 at episode 18490, frame count 203800
# running reward: -17070.00 at episode 18520, frame count 203900
# running reward: -17020.00 at episode 18530, frame count 204000
# running reward: -16910.00 at episode 18540, frame count 204100
# running reward: -16910.00 at episode 18540, frame count 204200
# running reward: -17690.00 at episode 18560, frame count 204300
# running reward: -17060.00 at episode 18570, frame count 204400
# running reward: -16680.00 at episode 18590, frame count 204500
# running reward: -16680.00 at episode 18590, frame count 204600
# running reward: -17170.00 at episode 18610, frame count 204700
# running reward: -17110.00 at episode 18620, frame count 204800
# running reward: -16480.00 at episode 18630, frame count 204900
# running reward: -16530.00 at episode 18640, frame count 205000
# running reward: -16530.00 at episode 18640, frame count 205100
# running reward: -16610.00 at episode 18650, frame count 205200
# running reward: -16700.00 at episode 18660, frame count 205300
# running reward: -16870.00 at episode 18670, frame count 205400
# running reward: -17240.00 at episode 18680, frame count 205500
# running reward: -16950.00 at episode 18700, frame count 205600
# running reward: -16470.00 at episode 18720, frame count 205700
# running reward: -16560.00 at episode 18730, frame count 205800
# running reward: -16870.00 at episode 18740, frame count 205900
# running reward: -16650.00 at episode 18760, frame count 206000
# running reward: -16650.00 at episode 18760, frame count 206100
# running reward: -16650.00 at episode 18760, frame count 206200
# running reward: -17310.00 at episode 18770, frame count 206300
# running reward: -17310.00 at episode 18770, frame count 206400
# running reward: -17690.00 at episode 18780, frame count 206500
# running reward: -17630.00 at episode 18800, frame count 206600
# running reward: -18280.00 at episode 18810, frame count 206700
# running reward: -18280.00 at episode 18810, frame count 206800
# running reward: -18120.00 at episode 18830, frame count 206900
# running reward: -18360.00 at episode 18840, frame count 207000
# running reward: -18360.00 at episode 18840, frame count 207100
# running reward: -18180.00 at episode 18860, frame count 207200
# running reward: -17990.00 at episode 18870, frame count 207300
# running reward: -18380.00 at episode 18880, frame count 207400
# running reward: -17130.00 at episode 18910, frame count 207500
# running reward: -17320.00 at episode 18920, frame count 207600
# running reward: -17320.00 at episode 18920, frame count 207700
# running reward: -17490.00 at episode 18930, frame count 207800
# running reward: -17960.00 at episode 18950, frame count 207900
# running reward: -17960.00 at episode 18950, frame count 208000
# running reward: -17960.00 at episode 18950, frame count 208100
# running reward: -16760.00 at episode 18960, frame count 208200
# running reward: -18020.00 at episode 18980, frame count 208300
# running reward: -17330.00 at episode 19010, frame count 208500
# running reward: -17450.00 at episode 19020, frame count 208600
# running reward: -17150.00 at episode 19030, frame count 208700
# running reward: -17120.00 at episode 19050, frame count 208800
# running reward: -16700.00 at episode 19060, frame count 208900
# running reward: -15410.00 at episode 19080, frame count 209000
# running reward: -15410.00 at episode 19080, frame count 209100
# running reward: -16010.00 at episode 19090, frame count 209200
# running reward: -16040.00 at episode 19110, frame count 209300
# running reward: -16340.00 at episode 19120, frame count 209400
# running reward: -16550.00 at episode 19130, frame count 209500
# running reward: -16550.00 at episode 19130, frame count 209600
# running reward: -16910.00 at episode 19140, frame count 209700
# running reward: -16910.00 at episode 19140, frame count 209800
# running reward: -18110.00 at episode 19150, frame count 209900
# running reward: -17680.00 at episode 19160, frame count 210000
# running reward: -18070.00 at episode 19170, frame count 210100
# running reward: -18890.00 at episode 19180, frame count 210200
# running reward: -19150.00 at episode 19200, frame count 210300
# running reward: -18660.00 at episode 19210, frame count 210400
# running reward: -17850.00 at episode 19220, frame count 210500
# running reward: -17850.00 at episode 19220, frame count 210600
# running reward: -18500.00 at episode 19230, frame count 210700
# running reward: -17720.00 at episode 19240, frame count 210800
# running reward: -17720.00 at episode 19240, frame count 210900
# running reward: -17720.00 at episode 19240, frame count 211000
# running reward: -18410.00 at episode 19260, frame count 211100
# running reward: -18410.00 at episode 19260, frame count 211200
# running reward: -19120.00 at episode 19270, frame count 211300
# running reward: -19220.00 at episode 19280, frame count 211400
# running reward: -19220.00 at episode 19280, frame count 211500
# running reward: -19170.00 at episode 19290, frame count 211600
# running reward: -18900.00 at episode 19300, frame count 211700
# running reward: -18900.00 at episode 19300, frame count 211800
# running reward: -18900.00 at episode 19300, frame count 211900
# running reward: -19280.00 at episode 19310, frame count 212000
# running reward: -19280.00 at episode 19310, frame count 212100
# running reward: -19990.00 at episode 19320, frame count 212200
# running reward: -19990.00 at episode 19320, frame count 212300
# running reward: -19110.00 at episode 19330, frame count 212400
# running reward: -19610.00 at episode 19340, frame count 212500
# running reward: -19760.00 at episode 19350, frame count 212600
# running reward: -20000.00 at episode 19360, frame count 212700
# running reward: -20020.00 at episode 19380, frame count 212800
# running reward: -19050.00 at episode 19390, frame count 212900
# running reward: -19050.00 at episode 19390, frame count 213000
# running reward: -19110.00 at episode 19410, frame count 213100
# Traceback (most recent call last):
#   File "C:\Users\carlo\AppData\Local\Temp/ipykernel_26220/3261026035.py", line 56, in <module>
#     env.step()
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\environment.py", line 338, in step
#     self._update_state(rl_output)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\environment.py", line 291, in _update_state
#     self._env_state[brain_name] = steps_from_proto(
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_utils.py", line 330, in steps_from_proto
#     _process_maybe_compressed_observation(
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_utils.py", line 257, in _process_maybe_compressed_observation
#     batched_visual = [
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_utils.py", line 258, in <listcomp>
#     _observation_to_np_array(agent_obs.observations[obs_index], shape)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_utils.py", line 234, in _observation_to_np_array
#     img = process_pixels(
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\timers.py", line 305, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\carlo\anaconda3\lib\site-packages\mlagents_envs\rpc_utils.py", line 125, in process_pixels
#     image_arrays.append(np.array(image, dtype=np.float32) / 255.0)
# KeyboardInterrupt
# None

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
model.layers[4].get_weights()[0].shape
# Out:
# (9, 9, 128, 128)

# %%
resh = np.reshape(model.layers[4].get_weights()[0], (-1, 9, 9, 1))

# %%
# for i in 
plt.imshow(model.layers[4].get_weights()[0][:,:,127,127])

# %%
plt.imshow(state_history[0], cmap='gray')

# %%
resh.shape
# Out:
# (16384, 9, 9, 1)

# %%
plt.imshow(resh[6, :,:,:])

# %%
env.close()
